# %% [markdown]
# # Imports

# %%
# Python standard library
import glob
import os

# Third-party libraries
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Local python files
from path_constants import FIGURE_FOLDER, DATA_FOLDER, ORPHEUM_BENCHMARKING_FOLDER
from nb_utils import describe
from plot_constants import (
    PROTEIN_COLOR,
    DAYHOFF_COLOR,
    PEPTIDE_MOLTYPE_PALETTE,
    PEPTIDE_MOLTYPE_ORDER,
    PEPTIDE_ALPHABET_KSIZES,
    PEPTIDE_ALPHABET_PALETTES,
)
from mya_utils import (
    clean_common_names_of_species,
    BUSCO_MAMMALIA_SPECIES,
    MYA_COLOR_KWARGS,
    MYA_ORDER,
)

# %% [markdown]
# ## Get number of protein sequences per species

# %%
proteome_folder = os.path.join(
    DATA_FOLDER, "orpheum-benchmarking", "mammalia_busco_subsets"
)

busco_mammalia_species = BUSCO_MAMMALIA_SPECIES.copy()

col = "proteome_size"
busco_mammalia_species[col] = 0
for fasta in glob.glob(os.path.join(proteome_folder, "*.fasta")):
    species_lower = os.path.basename(fasta).split("__")[-1].split(".")[0]
    proteome_size = sum(1 for _ in screed.open(fasta))

    busco_mammalia_species.loc[species_lower, col] = proteome_size
busco_mammalia_species = busco_mammalia_species.sort_values("mya")
describe(busco_mammalia_species)
# Out:
# (18, 4)
# --- First 5 entries ---
#                    common_name   scientific_name   mya  proteome_size
# scientific_lower
# homo_sapiens             human      Homo sapiens   0.0              0
# macaca_mulatta         macaque    Macaca mulatta  29.4              0
# aotus_nancymaae   night monkey   Aotus nancymaae  43.2              0
# tupaia_chinensis        tupaia  Tupaia chinensis  82.0              0
# mus_musculus       house mouse      Mus musculus  90.0              0

# %% [markdown]
# ## Reindex BUSCO mammalia series to use common name

# %%
busco_mammalia_common = busco_mammalia_species.reset_index().set_index("common_name")

# %% [markdown]
# ## Read ROC AUC csv

# %%
csv = os.path.join(
    ORPHEUM_BENCHMARKING_FOLDER,
    "busco_mammalia_coding_scores_roc_auc_score.csv",
)


combined_roc_auc_score = pd.read_csv(csv)
# combined_roc_auc_score = combined_roc_auc_score.join(distance_from_human_mya, on='species')

combined_roc_auc_score.species = combined_roc_auc_score.species.map(
    clean_common_names_of_species
)
# Everything decreases after k > 21
combined_roc_auc_score = combined_roc_auc_score.query("ksize <= 21")
combined_roc_auc_score = combined_roc_auc_score.join(
    busco_mammalia_common, on="species"
)
combined_roc_auc_score.head()
# Out:
#   species alphabet  ksize  score_value score_name    scientific_lower  \
# 0   baiji  dayhoff      5     0.397805    roc_auc  lipotes_vexillifer
# 1   baiji  dayhoff      6     0.363173    roc_auc  lipotes_vexillifer
# 2   baiji  dayhoff      7     0.363950    roc_auc  lipotes_vexillifer
# 3   baiji  dayhoff      8     0.385517    roc_auc  lipotes_vexillifer
# 4   baiji  dayhoff      9     0.418185    roc_auc  lipotes_vexillifer
#
#       scientific_name   mya  proteome_size
# 0  Lipotes vexillifer  96.0              0
# 1  Lipotes vexillifer  96.0              0
# 2  Lipotes vexillifer  96.0              0
# 3  Lipotes vexillifer  96.0              0
# 4  Lipotes vexillifer  96.0              0

# %%
max_roc_scores = combined_roc_auc_score.groupby(
    ['species', 'alphabet']).score_value.max()
max_roc_scores.name = 'max_roc_auc'
max_roc_scores = max_roc_scores.reset_index()
max_roc_scores = max_roc_scores.join(busco_mammalia_common, on='species')
describe(max_roc_scores)
# Out:
# (36, 7)
# --- First 5 entries ---
#   species alphabet  max_roc_auc     scientific_lower      scientific_name  \
# 0   baiji  dayhoff     0.500255   lipotes_vexillifer   Lipotes vexillifer
# 1   baiji  protein     0.500607   lipotes_vexillifer   Lipotes vexillifer
# 2     bat  dayhoff     0.552860  rhinolophus_sinicus  Rhinolophus sinicus
# 3     bat  protein     0.503737  rhinolophus_sinicus  Rhinolophus sinicus
# 4   camel  dayhoff     0.500110   camelus_bactrianus   Camelus bactrianus
#
#     mya  proteome_size
# 0  96.0              0
# 1  96.0              0
# 2  96.0              0
# 3  96.0              0
# 4  96.0              0

# %%
max_roc_scores.query('max_roc_auc > 0.6')
# Out:
#          species alphabet  max_roc_auc       scientific_lower  \
# 14      hedgehog  dayhoff     0.869341    erinaceus_europaeus
# 15      hedgehog  protein     0.929230    erinaceus_europaeus
# 16   house mouse  dayhoff     0.880976           mus_musculus
# 17   house mouse  protein     0.938552           mus_musculus
# 18         human  dayhoff     0.996881           homo_sapiens
# 19         human  protein     0.998456           homo_sapiens
# 22       macaque  dayhoff     0.770334         macaca_mulatta
# 23       macaque  protein     0.789053         macaca_mulatta
# 24  night monkey  dayhoff     0.818646        aotus_nancymaae
# 25  night monkey  protein     0.844914        aotus_nancymaae
# 28        rabbit  dayhoff     0.703327  oryctolagus_cuniculus
# 29        rabbit  protein     0.743184  oryctolagus_cuniculus
#
#           scientific_name   mya  proteome_size
# 14    Erinaceus europaeus  96.0              0
# 15    Erinaceus europaeus  96.0              0
# 16           Mus musculus  90.0              0
# 17           Mus musculus  90.0              0
# 18           Homo sapiens   0.0              0
# 19           Homo sapiens   0.0              0
# 22         Macaca mulatta  29.4              0
# 23         Macaca mulatta  29.4              0
# 24        Aotus nancymaae  43.2              0
# 25        Aotus nancymaae  43.2              0
# 28  Oryctolagus cuniculus  90.0              0
# 29  Oryctolagus cuniculus  90.0              0

# %% [markdown]
# # SFig 1G

# %%
g = sns.lmplot(
    x="proteome_size",
    y="max_roc_auc",
    col="alphabet",
    col_order=["protein", "dayhoff"],
    data=max_roc_scores,
    height=2.5,
    fit_reg=False,
    **MYA_COLOR_KWARGS
)
g.set(ylim=(0, 1.05), xlim=(-10, 2e4), xlabel="BUSCO Mammalia proteins", xscale="log")
for ax in g.axes.flat:
    ax.axhline(0.7, linestyle="--", color="grey")
    ax.axvline(2000, linestyle="--", color="grey")
pdf = os.path.join(FIGURE_FOLDER, "orpheum_translate__proteome_size_vs_max_roc_auc.pdf")
g.savefig(pdf)
# Out:
# /home/olga/miniconda3/envs/immune-evolution/lib/python3.7/site-packages/seaborn/axisgrid.py:49: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   ax.set(**kwargs)

# %%
combined_roc_auc_score_dayhoff17_protein8 = combined_roc_auc_score.query('(alphabet == "dayhoff" and ksize == 17) or (alphabet == "protein" and ksize == 8)')
describe(combined_roc_auc_score_dayhoff17_protein8)
# Out:
# (36, 9)
# --- First 5 entries ---
#     species alphabet  ksize  score_value score_name     scientific_lower  \
# 12    baiji  dayhoff     17     0.499700    roc_auc   lipotes_vexillifer
# 30    baiji  protein      8     0.500530    roc_auc   lipotes_vexillifer
# 66      bat  dayhoff     17     0.499999    roc_auc  rhinolophus_sinicus
# 84      bat  protein      8     0.500009    roc_auc  rhinolophus_sinicus
# 120   camel  dayhoff     17     0.500095    roc_auc   camelus_bactrianus
#
#          scientific_name   mya  proteome_size
# 12    Lipotes vexillifer  96.0              0
# 30    Lipotes vexillifer  96.0              0
# 66   Rhinolophus sinicus  96.0              0
# 84   Rhinolophus sinicus  96.0              0
# 120   Camelus bactrianus  96.0              0

# %%
combined_roc_auc_score_dayhoff17_protein8.query('proteome_size > 2000').groupby(['alphabet', 'mya']).score_value.mean()
# Out:
# Series([], Name: score_value, dtype: float64)

# %% [markdown]
# ### @paper plot correlation of proteom size to ROC auc

# %%
combined_roc_auc_score_dayhoff17_protein8.head()
# Out:
#     species alphabet  ksize  score_value score_name     scientific_lower  \
# 12    baiji  dayhoff     17     0.499700    roc_auc   lipotes_vexillifer
# 30    baiji  protein      8     0.500530    roc_auc   lipotes_vexillifer
# 66      bat  dayhoff     17     0.499999    roc_auc  rhinolophus_sinicus
# 84      bat  protein      8     0.500009    roc_auc  rhinolophus_sinicus
# 120   camel  dayhoff     17     0.500095    roc_auc   camelus_bactrianus
#
#          scientific_name   mya  proteome_size
# 12    Lipotes vexillifer  96.0              0
# 30    Lipotes vexillifer  96.0              0
# 66   Rhinolophus sinicus  96.0              0
# 84   Rhinolophus sinicus  96.0              0
# 120   Camelus bactrianus  96.0              0

# %%
combined_roc_auc_score_dayhoff17_protein8_corr = combined_roc_auc_score_dayhoff17_protein8.groupby('alphabet').corr(method='spearman')
combined_roc_auc_score_dayhoff17_protein8_corr
# Out:
#                         ksize  score_value       mya  proteome_size
# alphabet
# dayhoff  ksize            NaN          NaN       NaN            NaN
#          score_value      NaN     1.000000 -0.525680            NaN
#          mya              NaN    -0.525680  1.000000            NaN
#          proteome_size    NaN          NaN       NaN            NaN
# protein  ksize            NaN          NaN       NaN            NaN
#          score_value      NaN     1.000000 -0.439679            NaN
#          mya              NaN    -0.439679  1.000000            NaN
#          proteome_size    NaN          NaN       NaN            NaN

# %% [markdown]
# # SFig 1D

# %% [markdown]
# ### MYA vs ROC

# %%
protein_mya_roc_corr = combined_roc_auc_score_dayhoff17_protein8_corr.loc[
    ("protein", "mya"), "score_value"
]
dayhoff_mya_roc_corr = combined_roc_auc_score_dayhoff17_protein8_corr.loc[
    ("dayhoff", "mya"), "score_value"
]

mya_roc_corrs = {"protein": protein_mya_roc_corr, "dayhoff": dayhoff_mya_roc_corr}

g = sns.lmplot(
    data=combined_roc_auc_score_dayhoff17_protein8,
    x="mya",
    y="score_value",
    hue="alphabet",
    palette=PEPTIDE_MOLTYPE_PALETTE,
    hue_order=PEPTIDE_MOLTYPE_ORDER,
    size=2.25,
    legend=False
)
for ax in g.axes.flat:
    h, l = ax.get_legend_handles_labels()
    labels = [f'{x}, $R={mya_roc_corrs[x]:.3f}$' for x in l]
    ax.legend(h, labels)


g.set(title=('MYA vs ROC AUC'), ylabel='ROC AUC', xlabel='Millions of years ago (mya)')
pdf = os.path.join(
    FIGURE_FOLDER,
    f"orpheum_translate__lmplot__mya_vs_roc-auc.pdf",
)
g.set(ylim=(0, 1))
g.savefig(pdf)
# Out:
# /home/olga/miniconda3/envs/immune-evolution/lib/python3.7/site-packages/seaborn/regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
pdf
# Out:
# '../figures/orpheum_translate__lmplot__mya_vs_roc-auc.pdf'

# %% [markdown]
# # SFig 1F

# %% [markdown]
# ### Number of proteins vs ROC

# %%
protein_n_proteins_roc_corr = combined_roc_auc_score_dayhoff17_protein8_corr.loc[
    ("protein", "proteome_size"), "score_value"
]
dayhoff_n_proteins_roc_corr = combined_roc_auc_score_dayhoff17_protein8_corr.loc[
    ("dayhoff", "proteome_size"), "score_value"
]

n_proteins_roc_corrs = {"protein": protein_n_proteins_roc_corr, "dayhoff": dayhoff_n_proteins_roc_corr}

g = sns.lmplot(
    data=combined_roc_auc_score_dayhoff17_protein8,
    x="proteome_size",
    y="score_value",
    hue="alphabet",
    palette=PEPTIDE_MOLTYPE_PALETTE,
    hue_order=PEPTIDE_MOLTYPE_ORDER,
    size=2.25,
    legend=False,
)


for ax in g.axes.flat:
    h, l = ax.get_legend_handles_labels()
    labels = [f'{x}, $R={n_proteins_roc_corrs[x]:.3f}$' for x in l]
    ax.legend(h, labels)

g.set(title=('Proteome size vs ROC AUC'), ylabel='ROC AUC', xlabel='Number of proteins')
g.set(ylim=(0, 1))
pdf = os.path.join(
    FIGURE_FOLDER,
    f"orpheum_translate__lmplot__mya_vs_proteome-size.pdf",
)
g.savefig(pdf)
# Out:
# /home/olga/miniconda3/envs/immune-evolution/lib/python3.7/site-packages/seaborn/regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### @paper kmer complexity

# %% [markdown]
# ## Get k-mer complexity per species

# %%
csv = os.path.join(
    ORPHEUM_BENCHMARKING_FOLDER, "busco_mammalia_kmer_complexity.csv"
)

kmer_complexity = pd.read_csv(csv)
kmer_complexity["moltype"] = kmer_complexity.molecule.str.strip("0123456789")
kmer_complexity = kmer_complexity.join(busco_mammalia_species, on="name")
kmer_complexity
# Out:
#                               name   molecule  ksize  sigma  \
# 0                 tupaia_chinensis   dayhoff6     17      6
# 1                 tupaia_chinensis  protein20      8     20
# 2               camelus_bactrianus   dayhoff6     17      6
# 3               camelus_bactrianus  protein20      8     20
# 4                     mus_musculus   dayhoff6     17      6
# 5                     mus_musculus  protein20      8     20
# 6               lipotes_vexillifer   dayhoff6     17      6
# 7               lipotes_vexillifer  protein20      8     20
# 8                     capra_hircus   dayhoff6     17      6
# 9                     capra_hircus  protein20      8     20
# 10             rhinolophus_sinicus   dayhoff6     17      6
# 11             rhinolophus_sinicus  protein20      8     20
# 12       ceratotherium_simum_simum   dayhoff6     17      6
# 13       ceratotherium_simum_simum  protein20      8     20
# 14              nannospalax_galili   dayhoff6     17      6
# 15              nannospalax_galili  protein20      8     20
# 16                    homo_sapiens   dayhoff6     17      6
# 17                    homo_sapiens  protein20      8     20
# 18             erinaceus_europaeus   dayhoff6     17      6
# 19             erinaceus_europaeus  protein20      8     20
# 20  peromyscus_maniculatus_bairdii   dayhoff6     17      6
# 21  peromyscus_maniculatus_bairdii  protein20      8     20
# 22                  macaca_mulatta   dayhoff6     17      6
# 23                  macaca_mulatta  protein20      8     20
# 24                 aotus_nancymaae   dayhoff6     17      6
# 25                 aotus_nancymaae  protein20      8     20
# 26          phascolarctos_cinereus   dayhoff6     17      6
# 27          phascolarctos_cinereus  protein20      8     20
# 28             chinchilla_lanigera   dayhoff6     17      6
# 29             chinchilla_lanigera  protein20      8     20
# 30                   sorex_araneus   dayhoff6     17      6
# 31                   sorex_araneus  protein20      8     20
# 32           oryctolagus_cuniculus   dayhoff6     17      6
# 33           oryctolagus_cuniculus  protein20      8     20
# 34        ornithorhynchus_anatinus   dayhoff6     17      6
# 35        ornithorhynchus_anatinus  protein20      8     20
#
#     expected_collisions  n_unique_kmers  n_theoretical_kmers_log10  \
# 0          6.506573e-10          506371                  13.228571
# 1          7.144468e-10          518316                  10.408240
# 2          2.747611e-21             724                  13.228571
# 3          3.197955e-21             752                  10.408240
# 4          7.880357e-06         5443866                  13.228571
# 5          8.231361e-06         5505061                  10.408240
# 6          1.911689e-19            2091                  13.228571
# 7          2.188906e-19            2163                  10.408240
# 8          3.281257e-13           75724                  13.228571
# 9          3.585962e-13           77413                  10.408240
# 10         6.246088e-21             889                  13.228571
# 11         6.502889e-21             898                  10.408240
# 12         5.062512e-24             150                  13.228571
# 13         6.391305e-24             159                  10.408240
# 14         1.925671e-20            1178                  13.228571
# 15         2.108382e-20            1205                  10.408240
# 16         7.852379e-06         5439082                  13.228571
# 17         8.194001e-06         5498718                  10.408240
# 18         7.888326e-06         5445706                  13.228571
# 19         8.199259e-06         5499456                  10.408240
# 20         2.690426e-22             405                  13.228571
# 21         2.937666e-22             414                  10.408240
# 22         4.616363e-07         2641140                  13.228571
# 23         4.924859e-07         2684633                  10.408240
# 24         1.343059e-06         3463840                  13.228571
# 25         1.421344e-06         3513425                  10.408240
# 26         2.616793e-18            4022                  13.228571
# 27         2.757474e-18            4075                  10.408240
# 28         7.480538e-21             930                  13.228571
# 29         8.387814e-21             957                  10.408240
# 30         5.209895e-16           15108                  13.228571
# 31         5.664048e-16           15430                  10.408240
# 32         2.712892e-07         2308839                  13.228571
# 33         2.891754e-07         2346224                  10.408240
# 34         1.730450e-09          647083                  13.228571
# 35         1.852019e-09          658167                  10.408240
#
#     n_unique_kmers_log10  unique_over_theoretical_log10  moltype  \
# 0               5.704469                      -7.524102  dayhoff
# 1               5.714595                      -4.693645  protein
# 2               2.859739                     -10.368833  dayhoff
# 3               2.876218                      -7.532022  protein
# 4               6.735907                      -6.492664  dayhoff
# 5               6.740762                      -3.667478  protein
# 6               3.320354                      -9.908217  dayhoff
# 7               3.335057                      -7.073183  protein
# 8               4.879234                      -8.349338  dayhoff
# 9               4.888814                      -5.519426  protein
# 10              2.948902                     -10.279669  dayhoff
# 11              2.953276                      -7.454964  protein
# 12              2.176091                     -11.052480  dayhoff
# 13              2.201397                      -8.206843  protein
# 14              3.071145                     -10.157426  dayhoff
# 15              3.080987                      -7.327253  protein
# 16              6.735526                      -6.493046  dayhoff
# 17              6.740261                      -3.667979  protein
# 18              6.736054                      -6.492517  dayhoff
# 19              6.740320                      -3.667920  protein
# 20              2.607455                     -10.621116  dayhoff
# 21              2.617000                      -7.791240  protein
# 22              6.421791                      -6.806780  dayhoff
# 23              6.428885                      -3.979355  protein
# 24              6.539558                      -6.689013  dayhoff
# 25              6.545731                      -3.862509  protein
# 26              3.604442                      -9.624129  dayhoff
# 27              3.610128                      -6.798112  protein
# 28              2.968483                     -10.260088  dayhoff
# 29              2.980912                      -7.427328  protein
# 30              4.179207                      -9.049364  dayhoff
# 31              4.188366                      -6.219874  protein
# 32              6.363394                      -6.865178  dayhoff
# 33              6.370369                      -4.037870  protein
# 34              5.810960                      -7.417611  dayhoff
# 35              5.818336                      -4.589904  protein
#
#      common_name                 scientific_name    mya  proteome_size
# 0         tupaia                Tupaia chinensis   82.0              0
# 1         tupaia                Tupaia chinensis   82.0              0
# 2          camel              Camelus bactrianus   96.0              0
# 3          camel              Camelus bactrianus   96.0              0
# 4    house mouse                    Mus musculus   90.0              0
# 5    house mouse                    Mus musculus   90.0              0
# 6          baiji              Lipotes vexillifer   96.0              0
# 7          baiji              Lipotes vexillifer   96.0              0
# 8           goat                    Capra hircus   96.0              0
# 9           goat                    Capra hircus   96.0              0
# 10           bat             Rhinolophus sinicus   96.0              0
# 11           bat             Rhinolophus sinicus   96.0              0
# 12         rhino       Ceratotherium simum simum   96.0              0
# 13         rhino       Ceratotherium simum simum   96.0              0
# 14        spalax              Nannospalax galili   90.0              0
# 15        spalax              Nannospalax galili   90.0              0
# 16         human                    Homo sapiens    0.0              0
# 17         human                    Homo sapiens    0.0              0
# 18      hedgehog             Erinaceus europaeus   96.0              0
# 19      hedgehog             Erinaceus europaeus   96.0              0
# 20    deer mouse  Peromyscus Maniculatus bairdii   90.0              0
# 21    deer mouse  Peromyscus Maniculatus bairdii   90.0              0
# 22       macaque                  Macaca mulatta   29.4              0
# 23       macaque                  Macaca mulatta   29.4              0
# 24  night monkey                 Aotus nancymaae   43.2              0
# 25  night monkey                 Aotus nancymaae   43.2              0
# 26         koala          Phascolarctos cinereus  159.0              0
# 27         koala          Phascolarctos cinereus  159.0              0
# 28    chinchilla             Chinchilla lanigera   90.0              0
# 29    chinchilla             Chinchilla lanigera   90.0              0
# 30  common shrew                   Sorex araneus   96.0              0
# 31  common shrew                   Sorex araneus   96.0              0
# 32        rabbit           Oryctolagus cuniculus   90.0              0
# 33        rabbit           Oryctolagus cuniculus   90.0              0
# 34      platypus        Ornithorhynchus anatinus  177.0              0
# 35      platypus        Ornithorhynchus anatinus  177.0              0

# %%
kmer_complexity_roc_scores = kmer_complexity.merge(
    combined_roc_auc_score_dayhoff17_protein8[["species", "alphabet", "score_value"]],
    left_on=["common_name", "moltype"],
    right_on=["species", "alphabet"],
)
kmer_complexity_roc_scores.head()
# Out:
#                  name   molecule  ksize  sigma  expected_collisions  \
# 0    tupaia_chinensis   dayhoff6     17      6         6.506573e-10
# 1    tupaia_chinensis  protein20      8     20         7.144468e-10
# 2  camelus_bactrianus   dayhoff6     17      6         2.747611e-21
# 3  camelus_bactrianus  protein20      8     20         3.197955e-21
# 4        mus_musculus   dayhoff6     17      6         7.880357e-06
#
#    n_unique_kmers  n_theoretical_kmers_log10  n_unique_kmers_log10  \
# 0          506371                  13.228571              5.704469
# 1          518316                  10.408240              5.714595
# 2             724                  13.228571              2.859739
# 3             752                  10.408240              2.876218
# 4         5443866                  13.228571              6.735907
#
#    unique_over_theoretical_log10  moltype  common_name     scientific_name  \
# 0                      -7.524102  dayhoff       tupaia    Tupaia chinensis
# 1                      -4.693645  protein       tupaia    Tupaia chinensis
# 2                     -10.368833  dayhoff        camel  Camelus bactrianus
# 3                      -7.532022  protein        camel  Camelus bactrianus
# 4                      -6.492664  dayhoff  house mouse        Mus musculus
#
#     mya  proteome_size      species alphabet  score_value
# 0  82.0              0       tupaia  dayhoff     0.567616
# 1  82.0              0       tupaia  protein     0.586537
# 2  96.0              0        camel  dayhoff     0.500095
# 3  96.0              0        camel  protein     0.500168
# 4  90.0              0  house mouse  dayhoff     0.872079

# %%
kmer_complexity_roc_scores_corr = kmer_complexity_roc_scores.groupby('alphabet')[['score_value', 'n_unique_kmers', 'n_unique_kmers_log10']].corr(method='spearman')
kmer_complexity_roc_scores_corr
# Out:
#                                score_value  n_unique_kmers  \
# alphabet
# dayhoff  score_value              1.000000        0.923633
#          n_unique_kmers           0.923633        1.000000
#          n_unique_kmers_log10     0.923633        1.000000
# protein  score_value              1.000000        0.966976
#          n_unique_kmers           0.966976        1.000000
#          n_unique_kmers_log10     0.966976        1.000000
#
#                                n_unique_kmers_log10
# alphabet
# dayhoff  score_value                       0.923633
#          n_unique_kmers                    1.000000
#          n_unique_kmers_log10              1.000000
# protein  score_value                       0.966976
#          n_unique_kmers                    1.000000
#          n_unique_kmers_log10              1.000000

# %% [markdown]
# # SFig 1E

# %%
protein_kmer_roc_corr = kmer_complexity_roc_scores_corr.loc[('protein', 'score_value'), 'n_unique_kmers_log10']
dayhoff_kmer_roc_corr = kmer_complexity_roc_scores_corr.loc[('dayhoff', 'score_value'), 'n_unique_kmers_log10']
kmer_roc_corrs = {'protein': protein_kmer_roc_corr, 'dayhoff': dayhoff_kmer_roc_corr}

g = sns.lmplot(
    data=kmer_complexity_roc_scores,
    x="n_unique_kmers_log10",
    y="score_value",
    hue="alphabet",
    palette=PEPTIDE_MOLTYPE_PALETTE,
    hue_order=PEPTIDE_MOLTYPE_ORDER,
    size=2.25,
    legend=False,
)
g.set(title=('Number of unique $k$-mers vs ROC AUC'), xlabel='$\log_{10}$ Number of unique $k$-mers', ylabel='ROC AUC')
for ax in g.axes.flat:
    h, l = ax.get_legend_handles_labels()
    labels = [f'{x}, $R={kmer_roc_corrs[x]:.3f}$' for x in l]
    ax.legend(h, labels)
g.set(ylim=(0, 1))
pdf = os.path.join(
    FIGURE_FOLDER,
    f"orpheum_translate__lmplot__mya_vs_n_unique_kmers.pdf",
)
g.savefig(pdf)
# Out:
# /home/olga/miniconda3/envs/immune-evolution/lib/python3.7/site-packages/seaborn/regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
