# %% [markdown]
# # Goal for how to organize the signatures
#
# Copy all ribosomal-removed signatures to these subfolders
#
#
# Using `DNA`, `protein`, and `dayhoff` for shorthand now. In reality would use the full sketch id, e.g. `alphabet-DNA__ksize-21__scaled-10`
#
# ```
# mouse2mouse/
#     self2self-bootstrapped/
#         0--train-mouse1-single-cells/
#             iteration-00/
#                 DNA/
#                 protein/
#                 dayhoff/
#             iteration-01/
#                 ...
#         1--test-mouse1-single-cells/
#             iteration-00/
#                 DNA/
#                 protein/
#                 dayhoff/
#             iteration-01/
#                 ...
#         2--train-mouse1-merged-celltype-sigs/
#             iteration-00/
#                 DNA/
#                 protein/
#                 dayhoff/
#             iteration-01/
#                 ...
#         3--train-mouse1-celltype-remove-common-kmers/
#             iteration-00/
#                 DNA/
#                 protein/
#                 dayhoff/
#             iteration-01/
#                 ...
#         4--train-mouse1--celltype-sbt-dbs/
#             iteration-00/
#                 DNA/
#                 protein/
#                 dayhoff/
#             iteration-01/
#                 ...
#         5--search-results/
#             iteration-00/
#                 DNA/
#                 protein/
#                 dayhoff/
#             iteration-00/
#                 ...
#     mouse1-mouse2/
#         0--train-mouse1-single-cells/
#             DNA/
#             protein/
#             dayhoff/
#         1--test-mouse2-single-cells/
#             DNA/
#             protein/
#             dayhoff/
#         2--train-mouse1-merged-celltype-sigs/
#             DNA/
#             protein/
#             dayhoff/
#         3--train-mouse1-celltype-remove-common-kmers/
#             DNA/
#             protein/
#             dayhoff/
#         4--train-mouse1-celltype-sbt-dbs/
#             DNA/
#             protein/
#             dayhoff
#         5--search-results/
#             DNA/
#             protein/
#             dayhoff/
# train-mouse/
#     0--protein-coding-fastas/
#         nucleotide/
#         peptide/
#     1--single-cell-sigs/
#         DNA/
#         protein/
#         dayhoff/
#     2--merged-celltype-sigs/
#         DNA/
#         protein/
#         dayhoff/
#     3--celltype-remove-common-kmers/
#         DNA/
#         protein/
#         dayhoff/
#     4--celltype-sbt-dbs/
#         DNA/
#         protein/
#         dayhoff/
# test-human/
#     0--protein-coding-fastas/
#         nucleotide/
#         peptide/
#     1--single-cell-sigs/
#         DNA/
#         protein/
#         dayhoff/
#     2--mouse-search-results/
#         DNA/
#         protein/
#         dayhoffl
# test-lemur/
#     0--protein-coding-fastas/
#         nucleotide/
#         peptide/
#     1--single-cell-sigs/
#         protein/
#         dayhoff/
#     2--mouse-search-results/
#         DNA/
#         protein/
#         dayhoff/
# test-bat/
#     0--protein-coding-fastas/
#         nucleotide/
#         peptide/
#     1--single-cell-sigs/
#         protein/
#         dayhoff/
#     2--mouse-search-results/
#         DNA/
#         protein/
#         dayhoff/
# ```

# %% [markdown]
# # Imports

# %%
import glob
import os
import shutil

import pandas as pd
import scanpy as sc
import sig_utils
from joblib import Parallel, delayed
from tqdm import tqdm

import create_sourmash_command_utils as csc_utils

import sig_reorg

pd.options.display.max_rows = 500

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Def Describe

# %%
# %%file pandas_utils.py

def describe(df, random=False):
    print(df.shape)
    print("--- First 5 entries ---")
    display(df.head())
    if random:
        print('--- Random subset ---')
        display(df.sample(5))
# Out:
# Overwriting pandas_utils.py

# %%
from pandas_utils import describe

# %% [markdown]
# ## Read one2one h5ad

# %%
adata = sc.read(
#     "/home/phoenix/data_lg/data_sm_copy/code/immune-evolution/h5ads/human-lemur-mouse-bat__lung_only_copy.h5ad"
    "/home/olga/data_lg/data_sm_copy/immune-evolution/h5ads/human-lemur-mouse-bat/human-lemur-mouse-bat__lung_only.h5ad"
)
adata.obs = adata.obs.reset_index().set_index('cell_id')
print(adata)
adata.obs.head()
# Out:
# AnnData object with n_obs × n_vars = 126745 × 10560
#     obs: 'index', 'age', 'cell_barcode', 'cell_ontology_class', 'cell_ontology_id', 'channel', 'free_annotation', 'individual', 'sample', 'sequencing_run', 'sex', 'species', 'species_batch', 'species_latin', 'tissue', 'narrow_group', 'broad_group', 'compartment_group', 'compartment_narrow', 'channel_cleaned', 'batch', 'n_genes', 'n_counts', 'species_batch_v2', 'compartment_broad', 'compartment_broad_narrow', 'compartment_species', 'compartment_narrow_species', 'common_individual_id'
#     var: 'bat__gene_name', 'mouse_lemur__gene_name-bat', 'mouse__gene_name-bat', 'mouse_lemur__gene_name_x-hlm', 'mouse__gene_name_x-hlm', 'gene_ids-lemur-hlm', 'n_cells-mouse-hlm', 'mouse_lemur__gene_name_y-hlm', 'mouse__gene_name_y-hlm'
#                                                   index  age  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  P2_1_AAACCTGAGAAACCAT-human-hlm  46y
# P2_1__AAATGCCAGATGAGAG  P2_1_AAATGCCAGATGAGAG-human-hlm  46y
# P2_1__AACACGTTCGATCCCT  P2_1_AACACGTTCGATCCCT-human-hlm  46y
# P2_1__AACACGTTCGCACTCT  P2_1_AACACGTTCGCACTCT-human-hlm  46y
# P2_1__AACCATGCAGCTCGCA  P2_1_AACCATGCAGCTCGCA-human-hlm  46y
#
#                             cell_barcode         cell_ontology_class  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  AAACCTGAGAAACCAT  capillary endothelial cell
# P2_1__AAATGCCAGATGAGAG  AAATGCCAGATGAGAG  capillary endothelial cell
# P2_1__AACACGTTCGATCCCT  AACACGTTCGATCCCT  capillary endothelial cell
# P2_1__AACACGTTCGCACTCT  AACACGTTCGCACTCT  capillary endothelial cell
# P2_1__AACCATGCAGCTCGCA  AACCATGCAGCTCGCA  capillary endothelial cell
#
#                        cell_ontology_id channel     free_annotation  \
# cell_id
# P2_1__AAACCTGAGAAACCAT              nan    P2_1  Capillary Aerocyte
# P2_1__AAATGCCAGATGAGAG              nan    P2_1  Capillary Aerocyte
# P2_1__AACACGTTCGATCCCT              nan    P2_1  Capillary Aerocyte
# P2_1__AACACGTTCGCACTCT              nan    P2_1  Capillary Aerocyte
# P2_1__AACCATGCAGCTCGCA              nan    P2_1  Capillary Aerocyte
#
#                        individual    sample                 sequencing_run  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
# P2_1__AAATGCCAGATGAGAG  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
# P2_1__AACACGTTCGATCCCT  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
# P2_1__AACACGTTCGCACTCT  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
# P2_1__AACCATGCAGCTCGCA  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
#
#                         ... channel_cleaned batch n_genes n_counts  \
# cell_id                 ...
# P2_1__AAACCTGAGAAACCAT  ...            P2_1   NaN     NaN      NaN
# P2_1__AAATGCCAGATGAGAG  ...            P2_1   NaN     NaN      NaN
# P2_1__AACACGTTCGATCCCT  ...            P2_1   NaN     NaN      NaN
# P2_1__AACACGTTCGCACTCT  ...            P2_1   NaN     NaN      NaN
# P2_1__AACCATGCAGCTCGCA  ...            P2_1   NaN     NaN      NaN
#
#                        species_batch_v2       compartment_broad  \
# cell_id
# P2_1__AAACCTGAGAAACCAT              hlm  endothelial: Capillary
# P2_1__AAATGCCAGATGAGAG              hlm  endothelial: Capillary
# P2_1__AACACGTTCGATCCCT              hlm  endothelial: Capillary
# P2_1__AACACGTTCGCACTCT              hlm  endothelial: Capillary
# P2_1__AACCATGCAGCTCGCA              hlm  endothelial: Capillary
#
#                                           compartment_broad_narrow  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  endothelial: Capillary: Capillary Aerocyte
# P2_1__AAATGCCAGATGAGAG  endothelial: Capillary: Capillary Aerocyte
# P2_1__AACACGTTCGATCCCT  endothelial: Capillary: Capillary Aerocyte
# P2_1__AACACGTTCGCACTCT  endothelial: Capillary: Capillary Aerocyte
# P2_1__AACCATGCAGCTCGCA  endothelial: Capillary: Capillary Aerocyte
#
#                        compartment_species  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  endothelial: human
# P2_1__AAATGCCAGATGAGAG  endothelial: human
# P2_1__AACACGTTCGATCCCT  endothelial: human
# P2_1__AACACGTTCGCACTCT  endothelial: human
# P2_1__AACCATGCAGCTCGCA  endothelial: human
#
#                                     compartment_narrow_species  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  endothelial: Capillary Aerocyte: human
# P2_1__AAATGCCAGATGAGAG  endothelial: Capillary Aerocyte: human
# P2_1__AACACGTTCGATCCCT  endothelial: Capillary Aerocyte: human
# P2_1__AACACGTTCGCACTCT  endothelial: Capillary Aerocyte: human
# P2_1__AACCATGCAGCTCGCA  endothelial: Capillary Aerocyte: human
#
#                        common_individual_id
# cell_id
# P2_1__AAACCTGAGAAACCAT      human_patient_2
# P2_1__AAATGCCAGATGAGAG      human_patient_2
# P2_1__AACACGTTCGATCCCT      human_patient_2
# P2_1__AACACGTTCGCACTCT      human_patient_2
# P2_1__AACCATGCAGCTCGCA      human_patient_2
#
# [5 rows x 29 columns]

# %%
adata.obs.species.value_counts()
# Out:
# Human          57353
# Mouse lemur    36934
# Mouse          23802
# Bat             8656
# Name: species, dtype: int64

# %%
adata.obs.query('species == "Mouse"').groupby(["age", "channel"], observed=True).size()
# Out:
# age  channel
# 18m  MACA_18m_F_LUNG_50     320
#      MACA_18m_F_LUNG_51    1138
#      MACA_18m_M_LUNG_52    1573
#      MACA_18m_M_LUNG_53    1256
# 21m  MACA_21m_F_LUNG_54    1312
#      MACA_21m_F_LUNG_55    1526
# 30m  10X_P1_6              7728
#      10X_P1_14             1565
#      10X_P2_5               920
#      10X_P3_0               496
# 1m   10X_P5_13             1043
#      10X_P5_14             1384
# 3m   10X_P7_8               348
#      10X_P7_9               979
#      10X_P8_12              578
#      10X_P8_13             1636
# dtype: int64

# %% [markdown]
# ## Set shared celltypes

# %%
SHARED_CELLTYPES = ['Alveolar Epithelial Type 2',
 'B cell',
 'Capillary',
 'Dendritic',
 'Fibroblast',
 'Macrophage',
 'Monocyte',
 'Natural Killer T cell',
 'Smooth Muscle and Myofibroblast',
 'T cell']
len(SHARED_CELLTYPES)

adata_shared = adata[adata.obs.broad_group.isin(SHARED_CELLTYPES)]
adata_shared
# Out:
# /home/olga/miniconda3/envs/immune-evolution/lib/python3.7/site-packages/anndata/_core/anndata.py:1094: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if not is_categorical(df_full[k]):
# View of AnnData object with n_obs × n_vars = 89795 × 10560
#     obs: 'index', 'age', 'cell_barcode', 'cell_ontology_class', 'cell_ontology_id', 'channel', 'free_annotation', 'individual', 'sample', 'sequencing_run', 'sex', 'species', 'species_batch', 'species_latin', 'tissue', 'narrow_group', 'broad_group', 'compartment_group', 'compartment_narrow', 'channel_cleaned', 'batch', 'n_genes', 'n_counts', 'species_batch_v2', 'compartment_broad', 'compartment_broad_narrow', 'compartment_species', 'compartment_narrow_species', 'common_individual_id'
#     var: 'bat__gene_name', 'mouse_lemur__gene_name-bat', 'mouse__gene_name-bat', 'mouse_lemur__gene_name_x-hlm', 'mouse__gene_name_x-hlm', 'gene_ids-lemur-hlm', 'n_cells-mouse-hlm', 'mouse_lemur__gene_name_y-hlm', 'mouse__gene_name_y-hlm'

# %%
CELL_IDS_TO_USE = set(adata_shared.obs.query('species == "Mouse lemur"').index)
len(CELL_IDS_TO_USE)
# Out:
# 19088

# %%
sorted(adata_shared.obs.query('species == "Mouse lemur"').channel.unique())
# Out:
# ['Antoine_Lung_CD31_10X',
#  'Antoine_Lung_EPCAM_10X',
#  'Antoine_Lung_P3_10X',
#  'Bernard_Lung_10X',
#  'Martine_Lung_1_10X',
#  'Martine_Lung_2_10X',
#  'Stumpy_Lung_10X']

# %%
adata_shared.obs.query('species == "Mouse lemur" and channel == "Antoine_Lung_P3_10X"').head()
# Out:
#                                                                             index  \
# cell_id
# ANTOINE_LUNG_P3__AAACCTGAGCTTCGCG  Antoine_Lung_P3_10X_AAACCTGAGCTTCGCG-lemur-hlm
# ANTOINE_LUNG_P3__AAACCTGAGTCAATAG  Antoine_Lung_P3_10X_AAACCTGAGTCAATAG-lemur-hlm
# ANTOINE_LUNG_P3__AAACCTGCACCGATAT  Antoine_Lung_P3_10X_AAACCTGCACCGATAT-lemur-hlm
# ANTOINE_LUNG_P3__AAACCTGCAGGTGCCT  Antoine_Lung_P3_10X_AAACCTGCAGGTGCCT-lemur-hlm
# ANTOINE_LUNG_P3__AAACCTGCATGTAGTC  Antoine_Lung_P3_10X_AAACCTGCATGTAGTC-lemur-hlm
#
#                                    age      cell_barcode  \
# cell_id
# ANTOINE_LUNG_P3__AAACCTGAGCTTCGCG  12y  AAACCTGAGCTTCGCG
# ANTOINE_LUNG_P3__AAACCTGAGTCAATAG  12y  AAACCTGAGTCAATAG
# ANTOINE_LUNG_P3__AAACCTGCACCGATAT  12y  AAACCTGCACCGATAT
# ANTOINE_LUNG_P3__AAACCTGCAGGTGCCT  12y  AAACCTGCAGGTGCCT
# ANTOINE_LUNG_P3__AAACCTGCATGTAGTC  12y  AAACCTGCATGTAGTC
#
#                                                cell_ontology_class  \
# cell_id
# ANTOINE_LUNG_P3__AAACCTGAGCTTCGCG       capillary endothelial cell
# ANTOINE_LUNG_P3__AAACCTGAGTCAATAG  CD4-positive, alpha-beta T cell
# ANTOINE_LUNG_P3__AAACCTGCACCGATAT                           T cell
# ANTOINE_LUNG_P3__AAACCTGCAGGTGCCT                           T cell
# ANTOINE_LUNG_P3__AAACCTGCATGTAGTC                       fibroblast
#
#                                   cell_ontology_id              channel  \
# cell_id
# ANTOINE_LUNG_P3__AAACCTGAGCTTCGCG       CL:0002144  Antoine_Lung_P3_10X
# ANTOINE_LUNG_P3__AAACCTGAGTCAATAG       CL:0000624  Antoine_Lung_P3_10X
# ANTOINE_LUNG_P3__AAACCTGCACCGATAT       CL:0000084  Antoine_Lung_P3_10X
# ANTOINE_LUNG_P3__AAACCTGCAGGTGCCT       CL:0000084  Antoine_Lung_P3_10X
# ANTOINE_LUNG_P3__AAACCTGCATGTAGTC       CL:0000057  Antoine_Lung_P3_10X
#
#                                                 free_annotation individual  \
# cell_id
# ANTOINE_LUNG_P3__AAACCTGAGCTTCGCG      capillary cells (type 2)    Antoine
# ANTOINE_LUNG_P3__AAACCTGAGTCAATAG  t cells (CD4+low CD8- IL7R+)    Antoine
# ANTOINE_LUNG_P3__AAACCTGCACCGATAT           t cells (CD4+ CD8+)    Antoine
# ANTOINE_LUNG_P3__AAACCTGCAGGTGCCT           t cells (CD4+ CD8+)    Antoine
# ANTOINE_LUNG_P3__AAACCTGCATGTAGTC        fibroblasts (alveolar)    Antoine
#
#                                   sample                 sequencing_run  ...  \
# cell_id                                                                  ...
# ANTOINE_LUNG_P3__AAACCTGAGCTTCGCG    nan  180917_A00111_0211_AHGKCVDMXX  ...
# ANTOINE_LUNG_P3__AAACCTGAGTCAATAG    nan  180917_A00111_0211_AHGKCVDMXX  ...
# ANTOINE_LUNG_P3__AAACCTGCACCGATAT    nan  180917_A00111_0211_AHGKCVDMXX  ...
# ANTOINE_LUNG_P3__AAACCTGCAGGTGCCT    nan  180917_A00111_0211_AHGKCVDMXX  ...
# ANTOINE_LUNG_P3__AAACCTGCATGTAGTC    nan  180917_A00111_0211_AHGKCVDMXX  ...
#
#                                    channel_cleaned batch n_genes n_counts  \
# cell_id
# ANTOINE_LUNG_P3__AAACCTGAGCTTCGCG  ANTOINE_LUNG_P3   NaN     NaN      NaN
# ANTOINE_LUNG_P3__AAACCTGAGTCAATAG  ANTOINE_LUNG_P3   NaN     NaN      NaN
# ANTOINE_LUNG_P3__AAACCTGCACCGATAT  ANTOINE_LUNG_P3   NaN     NaN      NaN
# ANTOINE_LUNG_P3__AAACCTGCAGGTGCCT  ANTOINE_LUNG_P3   NaN     NaN      NaN
# ANTOINE_LUNG_P3__AAACCTGCATGTAGTC  ANTOINE_LUNG_P3   NaN     NaN      NaN
#
#                                   species_batch_v2       compartment_broad  \
# cell_id
# ANTOINE_LUNG_P3__AAACCTGAGCTTCGCG              hlm  endothelial: Capillary
# ANTOINE_LUNG_P3__AAACCTGAGTCAATAG              hlm        lymphoid: T cell
# ANTOINE_LUNG_P3__AAACCTGCACCGATAT              hlm        lymphoid: T cell
# ANTOINE_LUNG_P3__AAACCTGCAGGTGCCT              hlm        lymphoid: T cell
# ANTOINE_LUNG_P3__AAACCTGCATGTAGTC              hlm     stromal: Fibroblast
#
#                                                    compartment_broad_narrow  \
# cell_id
# ANTOINE_LUNG_P3__AAACCTGAGCTTCGCG         endothelial: Capillary: Capillary
# ANTOINE_LUNG_P3__AAACCTGAGTCAATAG                  lymphoid: T cell: CD4+ T
# ANTOINE_LUNG_P3__AAACCTGCACCGATAT             lymphoid: T cell: CD4+ CD8+ T
# ANTOINE_LUNG_P3__AAACCTGCAGGTGCCT             lymphoid: T cell: CD4+ CD8+ T
# ANTOINE_LUNG_P3__AAACCTGCATGTAGTC  stromal: Fibroblast: Alveolar Fibroblast
#
#                                   compartment_species  \
# cell_id
# ANTOINE_LUNG_P3__AAACCTGAGCTTCGCG  endothelial: lemur
# ANTOINE_LUNG_P3__AAACCTGAGTCAATAG     lymphoid: lemur
# ANTOINE_LUNG_P3__AAACCTGCACCGATAT     lymphoid: lemur
# ANTOINE_LUNG_P3__AAACCTGCAGGTGCCT     lymphoid: lemur
# ANTOINE_LUNG_P3__AAACCTGCATGTAGTC      stromal: lemur
#
#                                             compartment_narrow_species  \
# cell_id
# ANTOINE_LUNG_P3__AAACCTGAGCTTCGCG        endothelial: Capillary: lemur
# ANTOINE_LUNG_P3__AAACCTGAGTCAATAG              lymphoid: CD4+ T: lemur
# ANTOINE_LUNG_P3__AAACCTGCACCGATAT         lymphoid: CD4+ CD8+ T: lemur
# ANTOINE_LUNG_P3__AAACCTGCAGGTGCCT         lymphoid: CD4+ CD8+ T: lemur
# ANTOINE_LUNG_P3__AAACCTGCATGTAGTC  stromal: Alveolar Fibroblast: lemur
#
#                                   common_individual_id
# cell_id
# ANTOINE_LUNG_P3__AAACCTGAGCTTCGCG        lemur_Antoine
# ANTOINE_LUNG_P3__AAACCTGAGTCAATAG        lemur_Antoine
# ANTOINE_LUNG_P3__AAACCTGCACCGATAT        lemur_Antoine
# ANTOINE_LUNG_P3__AAACCTGCAGGTGCCT        lemur_Antoine
# ANTOINE_LUNG_P3__AAACCTGCATGTAGTC        lemur_Antoine
#
# [5 rows x 29 columns]

# %% [markdown]
# # Lemur

# %% [markdown]
# ## Single cell fastas

# %%
lemur_kmermaid_base = "/home/olga/data_lg/data_sm_copy/tabula-microcebus/analyses/kmermaid/tenx-tgz--alldata-v2-from-bams--remove-ribo"

# %%
ls -lha $lemur_kmermaid_base
# Out:
# total 29M
# drwxr-xr-x 15 olga czb 4.0K Mar  1 15:38 ./
# drwxrwxrwx 26 olga czb 4.0K Oct 16  2020 ../
# drwxr-xr-x  5 olga czb 4.0K Oct  9  2020 10x-fastqs/
# drwxr-xr-x  4 olga czb 4.0K Oct  9  2020 fastp/
# drwxr-xr-x  2 olga czb 4.0K Oct 18  2020 pipeline_info/
# drwxr-xr-x  2 olga czb 4.0K Oct 12  2020 protein_index/
# drwxr-xr-x  7 olga czb 4.0K Mar  1 15:38 search_lemur_in_mouse_no_ribosome_no_containment_no_dissociation__remove_common_hashes_from_mouse_sbt__refseq_removed_ribo/
# drwxr-xr-x  2 olga czb 8.0M Apr 20 10:19 sketches_nucleotide_handmade/
# drwxr-xr-x  3 olga czb 4.0K Apr 25 17:46 sketches_nucleotide_handmade_merged/
# drwxr-xr-x  3 olga czb 4.0K Apr 29 13:15 sketches_nucleotide_handmade_merged_remove_ribosomal_dissociation_allcells/
# drwxr-xr-x  2 olga czb 4.0M Feb 28 19:56 sketches_peptide_handmade/
# drwxr-xr-x  6 olga czb 4.0K Apr 26 11:24 sketches_peptide_handmade_merged/
# drwxr-xr-x  6 olga czb 4.0K Apr 26 16:52 sketches_peptide_handmade_merged_remove_ribosomal_dissociation_allcells/
# drwxr-xr-x  4 olga czb 4.0K Oct  9  2020 SortMeRNA/
# drwxr-xr-x  2 olga czb  16M Oct 18  2020 translate/

# %%
sig_outdir_base = "/home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures"

test_dir = os.path.join(sig_outdir_base, "4--test-lemur")

test_0_fastas = os.path.join(test_dir, "0--fastas")
# ! rm -rf $test_0_fastas
test_1_single_cells = os.path.join(test_dir, "1--single-cell-sigs")
# ! rm -rf $test_1_single_cells
fasta_input_dir = os.path.join(lemur_kmermaid_base, "translate")

results_dir = os.path.join(test_dir, "2--mouse-search-results")
dirs = (test_0_fastas, test_1_single_cells, results_dir)

for outdir in dirs:
    if not os.path.exists(outdir):
        os.makedirs(outdir)

# %%
ls -lha $fasta_input_dir/ |tail
# Out:
# -rw-r--r--  1 olga czb   99K Oct 12  2020 ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__TTTGTCATCTTCGGTC__coding_reads_nucleotides.fasta
# -rw-r--r--  1 olga czb   77K Oct 12  2020 ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__TTTGTCATCTTCGGTC__coding_reads_peptides.fasta
# -rw-r--r--  1 olga czb  1.5M Oct 12  2020 ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__TTTGTCATCTTCGGTC__coding_scores.csv
# -rw-r--r--  1 olga czb  1.7K Oct 12  2020 ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__TTTGTCATCTTCGGTC__coding_summary.json
# -rw-r--r--  1 olga czb  410K Oct 12  2020 ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__TTTGTCATCTTCGGTC__noncoding_reads_nucleotides.fasta
# -rw-r--r--  1 olga czb  105K Oct 12  2020 ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__TTTGTCATCTTTACGT__coding_reads_nucleotides.fasta
# -rw-r--r--  1 olga czb   81K Oct 12  2020 ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__TTTGTCATCTTTACGT__coding_reads_peptides.fasta
# -rw-r--r--  1 olga czb  1.2M Oct 12  2020 ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__TTTGTCATCTTTACGT__coding_scores.csv
# -rw-r--r--  1 olga czb  1.8K Oct 12  2020 ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__TTTGTCATCTTTACGT__coding_summary.json
# -rw-r--r--  1 olga czb  322K Oct 12  2020 ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__TTTGTCATCTTTACGT__noncoding_reads_nucleotides.fasta

# %% [markdown]
# ## Copy fastas

# %%
def clean_fasta_name(basename, strings_to_remove=["__aligned", '__possorted_genome_bam', '_possorted_genome_bam', '__unaligned']):
    new_name = None
    for to_remove in strings_to_remove:
        if new_name is None:
            # First time --> take original basename
            new_name = basename.replace(to_remove, '')
        else:
            new_name = new_name.replace(to_remove, '')
            
    new_name = new_name.split('_coding_reads')[0].strip("_")
    return new_name

# %%
sig_reorg.copy_fastas(
    test_0_fastas,
    fasta_input_dir,
    select_cell_ids=CELL_IDS_TO_USE,
    dryrun=False,
    cell_id_fun=clean_fasta_name,
)
# Out:
# 0it [00:00, ?it/s]
# Copying peptides
# 19896it [00:01, 17227.27it/s]
# 0it [00:00, ?it/s]
# Copying nucleotides
# 19896it [00:01, 15871.65it/s]

# %%
# !ls -lha $test_0_fastas/nucleotides | head
# Out:
# total 4.9G
# drwxr-xr-x 2 olga czb 256K Apr 16 17:47 .
# drwxr-xr-x 4 olga czb 4.0K Apr 16 17:43 ..
# -rw-r--r-- 1 olga czb 4.9M Apr 16 17:45 ANTOINE_LUNG_P3__possorted_genome_bam__aligned__aligned__AAACGGGGTAAGTGTA__coding_reads_nucleotides.fasta
# -rw-r--r-- 1 olga czb 3.2M Apr 16 17:46 ANTOINE_LUNG_P3__possorted_genome_bam__aligned__aligned__AAACGGGGTTTCCACC__coding_reads_nucleotides.fasta
# -rw-r--r-- 1 olga czb 5.1M Apr 16 17:45 ANTOINE_LUNG_P3__possorted_genome_bam__aligned__aligned__AAAGCAAAGACCTTTG__coding_reads_nucleotides.fasta
# -rw-r--r-- 1 olga czb 3.1M Apr 16 17:45 ANTOINE_LUNG_P3__possorted_genome_bam__aligned__aligned__AAAGCAAAGCTGCCCA__coding_reads_nucleotides.fasta
# -rw-r--r-- 1 olga czb 6.7M Apr 16 17:44 ANTOINE_LUNG_P3__possorted_genome_bam__aligned__aligned__AAAGCAACATGTCCTC__coding_reads_nucleotides.fasta
# -rw-r--r-- 1 olga czb 3.2M Apr 16 17:45 ANTOINE_LUNG_P3__possorted_genome_bam__aligned__aligned__AAAGCAATCGTTTAGG__coding_reads_nucleotides.fasta
# -rw-r--r-- 1 olga czb 4.2M Apr 16 17:44 ANTOINE_LUNG_P3__possorted_genome_bam__aligned__aligned__AAAGTAGGTATATCCG__coding_reads_nucleotides.fasta
# ls: write error: Broken pipe

# %%
# !ls -lha $test_0_fastas/nucleotides | wc -l
# Out:
# 1967

# %%
n = 0

for filename in glob.iglob(os.path.join(test_0_fastas, '*', '*.fasta')):
    if "P3" in filename and n < 10:
        n += 1
        print(filename)
#         break
# Out:
# /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/0--fastas/nucleotides/ANTOINE_LUNG_P3__possorted_genome_bam__aligned__aligned__AATCGGTCACGGCTAC__coding_reads_nucleotides.fasta
# /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/0--fastas/nucleotides/ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__CATGGCGCAGATCCAT__coding_reads_nucleotides.fasta
# /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/0--fastas/nucleotides/ANTOINE_LUNG_P3__possorted_genome_bam__aligned__aligned__GTTCATTTCCTTGACC__coding_reads_nucleotides.fasta
# /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/0--fastas/nucleotides/ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__CCCAATCTCATCGATG__coding_reads_nucleotides.fasta
# /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/0--fastas/nucleotides/ANTOINE_LUNG_P3__possorted_genome_bam__aligned__aligned__TGCTACCAGAATTGTG__coding_reads_nucleotides.fasta
# /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/0--fastas/nucleotides/ANTOINE_LUNG_P3__possorted_genome_bam__aligned__aligned__GCTTGAATCTATCCTA__coding_reads_nucleotides.fasta
# /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/0--fastas/nucleotides/ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__AAAGCAAAGACCTTTG__coding_reads_nucleotides.fasta
# /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/0--fastas/nucleotides/ANTOINE_LUNG_P3__possorted_genome_bam__aligned__aligned__CAGCTAAAGATCCGAG__coding_reads_nucleotides.fasta
# /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/0--fastas/nucleotides/ANTOINE_LUNG_P3__possorted_genome_bam__unaligned__unaligned__AACTCCCTCCCAGGTG__coding_reads_nucleotides.fasta
# /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/0--fastas/nucleotides/ANTOINE_LUNG_P3__possorted_genome_bam__aligned__aligned__TGGGAAGTCATGTCTT__coding_reads_nucleotides.fasta

# %% [markdown]
# ## Single cell signatures

# %%
peptide_sketch_dir = os.path.join(
    lemur_kmermaid_base,
    "sketches_peptide_handmade_merged_remove_ribosomal_dissociation_allcells",
)

nucleotide_sketch_dir = os.path.join(
    lemur_kmermaid_base,
    "sketches_nucleotide_handmade_merged_remove_ribosomal_dissociation_allcells",
)

sig_reorg.copy_nucleotide_peptide_sketches(
    peptide_sketch_dir=peptide_sketch_dir,
    nucleotide_sketch_dir=nucleotide_sketch_dir,
    pre_sketch_id_outdir=test_1_single_cells,
    select_cell_ids=CELL_IDS_TO_USE,
    dryrun=False,
    # Remove all reference to "_POS" in the channel to match downstream work
    cell_id_fun=lambda x: x.replace('_POS', '')
)
# Out:
# Copying alphabet-DNA__ksize-21__scaled-10
# 5695it [03:30, 27.03it/s]
# 20it [00:00, 196.09it/s]
# Copying alphabet-protein__ksize-30__scaled-10
# 5695it [00:13, 422.00it/s]
# 0it [00:00, ?it/s]
# Copying alphabet-dayhoff__ksize-51__scaled-10
# 5695it [00:13, 421.96it/s]

# %%
# !ls -lha $test_1_single_cells
# Out:
# total 1.6M
# drwxr-xr-x  5 olga czb 4.0K Apr 29 13:55 .
# drwxr-xr-x 22 olga czb 4.0K Apr 21 09:49 ..
# drwxr-xr-x  2 olga czb 512K Apr 29 13:57 alphabet-dayhoff__ksize-51__scaled-10
# drwxr-xr-x  2 olga czb 512K Apr 29 13:51 alphabet-DNA__ksize-21__scaled-10
# drwxr-xr-x  2 olga czb 512K Apr 29 13:55 alphabet-protein__ksize-30__scaled-10
# -rw-r--r--  1 olga czb    0 Apr 16 18:10 sig_describe_commands.txt

# %%
# ! rm -rf $test_1_single_cells/alphabet*

# %%
! ls -lha $test_1_single_cells/alphabet-dayhoff__ksize-51__scaled-10 | head
# Out:
# total 913M
# drwxr-xr-x 2 olga czb 512K Apr 29 13:57 .
# drwxr-xr-x 5 olga czb 4.0K Apr 29 13:55 ..
# -rw-r--r-- 1 olga czb 162K Apr 29 13:55 ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG.sig
# -rw-r--r-- 1 olga czb 179K Apr 29 13:55 ANTOINE_LUNG_CD31__AAACCTGAGGCAGTCA.sig
# -rw-r--r-- 1 olga czb 216K Apr 29 13:57 ANTOINE_LUNG_CD31__AAACCTGAGGGTGTGT.sig
# -rw-r--r-- 1 olga czb 216K Apr 29 13:56 ANTOINE_LUNG_CD31__AAACCTGGTATATGGA.sig
# -rw-r--r-- 1 olga czb 219K Apr 29 13:56 ANTOINE_LUNG_CD31__AAACCTGTCCGTCATC.sig
# -rw-r--r-- 1 olga czb  95K Apr 29 13:57 ANTOINE_LUNG_CD31__AAACCTGTCGAGAGCA.sig
# -rw-r--r-- 1 olga czb 184K Apr 29 13:55 ANTOINE_LUNG_CD31__AAACCTGTCGGAGCAA.sig
# ls: write error: Broken pipe

# %%
! ls -lha $test_1_single_cells/alphabet-DNA__ksize-21__scaled-10 | head
# Out:
# total 2.5G
# drwxr-xr-x 2 olga czb  512K Apr 29 13:51 .
# drwxr-xr-x 5 olga czb  4.0K Apr 29 13:55 ..
# -rw-r--r-- 1 olga czb  579K Apr 29 13:49 ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG.sig
# -rw-r--r-- 1 olga czb  661K Apr 29 13:49 ANTOINE_LUNG_CD31__AAACCTGAGGCAGTCA.sig
# -rw-r--r-- 1 olga czb  768K Apr 29 13:51 ANTOINE_LUNG_CD31__AAACCTGAGGGTGTGT.sig
# -rw-r--r-- 1 olga czb  772K Apr 29 13:50 ANTOINE_LUNG_CD31__AAACCTGGTATATGGA.sig
# -rw-r--r-- 1 olga czb  773K Apr 29 13:50 ANTOINE_LUNG_CD31__AAACCTGTCCGTCATC.sig
# -rw-r--r-- 1 olga czb  352K Apr 29 13:51 ANTOINE_LUNG_CD31__AAACCTGTCGAGAGCA.sig
# -rw-r--r-- 1 olga czb  656K Apr 29 13:50 ANTOINE_LUNG_CD31__AAACCTGTCGGAGCAA.sig
# ls: write error: Broken pipe

# %%
adata_shared.obs.head()
# Out:
#                                                   index  age  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  P2_1_AAACCTGAGAAACCAT-human-hlm  46y
# P2_1__AAATGCCAGATGAGAG  P2_1_AAATGCCAGATGAGAG-human-hlm  46y
# P2_1__AACACGTTCGATCCCT  P2_1_AACACGTTCGATCCCT-human-hlm  46y
# P2_1__AACACGTTCGCACTCT  P2_1_AACACGTTCGCACTCT-human-hlm  46y
# P2_1__AACCATGCAGCTCGCA  P2_1_AACCATGCAGCTCGCA-human-hlm  46y
#
#                             cell_barcode         cell_ontology_class  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  AAACCTGAGAAACCAT  capillary endothelial cell
# P2_1__AAATGCCAGATGAGAG  AAATGCCAGATGAGAG  capillary endothelial cell
# P2_1__AACACGTTCGATCCCT  AACACGTTCGATCCCT  capillary endothelial cell
# P2_1__AACACGTTCGCACTCT  AACACGTTCGCACTCT  capillary endothelial cell
# P2_1__AACCATGCAGCTCGCA  AACCATGCAGCTCGCA  capillary endothelial cell
#
#                        cell_ontology_id channel     free_annotation  \
# cell_id
# P2_1__AAACCTGAGAAACCAT              nan    P2_1  Capillary Aerocyte
# P2_1__AAATGCCAGATGAGAG              nan    P2_1  Capillary Aerocyte
# P2_1__AACACGTTCGATCCCT              nan    P2_1  Capillary Aerocyte
# P2_1__AACACGTTCGCACTCT              nan    P2_1  Capillary Aerocyte
# P2_1__AACCATGCAGCTCGCA              nan    P2_1  Capillary Aerocyte
#
#                        individual    sample                 sequencing_run  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
# P2_1__AAATGCCAGATGAGAG  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
# P2_1__AACACGTTCGATCCCT  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
# P2_1__AACACGTTCGCACTCT  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
# P2_1__AACCATGCAGCTCGCA  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
#
#                         ... channel_cleaned batch n_genes n_counts  \
# cell_id                 ...
# P2_1__AAACCTGAGAAACCAT  ...            P2_1   NaN     NaN      NaN
# P2_1__AAATGCCAGATGAGAG  ...            P2_1   NaN     NaN      NaN
# P2_1__AACACGTTCGATCCCT  ...            P2_1   NaN     NaN      NaN
# P2_1__AACACGTTCGCACTCT  ...            P2_1   NaN     NaN      NaN
# P2_1__AACCATGCAGCTCGCA  ...            P2_1   NaN     NaN      NaN
#
#                        species_batch_v2       compartment_broad  \
# cell_id
# P2_1__AAACCTGAGAAACCAT              hlm  endothelial: Capillary
# P2_1__AAATGCCAGATGAGAG              hlm  endothelial: Capillary
# P2_1__AACACGTTCGATCCCT              hlm  endothelial: Capillary
# P2_1__AACACGTTCGCACTCT              hlm  endothelial: Capillary
# P2_1__AACCATGCAGCTCGCA              hlm  endothelial: Capillary
#
#                                           compartment_broad_narrow  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  endothelial: Capillary: Capillary Aerocyte
# P2_1__AAATGCCAGATGAGAG  endothelial: Capillary: Capillary Aerocyte
# P2_1__AACACGTTCGATCCCT  endothelial: Capillary: Capillary Aerocyte
# P2_1__AACACGTTCGCACTCT  endothelial: Capillary: Capillary Aerocyte
# P2_1__AACCATGCAGCTCGCA  endothelial: Capillary: Capillary Aerocyte
#
#                        compartment_species  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  endothelial: human
# P2_1__AAATGCCAGATGAGAG  endothelial: human
# P2_1__AACACGTTCGATCCCT  endothelial: human
# P2_1__AACACGTTCGCACTCT  endothelial: human
# P2_1__AACCATGCAGCTCGCA  endothelial: human
#
#                                     compartment_narrow_species  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  endothelial: Capillary Aerocyte: human
# P2_1__AAATGCCAGATGAGAG  endothelial: Capillary Aerocyte: human
# P2_1__AACACGTTCGATCCCT  endothelial: Capillary Aerocyte: human
# P2_1__AACACGTTCGCACTCT  endothelial: Capillary Aerocyte: human
# P2_1__AACCATGCAGCTCGCA  endothelial: Capillary Aerocyte: human
#
#                        common_individual_id
# cell_id
# P2_1__AAACCTGAGAAACCAT      human_patient_2
# P2_1__AAATGCCAGATGAGAG      human_patient_2
# P2_1__AACACGTTCGATCCCT      human_patient_2
# P2_1__AACACGTTCGCACTCT      human_patient_2
# P2_1__AACCATGCAGCTCGCA      human_patient_2
#
# [5 rows x 29 columns]

# %%
lemur_obs = adata_shared.obs.query('species == "Mouse lemur"')
lemur_obs.broad_group.value_counts()
# Out:
# Macrophage                         6921
# T cell                             4105
# Monocyte                           2644
# Capillary                          2136
# Fibroblast                         1271
# Alveolar Epithelial Type 2          804
# Natural Killer T cell               446
# B cell                              358
# Dendritic                           316
# Smooth Muscle and Myofibroblast      87
# Name: broad_group, dtype: int64

# %%
lemur_obs.groupby(['broad_group', 'channel'], observed=True).size()
# Out:
# broad_group                      channel
# Macrophage                       Antoine_Lung_CD31_10X     3055
#                                  Antoine_Lung_EPCAM_10X     911
#                                  Antoine_Lung_P3_10X         20
#                                  Bernard_Lung_10X          1198
#                                  Martine_Lung_1_10X         224
#                                  Martine_Lung_2_10X         205
#                                  Stumpy_Lung_10X           1308
# Alveolar Epithelial Type 2       Antoine_Lung_CD31_10X      329
#                                  Antoine_Lung_EPCAM_10X     197
#                                  Antoine_Lung_P3_10X         22
#                                  Bernard_Lung_10X            89
#                                  Stumpy_Lung_10X            167
# T cell                           Antoine_Lung_CD31_10X      880
#                                  Antoine_Lung_EPCAM_10X      13
#                                  Antoine_Lung_P3_10X       1790
#                                  Bernard_Lung_10X           372
#                                  Martine_Lung_1_10X         465
#                                  Martine_Lung_2_10X         527
#                                  Stumpy_Lung_10X             58
# Capillary                        Antoine_Lung_CD31_10X      762
#                                  Antoine_Lung_EPCAM_10X     161
#                                  Antoine_Lung_P3_10X       1213
# Natural Killer T cell            Antoine_Lung_CD31_10X      146
#                                  Antoine_Lung_EPCAM_10X       3
#                                  Antoine_Lung_P3_10X        297
# Fibroblast                       Antoine_Lung_CD31_10X      419
#                                  Antoine_Lung_EPCAM_10X      27
#                                  Antoine_Lung_P3_10X        669
#                                  Bernard_Lung_10X            45
#                                  Martine_Lung_1_10X          60
#                                  Martine_Lung_2_10X          51
# B cell                           Antoine_Lung_CD31_10X       79
#                                  Antoine_Lung_EPCAM_10X       9
#                                  Antoine_Lung_P3_10X        112
#                                  Bernard_Lung_10X            35
#                                  Martine_Lung_1_10X          70
#                                  Martine_Lung_2_10X          53
# Dendritic                        Antoine_Lung_CD31_10X       94
#                                  Antoine_Lung_EPCAM_10X      18
#                                  Antoine_Lung_P3_10X        168
#                                  Martine_Lung_1_10X          17
#                                  Martine_Lung_2_10X          19
# Smooth Muscle and Myofibroblast  Antoine_Lung_CD31_10X       24
#                                  Antoine_Lung_EPCAM_10X       5
#                                  Antoine_Lung_P3_10X         29
#                                  Martine_Lung_1_10X          10
#                                  Martine_Lung_2_10X          19
# Monocyte                         Antoine_Lung_CD31_10X       85
#                                  Antoine_Lung_EPCAM_10X    1303
#                                  Antoine_Lung_P3_10X         31
#                                  Bernard_Lung_10X           857
#                                  Martine_Lung_1_10X          10
#                                  Martine_Lung_2_10X          13
#                                  Stumpy_Lung_10X            345
# dtype: int64

# %%
! ls -lha $peptide_sketch_dir/alphabet-protein__ksize-30__scaled-10/ANTOINE_LUNG_CD31_POS__AAAGTAGTCCGGGTGT* | head
# Out:
# zsh:1: no matches found: /home/olga/data_lg/data_sm_copy/tabula-microcebus/analyses/kmermaid/tenx-tgz--alldata-v2-from-bams--remove-ribo/sketches_peptide_handmade_merged_remove_ribosomal_dissociation_allcells/alphabet-protein__ksize-30__scaled-10/ANTOINE_LUNG_CD31_POS__AAAGTAGTCCGGGTGT*

# %%
lemur_obs.query('broad_group == "Smooth Muscle and Myofibroblast"')
# Out:
#                                                                                   index  \
# cell_id
# ANTOINE_LUNG_CD31__AAAGTAGTCCGGGTGT    Antoine_Lung_CD31_10X_AAAGTAGTCCGGGTGT-lemur-hlm
# ANTOINE_LUNG_CD31__ACGATGTTCTGCGTAA    Antoine_Lung_CD31_10X_ACGATGTTCTGCGTAA-lemur-hlm
# ANTOINE_LUNG_CD31__ACTTGTTCACAGAGGT    Antoine_Lung_CD31_10X_ACTTGTTCACAGAGGT-lemur-hlm
# ANTOINE_LUNG_CD31__AGAATAGTCTGAGGGA    Antoine_Lung_CD31_10X_AGAATAGTCTGAGGGA-lemur-hlm
# ANTOINE_LUNG_CD31__AGCGTCGTCAGGCAAG    Antoine_Lung_CD31_10X_AGCGTCGTCAGGCAAG-lemur-hlm
# ANTOINE_LUNG_CD31__ATCATGGTCCAGTAGT    Antoine_Lung_CD31_10X_ATCATGGTCCAGTAGT-lemur-hlm
# ANTOINE_LUNG_CD31__ATGTGTGGTTTGTGTG    Antoine_Lung_CD31_10X_ATGTGTGGTTTGTGTG-lemur-hlm
# ANTOINE_LUNG_CD31__CAGCGACGTTCCTCCA    Antoine_Lung_CD31_10X_CAGCGACGTTCCTCCA-lemur-hlm
# ANTOINE_LUNG_CD31__CATATTCCAGACAAAT    Antoine_Lung_CD31_10X_CATATTCCAGACAAAT-lemur-hlm
# ANTOINE_LUNG_CD31__CATCAGAAGGGATCTG    Antoine_Lung_CD31_10X_CATCAGAAGGGATCTG-lemur-hlm
# ANTOINE_LUNG_CD31__CATGGCGTCAAGAAGT    Antoine_Lung_CD31_10X_CATGGCGTCAAGAAGT-lemur-hlm
# ANTOINE_LUNG_CD31__CCGGGATTCACGACTA    Antoine_Lung_CD31_10X_CCGGGATTCACGACTA-lemur-hlm
# ANTOINE_LUNG_CD31__CGAGCCACACTGTCGG    Antoine_Lung_CD31_10X_CGAGCCACACTGTCGG-lemur-hlm
# ANTOINE_LUNG_CD31__CGTCACTTCTGTCTAT    Antoine_Lung_CD31_10X_CGTCACTTCTGTCTAT-lemur-hlm
# MARTINE_LUNG_2__TGGGAAGTCTTGCATT      12y  TGGGAAGTCTTGCATT
#
#                                      cell_ontology_class cell_ontology_id  \
# cell_id
# ANTOINE_LUNG_CD31__AAAGTAGTCCGGGTGT         stromal cell       CL:0000499
# ANTOINE_LUNG_CD31__ACGATGTTCTGCGTAA   smooth muscle cell       CL:0000192
# ANTOINE_LUNG_CD31__ACTTGTTCACAGAGGT         stromal cell       CL:0000499
# ANTOINE_LUNG_CD31__AGAATAGTCTGAGGGA   smooth muscle cell       CL:0000192
# ANTOINE_LUNG_CD31__AGCGTCGTCAGGCAAG   smooth muscle cell       CL:0000192
# ANTOINE_LUNG_CD31__ATCATGGTCCAGTAGT   smooth muscle cell       CL:0000192
# ANTOINE_LUNG_CD31__ATGTGTGGTTTGTGTG         stromal cell       CL:0000499
# ANTOINE_LUNG_CD31__CAGCGACGTTCCTCCA   smooth muscle cell       CL:0000192
# ANTOINE_LUNG_CD31__CATATTCCAGACAAAT         stromal cell       CL:0000499
# ANTOINE_LUNG_CD31__CATCAGAAGGGATCTG         stromal cell       CL:0000499
# ANTOINE_LUNG_CD31__CATGGCGTCAAGAAGT         stromal cell       CL:0000499
# ANTOINE_LUNG_CD31__CCGGGATTCACGACTA         stromal cell       CL:0000499
# ANTOINE_LUNG_CD31__CGAGCCACACTGTCGG   smooth muscle cell       CL:0000192
# ANTOINE_LUNG_CD31__CGTCACTTCTGTCTAT   smooth muscle cell       CL:0000192
# ANTOINE_LUNG_CD31__CGTCCATAGGCCCTTG   smooth muscle cell       CL:0000192
# ANTOINE_LUNG_CD31__CGTGTAAAGAGGTACC         stromal cell       CL:0000499
# ANTOINE_LUNG_CD31__CTAAGACGTATATGGA   smooth muscle cell       CL:0000192
# ANTOINE_LUNG_CD31__GAACCTAAGAGTACAT         stromal cell       CL:0000499
# ANTOINE_LUNG_CD31__GATCGATTCGCTAGCG         stromal cell       CL:0000499
# ANTOINE_LUNG_CD31__GCGAGAATCAAACGGG   smooth muscle cell       CL:0000192
# ANTOINE_LUNG_CD31__GGTGTTAAGTTGCAGG         stromal cell       CL:0000499
# ANTOINE_LUNG_CD31__TAAGTGCGTGCAGACA         stromal cell       CL:0000499
# ANTOINE_LUNG_CD31__TACAGTGAGATGCCAG         stromal cell       CL:0000499
# ANTOINE_LUNG_CD31__TTTGCGCTCAAGGCTT   smooth muscle cell       CL:0000192
# ANTOINE_LUNG_EPCAM__CGCTATCGTTCCGTCT  smooth muscle cell       CL:0000192
# ANTOINE_LUNG_EPCAM__GGGTTGCCAAGAAGAG  smooth muscle cell       CL:0000192
# ANTOINE_LUNG_EPCAM__TAAGCGTCACCAGTTA  smooth muscle cell       CL:0000192
# ANTOINE_LUNG_EPCAM__TACGGATTCCTCAATT  smooth muscle cell       CL:0000192
# ANTOINE_LUNG_EPCAM__TATGCCCCAGGGTTAG  smooth muscle cell       CL:0000192
# ANTOINE_LUNG_P3__ACATCAGAGTTCGCGC     smooth muscle cell       CL:0000192
# ANTOINE_LUNG_P3__ACATCAGGTCCGTTAA           stromal cell       CL:0000499
ooth muscle cells (airway) and myofibroblasts
# ANTOINE_LUNG_P3__TTGAACGAGCAGCCTC     smooth muscle cells (airway) and myofibroblasts
# ANTOINE_LUNG_P3__TTTCCTCAGCAGCGTA     smooth muscle cells (airway) and myofibroblasts
# MARTINE_LUNG_1__AAACGGGTCAGTACGT                       smooth muscle cells (vascular)
# MARTINE_LUNG_1__AAAGCAATCGTGACAT                       smooth muscle cells (vascular)
# MARTINE_LUNG_1__CGTGAGCTCTACGAGT                       smooth muscle cells (vascular)
# MARTINE_LUNG_1__GACGTTACAGCTTCGG                       smooth muscle cells (vascular)
# MARTINE_LUNG_1__GCAAACTGTATCGCAT                       smooth muscle cells (vascular)
# MARTINE_LUNG_1__GCAATCATCACTCCTG                       smooth muscle cells (vascular)
# MARTINE_LUNG_1__GCATGCGCAGGGAGAG                       smooth muscle cells (vascular)
# MARTINE_LUNG_1__GTTTCTATCTCATTCA                       smooth muscle cells (vascular)
# MARTINE_LUNG_1__TGGACGCGTAATTGGA                       smooth muscle cells (vascular)
# MARTINE_LUNG_1__TGGTTCCGTAGCTTGT                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__AACGTTGGTTCAACCA                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__ATCATGGGTCATCGGC                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__CACACCTGTTATCACG                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__CCCATACAGGTAGCTG                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__CCCATACTCAGAGACG                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__CGATCGGGTCATACTG                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__CGCGTTTTCAAGGTAA                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__GACGTGCAGATGTCGG                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__GAGGTGACACGTTGGC                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__GGAACTTAGTAGTGCG                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__GGGTCTGCACATGACT                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__GTATTCTTCACTATTC                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__GTGCATACATTACCTT                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__TACTCATCAAAGCAAT                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__TCAGCAATCCGAATGT                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__TCAGGATCAAGTCTGT                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__TCGAGGCGTTCAGGCC                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__TGCCCATTCTAACTGG                       smooth muscle cells (vascular)
# MARTINE_LUNG_2__TGGGAAGTCTTGCATT                       smooth muscle cells (vascular)
#
#                                      individual sample  \
# cell_id
# ANTOINE_LUNG_CD31__AAAGTAGTCCGGGTGT     Antoine    nan
# ANTOINE_LUNG_CD31__ACGATGTTCTGCGTAA     Antoine    nan
# ANTOINE_LUNG_CD31__ACTTGTTCACAGAGGT     Antoine    nan
# ANTOINE_LUNG_CD31__AGAATAGTCTGAGGGA     Antoine    nan
# ANTOINE_LUNG_CD31__AGCGTCGTCAGGCAAG     Antoine    nan
# ANTOINE_LUNG_CD31__ATCATGGTCCAGTAGT     Antoine    nan
# ANTOINE_LUNG_CD31__ATGTGTGGTTTGTGTG     Antoine    nan
# ANTOINE_LUNG_CD31__AGCGTCGTCAGGCAAG    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__ATCATGGTCCAGTAGT    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__ATGTGTGGTTTGTGTG    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__CAGCGACGTTCCTCCA    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__CATATTCCAGACAAAT    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__CATCAGAAGGGATCTG    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__CATGGCGTCAAGAAGT    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__CCGGGATTCACGACTA    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__CGAGCCACACTGTCGG    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__CGTCACTTCTGTCTAT    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__CGTCCATAGGCCCTTG    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__CGTGTAAAGAGGTACC    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__CTAAGACGTATATGGA    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__GAACCTAAGAGTACAT    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__GATCGATTCGCTAGCG    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__GCGAGAATCAAACGGG    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__GGTGTTAAGTTGCAGG    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__TAAGTGCGTGCAGACA    ANTOINE_LUNG_CD31   NaN     NaN
# ANTOINE_LUNG_CD31__TACAGTGAGATGCCAG    ANTOINE_LUNG_CD31   NaN     NaN
# ...
# ANTOINE_LUNG_P3__GCTGGGTCATTTCACT         stromal: lemur
# ANTOINE_LUNG_P3__GGCCGATAGCGATATA         stromal: lemur
# ANTOINE_LUNG_P3__GTCACAAGTCCTCTTG         stromal: lemur
# ANTOINE_LUNG_P3__GTTCTCGAGTGATCGG         stromal: lemur
# ANTOINE_LUNG_P3__TAAACCGCAATGGAGC         stromal: lemur
# ANTOINE_LUNG_P3__TAAGAGACACTTAACG         stromal: lemur
# ANTOINE_LUNG_P3__TCGCGAGCACAACGTT         stromal: lemur
# ANTOINE_LUNG_P3__TGAGCATCACGACTCG         stromal: lemur
# ANTOINE_LUNG_P3__TGCGTGGTCGGAATCT         stromal: lemur
# ANTOINE_LUNG_P3__TGGACGCAGACCGGAT         stromal: lemur
# ANTOINE_LUNG_P3__TTCTACAGTAGTACCT         stromal: lemur
# ANTOINE_LUNG_P3__TTGAACGAGCAGCCTC         stromal: lemur
#
#                                      common_individual_id
# cell_id
# ANTOINE_LUNG_CD31__AAAGTAGTCCGGGTGT         lemur_Antoine
# ANTOINE_LUNG_CD31__ACGATGTTCTGCGTAA         lemur_Antoine
# ANTOINE_LUNG_CD31__ACTTGTTCACAGAGGT         lemur_Antoine
# ANTOINE_LUNG_CD31__AGAATAGTCTGAGGGA         lemur_Antoine
# ANTOINE_LUNG_CD31__AGCGTCGTCAGGCAAG         lemur_Antoine
# ANTOINE_LUNG_CD31__ATCATGGTCCAGTAGT         lemur_Antoine
# ANTOINE_LUNG_CD31__ATGTGTGGTTTGTGTG         lemur_Antoine
# ANTOINE_LUNG_CD31__CAGCGACGTTCCTCCA         lemur_Antoine
# ANTOINE_LUNG_CD31__CATATTCCAGACAAAT         lemur_Antoine
# ANTOINE_LUNG_CD31__CATCAGAAGGGATCTG         lemur_Antoine
# ANTOINE_LUNG_CD31__CATGGCGTCAAGAAGT         lemur_Antoine
# ANTOINE_LUNG_CD31__CCGGGATTCACGACTA         lemur_Antoine
# ANTOINE_LUNG_CD31__CGAGCCACACTGTCGG         lemur_Antoine
# ANTOINE_LUNG_CD31__CGTCACTTCTGTCTAT         lemur_Antoine
# ANTOINE_LUNG_CD31__CGTCCATAGGCCCTTG         lemur_Antoine
# ANTOINE_LUNG_CD31__CGTGTAAAGAGGTACC         lemur_Antoine
# ANTOINE_LUNG_CD31__CTAAGACGTATATGGA         lemur_Antoine
# ANTOINE_LUNG_CD31__GAACCTAAGAGTACAT         lemur_Antoine
# ANTOINE_LUNG_CD31__GATCGATTCGCTAGCG         lemur_Antoine
# ANTOINE_LUNG_CD31__GCGAGAATCAAACGGG         lemur_Antoine
# ANTOINE_LUNG_CD31__GGTGTTAAGTTGCAGG         lemur_Antoine
# ANTOINE_LUNG_CD31__TAAGTGCGTGCAGACA         lemur_Antoine
# ANTOINE_LUNG_CD31__TACAGTGAGATGCCAG         lemur_Antoine
# ANTOINE_LUNG_CD31__TTTGCGCTCAAGGCTT         lemur_Antoine
# ANTOINE_LUNG_EPCAM__CGCTATCGTTCCGTCT        lemur_Antoine
# ANTOINE_LUNG_EPCAM__GGGTTGCCAAGAAGAG        lemur_Antoine
# ANTOINE_LUNG_EPCAM__TAAGCGTCACCAGTTA        lemur_Antoine
# ANTOINE_LUNG_EPCAM__TACGGATTCCTCAATT        lemur_Antoine
# ANTOINE_LUNG_EPCAM__TATGCCCCAGGGTTAG        lemur_Antoine
# ANTOINE_LUNG_P3__ACATCAGAGTTCGCGC           lemur_Antoine
# ANTOINE_LUNG_P3__ACATCAGGTCCGTTAA           lemur_Antoine
# ANTOINE_LUNG_P3__ACTGAACGTCAAAGCG           lemur_Antoine
# ANTOINE_LUNG_P3__AGCGTATAGAATTGTG           lemur_Antoine
# ANTOINE_LUNG_P3__AGCGTCGTCGACGGAA           lemur_Antoine
# ANTOINE_LUNG_P3__AGCTCTCTCTTCATGT           lemur_Antoine
# ANTOINE_LUNG_P3__ATTATCCGTATTCTCT           lemur_Antoine
# MARTINE_LUNG_2__GAGGTGACACGTTGGC            lemur_Martine
# MARTINE_LUNG_2__GGAACTTAGTAGTGCG            lemur_Martine
# MARTINE_LUNG_2__GGGTCTGCACATGACT            lemur_Martine
# MARTINE_LUNG_2__GTATTCTTCACTATTC            lemur_Martine
# MARTINE_LUNG_2__GTGCATACATTACCTT            lemur_Martine
# MARTINE_LUNG_2__TACTCATCAAAGCAAT            lemur_Martine
# MARTINE_LUNG_2__TCAGCAATCCGAATGT            lemur_Martine
# MARTINE_LUNG_2__TCAGGATCAAGTCTGT            lemur_Martine
# MARTINE_LUNG_2__TCGAGGCGTTCAGGCC            lemur_Martine
# MARTINE_LUNG_2__TGCCCATTCTAACTGG            lemur_Martine
# MARTINE_LUNG_2__TGGGAAGTCTTGCATT            lemur_Martine
#
# [87 rows x 29 columns]

# %%
peptide_sketch_dir
# Out:
# '/home/olga/data_lg/data_sm_copy/tabula-microcebus/analyses/kmermaid/tenx-tgz--alldata-v2-from-bams--remove-ribo/sketches_peptide_handmade_merged_remove_ribosomal_dissociation_allcells'

# %%
! ls -lha $peptide_sketch_dir/alphabet-protein__ksize-30__scaled-10/ | head
# Out:
# total 1.2G
# drwxr-xr-x 2 olga czb 512K Apr 26 22:22 .
# drwxr-xr-x 6 olga czb 4.0K Apr 26 16:52 ..
# -rw-r--r-- 1 olga czb 207K Apr 26 18:12 ANTOINE_LUNG_CD31_POS__AAACCTGAGAAACGAG.sig
# -rw-r--r-- 1 olga czb 235K Apr 26 18:30 ANTOINE_LUNG_CD31_POS__AAACCTGAGGCAGTCA.sig
# -rw-r--r-- 1 olga czb 279K Apr 26 20:50 ANTOINE_LUNG_CD31_POS__AAACCTGAGGGTGTGT.sig
# -rw-r--r-- 1 olga czb 278K Apr 26 20:03 ANTOINE_LUNG_CD31_POS__AAACCTGGTATATGGA.sig
# -rw-r--r-- 1 olga czb 281K Apr 26 19:35 ANTOINE_LUNG_CD31_POS__AAACCTGTCCGTCATC.sig
# -rw-r--r-- 1 olga czb 125K Apr 26 20:50 ANTOINE_LUNG_CD31_POS__AAACCTGTCGAGAGCA.sig
# -rw-r--r-- 1 olga czb 238K Apr 26 18:41 ANTOINE_LUNG_CD31_POS__AAACCTGTCGGAGCAA.sig
# ls: write error: Broken pipe

# %%
! ls -1 $peptide_sketch_dir/alphabet-protein__ksize-30__scaled-10/ | wc -l
# Out:
# 5695

# %%
! ls -lha $nucleotide_sketch_dir/alphabet-DNA__ksize-21__scaled-10/ | head
# Out:
# total 3.1G
# drwxr-xr-x 2 olga czb  512K Apr 29 13:55 .
# drwxr-xr-x 3 olga czb  4.0K Apr 29 13:15 ..
# -rw-r--r-- 1 olga czb  579K Apr 29 13:28 ANTOINE_LUNG_CD31_POS__AAACCTGAGAAACGAG.sig
# -rw-r--r-- 1 olga czb  661K Apr 29 13:30 ANTOINE_LUNG_CD31_POS__AAACCTGAGGCAGTCA.sig
# -rw-r--r-- 1 olga czb  768K Apr 29 13:45 ANTOINE_LUNG_CD31_POS__AAACCTGAGGGTGTGT.sig
# -rw-r--r-- 1 olga czb  772K Apr 29 13:40 ANTOINE_LUNG_CD31_POS__AAACCTGGTATATGGA.sig
# -rw-r--r-- 1 olga czb  773K Apr 29 13:37 ANTOINE_LUNG_CD31_POS__AAACCTGTCCGTCATC.sig
# -rw-r--r-- 1 olga czb  352K Apr 29 13:45 ANTOINE_LUNG_CD31_POS__AAACCTGTCGAGAGCA.sig
# -rw-r--r-- 1 olga czb  656K Apr 29 13:31 ANTOINE_LUNG_CD31_POS__AAACCTGTCGGAGCAA.sig
# ls: write error: Broken pipe

# %%
! ls -lha $nucleotide_sketch_dir
# Out:
# total 513K
# drwxr-xr-x  3 olga czb 4.0K Apr 29 13:15 .
# drwxr-xr-x 15 olga czb 4.0K Mar  1 15:38 ..
# drwxr-xr-x  2 olga czb 512K Apr 29 13:55 alphabet-DNA__ksize-21__scaled-10

# %%
! ls -1 $nucleotide_sketch_dir/alphabet-DNA__ksize-21__scaled-10/ | wc -l
# Out:
# 5695

# %%
set(os.path.basename(x).split('__')[0] for x in glob.iglob(os.path.join(nucleotide_sketch_dir, 'alphabet-DNA__ksize-21__scaled-10', '*.sig')))
# Out:
# {'ANTOINE_LUNG_CD31_POS', 'ANTOINE_LUNG_EPCAM_POS', 'ANTOINE_LUNG_P3'}

# %%
# CELL_IDS_TO_USE

# %%
for filename in glob.iglob(os.path.join(test_1_single_cells, '*', '*.sig')):
    if "P3" in filename:
        print(filename)
        break
# Out:
# /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/1--single-cell-sigs/alphabet-dayhoff__ksize-51__scaled-10/ANTOINE_LUNG_P3__TATCAGGGTTCGTTGA.sig

# %% [markdown]
# # Create queries

# %%
moltypes = "DNA", "protein", "dayhoff"

alpha_ksizes = (("DNA", 21), ("protein", 30), ("dayhoff", 51))

# mouse celltype database directory
train_4_celltype_sbts = "/home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/1--train-mouse/4--celltype-sbt-dbts"
train_3_merged_celltype_remove_common = "/home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/1--train-mouse/3--merged-celltype-remove-common-kmers"
train_2_merged_celltype = "/home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/1--train-mouse/2--merged-celltype-sigs"

# Try both with removed common hashes and original
celltype_dirs = dict(
    remove_common=train_3_merged_celltype_remove_common,
    raw_merged=train_2_merged_celltype,
)

txts = []
for i, (name, celltype_dir) in enumerate(celltype_dirs.items()):
    this_celltype_dir_results = os.path.join(
        test_dir, f"3-{i}--mouse-search-results--{name}"
    )
    if not os.path.exists(this_celltype_dir_results):
        os.makedirs(this_celltype_dir_results)
    for alpha, ksize in alpha_ksizes:
        txt = csc_utils.make_sourmash_search_commands(
            this_celltype_dir_results,
            query_sigs_dir=test_1_single_cells,
            sbt_base_dir=celltype_dir,
            k_sizes=[ksize],
            scaled_sizes=[
                10,
            ],
            cell_ids=[],
            sbt_template_basename=None,
            query_sig_files=False,
            containment=True,
            moltype=alpha,
            threshold=1e-100,
            n_jobs=96,
            force=True,
            num_results=None,
            add_ksize_to_sig_dir=False,
            traverse_directory=True,
        )
        txts.append(txt)
txts_to_cat = " ".join(txts)
catted_txt = os.path.join(results_dir, "sourmash_search_commands_concatenated.txt")
! cat $txts_to_cat > $catted_txt

print(f"---\nparallel --progress --eta --jobs 96 < {catted_txt}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-fc0ee636a24a> in <module>
#      17 for i, (name, celltype_dir) in enumerate(celltype_dirs.items()):
#      18     this_celltype_dir_results = os.path.join(
# ---> 19         human_test_dir, f"3-{i}--mouse-search-results--{name}"
#      20     )
#      21     if not os.path.exists(this_celltype_dir_results):
#
# NameError: name 'human_test_dir' is not defined

# %% [markdown]
# ## Search mouse celltypes with k-mers shared by 5, 10% of cells, but remove k-mers shared by 80% of celltypes

# %%
moltypes = "DNA", "protein", "dayhoff"

alpha_ksizes = (("DNA", 21), ("protein", 30), ("dayhoff", 51))

# mouse celltype database directory
train_3_sigs_min_10_percent = "/home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/1--train-mouse/2--merged-celltype-sigs--min-kmer-count--10-percent"
train_3_sigs_min_5_percent = "/home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/1--train-mouse/2--merged-celltype-sigs--min-kmer-count--5-percent"
train_3_sigs_min_5_percent_remove_common = "/home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/1--train-mouse/3--merged-celltype-remove-common-kmers--min-kmer-count--5-percent"
train_3_sigs_min_10_percent_remove_common = "/home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/1--train-mouse/3--merged-celltype-remove-common-kmers--min-kmer-count--10-percent"

# Try both with removed common hashes and original
celltype_dirs = {
        'min-5-percent-shared-kmers': train_3_sigs_min_5_percent,
    'min-10-percent-shared-kmers': train_3_sigs_min_10_percent,
    'min-5-percent-shared-kmers-remove-common-kmers': train_3_sigs_min_5_percent_remove_common,
    'min-10-percent-shared-kmers-remove-common-kmers': train_3_sigs_min_10_percent_remove_common,
}

txts = []

containments = True, False
for containment in containments:
    for i, (name, celltype_dir) in enumerate(celltype_dirs.items()):
        suffix = f"3-{i}--mouse-containment-search-results--{name}" if containment else f"3-{i}--mouse-search-results--{name}"
        this_celltype_dir_results = os.path.join(
            test_dir, suffix
        )
        if not os.path.exists(this_celltype_dir_results):
            os.makedirs(this_celltype_dir_results)
        for alpha, ksize in alpha_ksizes:
            txt = csc_utils.make_sourmash_search_commands(
                this_celltype_dir_results,
                query_sigs_dir=test_1_single_cells,
                sbt_base_dir=celltype_dir,
                k_sizes=[ksize],
                scaled_sizes=[
                    10,
                ],
                sbt_template_basename=None,
                query_sig_files=False,
                containment=containment,
                moltype=alpha,
                threshold=1e-100,
                n_jobs=96,
                force=False,
                num_results=None,
                add_ksize_to_sig_dir=False,
                traverse_directory=True,
            )
            txts.append(txt)
txts_to_cat = " ".join(txts)
catted_txt = os.path.join(results_dir, "sourmash_search_commands_concatenated.txt")
! cat $txts_to_cat > $catted_txt

print(f"---\nparallel --progress --eta --jobs 96 < {catted_txt}")
! wc -l $catted_txt
# Out:
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-0--mouse-containment-search-results--min-5-percent-shared-kmers/sourmash_search_commands_DNA.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-0--mouse-containment-search-results--min-5-percent-shared-kmers/sourmash_search_commands_protein.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-0--mouse-containment-search-results--min-5-percent-shared-kmers/sourmash_search_commands_dayhoff.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-1--mouse-containment-search-results--min-10-percent-shared-kmers/sourmash_search_commands_DNA.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-1--mouse-containment-search-results--min-10-percent-shared-kmers/sourmash_search_commands_protein.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-1--mouse-containment-search-results--min-10-percent-shared-kmers/sourmash_search_commands_dayhoff.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-2--mouse-containment-search-results--min-5-percent-shared-kmers-remove-common-kmers/sourmash_search_commands_DNA.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-2--mouse-containment-search-results--min-5-percent-shared-kmers-remove-common-kmers/sourmash_search_commands_protein.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-2--mouse-containment-search-results--min-5-percent-shared-kmers-remove-common-kmers/sourmash_search_commands_dayhoff.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-3--mouse-containment-search-results--min-10-percent-shared-kmers-remove-common-kmers/sourmash_search_commands_DNA.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-3--mouse-containment-search-results--min-10-percent-shared-kmers-remove-common-kmers/sourmash_search_commands_protein.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-3--mouse-containment-search-results--min-10-percent-shared-kmers-remove-common-kmers/sourmash_search_commands_dayhoff.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-0--mouse-search-results--min-5-percent-shared-kmers/sourmash_search_commands_DNA.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-0--mouse-search-results--min-5-percent-shared-kmers/sourmash_search_commands_protein.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-0--mouse-search-results--min-5-percent-shared-kmers/sourmash_search_commands_dayhoff.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-1--mouse-search-results--min-10-percent-shared-kmers/sourmash_search_commands_DNA.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-1--mouse-search-results--min-10-percent-shared-kmers/sourmash_search_commands_protein.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-1--mouse-search-results--min-10-percent-shared-kmers/sourmash_search_commands_dayhoff.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-2--mouse-search-results--min-5-percent-shared-kmers-remove-common-kmers/sourmash_search_commands_DNA.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-2--mouse-search-results--min-5-percent-shared-kmers-remove-common-kmers/sourmash_search_commands_protein.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-2--mouse-search-results--min-5-percent-shared-kmers-remove-common-kmers/sourmash_search_commands_dayhoff.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-3--mouse-search-results--min-10-percent-shared-kmers-remove-common-kmers/sourmash_search_commands_DNA.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-3--mouse-search-results--min-10-percent-shared-kmers-remove-common-kmers/sourmash_search_commands_protein.txt
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/3-3--mouse-search-results--min-10-percent-shared-kmers-remove-common-kmers/sourmash_search_commands_dayhoff.txt
# ---
# parallel --progress --eta --jobs 96 < /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/2--mouse-search-results/sourmash_search_commands_concatenated.txt
# 49416 /home/olga/data_lg/data_sm_copy/immune-evolution/kmer-signatures/4--test-lemur/2--mouse-search-results/sourmash_search_commands_concatenated.txt

# %%
1+1
# Out:
# 2
