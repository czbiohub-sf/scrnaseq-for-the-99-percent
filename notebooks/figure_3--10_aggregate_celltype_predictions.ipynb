# %%
# %load_ext autoreload
# %autoreload 2

import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from joblib import Parallel, delayed
from sklearn.metrics import confusion_matrix
from tqdm import tqdm

# Artisinal, small-batch, handmade modules
import classification_metrics
from nb_utils import describe

from celltype_utils import SHARED_CELLTYPES, BROAD_TO_COMPARTMENT, broad_to_compartment
from path_constants import top_hit_paths, FIGURE_FOLDER, sig_outdir_base
from plot_constants import get_cmap_color
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Assign figure folder

# %%
figure_folder = os.path.join(FIGURE_FOLDER, "kmermaid_classification_metrics")

# %% [markdown]
# # Read in classification data

# %%
dfs = []
for species, parquet in top_hit_paths.items():
    try:
        df = pd.read_parquet(parquet)
    except FileNotFoundError:
        print(f"Could not find parquet for {species}")
        continue

    print(f"Species: {species}")
    describe(df)

    df["species"] = species
    df = df.query(
        "groundtruth_celltype in @SHARED_CELLTYPES "
        "and predicted_celltype in @SHARED_CELLTYPES"
    )
    df.index.name = "query_cell_id"
    dfs.append(df)
predicted_cells = pd.concat(dfs, ignore_index=False)

databases_to_choose = (
#     "min-10-percent-shared-kmers-remove-common-kmers",
    "min-5-percent-shared-kmers-remove-common-kmers",
)

# Only use database with common k-mers removed because without that, no AT2 cells are predicted!
# predicted_cells = predicted_cells.query(
#     'database_type == "min-10-percent-shared-kmers-remove-common-kmers" '
#     'and search_method == "similarity_abundance"'
# )
# predicted_cells = predicted_cells.query('database_type == "remove_common"')
# predicted_cells = predicted_cells.loc[predicted_cells.database_type.isin(databases_to_choose) ]
predicted_cells.groundtruth_celltype = (
    predicted_cells.groundtruth_celltype.cat.remove_unused_categories()
)
# predicted_cells.predicted_celltype = predicted_cells.predicted_celltype.cat.remove_unused_categories()
describe(predicted_cells)
# Out:
# Species: mouse
# (65940, 24)
# --- First 5 entries ---
#                                       similarity mouse1_broad_group  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.296154           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.271510           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.296568           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.507136             T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.537653             T cell
#
#                                              search_method  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  similarity_abundance
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  similarity_abundance
#
#                                                     database_type  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
#
#                                                                   sketch_id  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA      alphabet-DNA__ksize-21__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  alphabet-dayhoff__ksize-51__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  alphabet-protein__ksize-30__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA      alphabet-DNA__ksize-21__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  alphabet-dayhoff__ksize-51__scaled-10
#
#                                      mol_or_alpha alphabet  ksize  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet      DNA     21
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet  dayhoff     51
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet  protein     30
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet      DNA     21
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet  dayhoff     51
#
#                                      sketch_style  sketch_value  ...  \
# mouse2_cell_id                                                   ...
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10  ...
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10  ...
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10  ...
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10  ...
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10  ...
#
#                                      mouse2_compartment_group  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                 lymphoid
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                 lymphoid
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                 lymphoid
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                 lymphoid
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                 lymphoid
#
#                                                                         database_method  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           min-10-percent-shared-kmers: containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           min-10-percent-shared-kmers: containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           min-10-percent-shared-kmers: containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers: similarity_abundance
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers: similarity_abundance
#
#                                      mouse2_human_readable  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           male:female
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           male:female
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           male:female
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           male:female
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           male:female
#
#                                      broad_group_matches  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA               False
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA               False
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA               False
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                True
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                True
#
#                                      broad_group_matches_string  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA         different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA         different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA         different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              same celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              same celltype
#
#                                         alpha_ksize  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA      DNA, k:21
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  dayhoff, k:51
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  protein, k:30
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA      DNA, k:21
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  dayhoff, k:51
#
#                                                       alpha_match  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA      DNA, different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  dayhoff, different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  protein, different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           DNA, same celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       dayhoff, same celltype
#
#                                                          mouse2_match  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  male:female, different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  male:female, different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  male:female, different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       male:female, same celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       male:female, same celltype
#
#                                      groundtruth_celltype predicted_celltype
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA               T cell           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA               T cell           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA               T cell           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA               T cell             T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA               T cell             T cell
#
# [5 rows x 24 columns]
# Species: lemur
# (147236, 17)
# --- First 5 entries ---
#                                      similarity mouse_broad_group  \
# lemur_cell_id
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG    0.049508         Dendritic
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG    0.114944         Dendritic
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG    0.110182         Dendritic
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG    0.081077        Macrophage
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG    0.090060        Macrophage
#
#                                             search_method  \
# lemur_cell_id
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG           containment
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG           containment
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG           containment
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG  similarity_abundance
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG  similarity_abundance
#
#                                                                  sketch_id  \
# lemur_cell_id
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG      alphabet-DNA__ksize-21__scaled-10
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG  alphabet-dayhoff__ksize-51__scaled-10
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG  alphabet-protein__ksize-30__scaled-10
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG      alphabet-DNA__ksize-21__scaled-10
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG  alphabet-dayhoff__ksize-51__scaled-10
#
#                                     mol_or_alpha alphabet  ksize sketch_style  \
# lemur_cell_id
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG     alphabet      DNA     21       scaled
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG     alphabet  dayhoff     51       scaled
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG     alphabet  protein     30       scaled
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG     alphabet      DNA     21       scaled
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG     alphabet  dayhoff     51       scaled
#
#                                      sketch_value      lemur_channel  \
# lemur_cell_id
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG            10  ANTOINE_LUNG_CD31
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG            10  ANTOINE_LUNG_CD31
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG            10  ANTOINE_LUNG_CD31
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG            10  ANTOINE_LUNG_CD31
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG            10  ANTOINE_LUNG_CD31
#
#                                     lemur_cell_ontology_class  \
# lemur_cell_id
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG                macrophage
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG                macrophage
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG                macrophage
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG                macrophage
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG                macrophage
#
#                                     lemur_narrow_group lemur_broad_group  \
# lemur_cell_id
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG         Macrophage        Macrophage
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG         Macrophage        Macrophage
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG         Macrophage        Macrophage
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG         Macrophage        Macrophage
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG         Macrophage        Macrophage
#
#                                     lemur_compartment_group  \
# lemur_cell_id
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG                 myeloid
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG                 myeloid
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG                 myeloid
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG                 myeloid
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG                 myeloid
#
#                                                    database_type  \
# lemur_cell_id
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG  min-10-percent-shared-kmers
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG  min-10-percent-shared-kmers
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG  min-10-percent-shared-kmers
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG  min-10-percent-shared-kmers
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG  min-10-percent-shared-kmers
#
#                                     groundtruth_celltype predicted_celltype
# lemur_cell_id
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG           Macrophage          Dendritic
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG           Macrophage          Dendritic
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG           Macrophage          Dendritic
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG           Macrophage         Macrophage
# ANTOINE_LUNG_CD31__AAACCTGAGAAACGAG           Macrophage         Macrophage
# Species: bat
# (216998, 17)
# --- First 5 entries ---
#                            similarity mouse_broad_group         search_method  \
# bat_cell_id
# bat2-LU__AAACCTGAGGTACTCT    0.021308         Dendritic           containment
# bat2-LU__AAACCTGAGGTACTCT    0.056749         Dendritic           containment
# bat2-LU__AAACCTGAGGTACTCT    0.064116         Dendritic           containment
# bat2-LU__AAACCTGAGGTACTCT    0.060978        Macrophage  similarity_abundance
# bat2-LU__AAACCTGAGGTACTCT    0.030150         Dendritic  similarity_abundance
#
#                                                        sketch_id mol_or_alpha  \
# bat_cell_id
# bat2-LU__AAACCTGAGGTACTCT      alphabet-DNA__ksize-21__scaled-10     alphabet
# bat2-LU__AAACCTGAGGTACTCT  alphabet-dayhoff__ksize-51__scaled-10     alphabet
# bat2-LU__AAACCTGAGGTACTCT  alphabet-protein__ksize-30__scaled-10     alphabet
# bat2-LU__AAACCTGAGGTACTCT      alphabet-DNA__ksize-21__scaled-10     alphabet
# bat2-LU__AAACCTGAGGTACTCT  alphabet-dayhoff__ksize-51__scaled-10     alphabet
#
#                           alphabet  ksize sketch_style  sketch_value  \
# bat_cell_id
# bat2-LU__AAACCTGAGGTACTCT      DNA     21       scaled            10
# bat2-LU__AAACCTGAGGTACTCT  dayhoff     51       scaled            10
# bat2-LU__AAACCTGAGGTACTCT  protein     30       scaled            10
# bat2-LU__AAACCTGAGGTACTCT      DNA     21       scaled            10
# bat2-LU__AAACCTGAGGTACTCT  dayhoff     51       scaled            10
#
#                           bat_channel bat_cell_ontology_class  \
# bat_cell_id
# bat2-LU__AAACCTGAGGTACTCT     bat2-LU                     nan
# bat2-LU__AAACCTGAGGTACTCT     bat2-LU                     nan
# bat2-LU__AAACCTGAGGTACTCT     bat2-LU                     nan
# bat2-LU__AAACCTGAGGTACTCT     bat2-LU                     nan
# bat2-LU__AAACCTGAGGTACTCT     bat2-LU                     nan
#
#                           bat_narrow_group bat_broad_group  \
# bat_cell_id
# bat2-LU__AAACCTGAGGTACTCT       Macrophage      Macrophage
# bat2-LU__AAACCTGAGGTACTCT       Macrophage      Macrophage
# bat2-LU__AAACCTGAGGTACTCT       Macrophage      Macrophage
# bat2-LU__AAACCTGAGGTACTCT       Macrophage      Macrophage
# bat2-LU__AAACCTGAGGTACTCT       Macrophage      Macrophage
#
#                           bat_compartment_group                database_type  \
# bat_cell_id
# bat2-LU__AAACCTGAGGTACTCT               myeloid  min-10-percent-shared-kmers
# bat2-LU__AAACCTGAGGTACTCT               myeloid  min-10-percent-shared-kmers
# bat2-LU__AAACCTGAGGTACTCT               myeloid  min-10-percent-shared-kmers
# bat2-LU__AAACCTGAGGTACTCT               myeloid  min-10-percent-shared-kmers
# bat2-LU__AAACCTGAGGTACTCT               myeloid  min-10-percent-shared-kmers
#
#                           groundtruth_celltype predicted_celltype
# bat_cell_id
# bat2-LU__AAACCTGAGGTACTCT           Macrophage          Dendritic
# bat2-LU__AAACCTGAGGTACTCT           Macrophage          Dendritic
# bat2-LU__AAACCTGAGGTACTCT           Macrophage          Dendritic
# bat2-LU__AAACCTGAGGTACTCT           Macrophage         Macrophage
# bat2-LU__AAACCTGAGGTACTCT           Macrophage          Dendritic
# Species: human
# (424610, 17)
# --- First 5 entries ---
#                         similarity mouse_broad_group search_method  \
# human_cell_id
# P3_2__AAACCTGGTTAGAACA    0.047525         Dendritic   containment
# P3_2__AAACCTGGTTAGAACA    0.246955         Dendritic   containment
# P3_2__AAACCTGGTTAGAACA    0.231591         Dendritic   containment
# P3_2__AAACCTGGTTAGAACA    0.016143         Dendritic   containment
# P3_2__AAACCTGGTTAGAACA    0.102805         Dendritic   containment
#
#                                                     sketch_id mol_or_alpha  \
# human_cell_id
# P3_2__AAACCTGGTTAGAACA      alphabet-DNA__ksize-21__scaled-10     alphabet
# P3_2__AAACCTGGTTAGAACA  alphabet-dayhoff__ksize-51__scaled-10     alphabet
# P3_2__AAACCTGGTTAGAACA  alphabet-protein__ksize-30__scaled-10     alphabet
# P3_2__AAACCTGGTTAGAACA      alphabet-DNA__ksize-21__scaled-10     alphabet
# P3_2__AAACCTGGTTAGAACA  alphabet-dayhoff__ksize-51__scaled-10     alphabet
#
#                        alphabet  ksize sketch_style  sketch_value  \
# human_cell_id
# P3_2__AAACCTGGTTAGAACA      DNA     21       scaled            10
# P3_2__AAACCTGGTTAGAACA  dayhoff     51       scaled            10
# P3_2__AAACCTGGTTAGAACA  protein     30       scaled            10
# P3_2__AAACCTGGTTAGAACA      DNA     21       scaled            10
# P3_2__AAACCTGGTTAGAACA  dayhoff     51       scaled            10
#
#                        human_channel human_cell_ontology_class  \
# human_cell_id
# P3_2__AAACCTGGTTAGAACA          P3_2                macrophage
# P3_2__AAACCTGGTTAGAACA          P3_2                macrophage
# P3_2__AAACCTGGTTAGAACA          P3_2                macrophage
# P3_2__AAACCTGGTTAGAACA          P3_2                macrophage
# P3_2__AAACCTGGTTAGAACA          P3_2                macrophage
#
#                        human_narrow_group human_broad_group  \
# human_cell_id
# P3_2__AAACCTGGTTAGAACA         Macrophage        Macrophage
# P3_2__AAACCTGGTTAGAACA         Macrophage        Macrophage
# P3_2__AAACCTGGTTAGAACA         Macrophage        Macrophage
# P3_2__AAACCTGGTTAGAACA         Macrophage        Macrophage
# P3_2__AAACCTGGTTAGAACA         Macrophage        Macrophage
#
#                        human_compartment_group  \
# human_cell_id
# P3_2__AAACCTGGTTAGAACA                 myeloid
# P3_2__AAACCTGGTTAGAACA                 myeloid
# P3_2__AAACCTGGTTAGAACA                 myeloid
# P3_2__AAACCTGGTTAGAACA                 myeloid
# P3_2__AAACCTGGTTAGAACA                 myeloid
#
#                                                           database_type  \
# human_cell_id
# P3_2__AAACCTGGTTAGAACA                      min-10-percent-shared-kmers
# P3_2__AAACCTGGTTAGAACA                      min-10-percent-shared-kmers
# P3_2__AAACCTGGTTAGAACA                      min-10-percent-shared-kmers
# P3_2__AAACCTGGTTAGAACA  min-10-percent-shared-kmers-remove-common-kmers
# P3_2__AAACCTGGTTAGAACA  min-10-percent-shared-kmers-remove-common-kmers
#
#                        groundtruth_celltype predicted_celltype
# human_cell_id
# P3_2__AAACCTGGTTAGAACA           Macrophage          Dendritic
# P3_2__AAACCTGGTTAGAACA           Macrophage          Dendritic
# P3_2__AAACCTGGTTAGAACA           Macrophage          Dendritic
# P3_2__AAACCTGGTTAGAACA           Macrophage          Dendritic
# P3_2__AAACCTGGTTAGAACA           Macrophage          Dendritic
# (854784, 41)
# --- First 5 entries ---
#                                       similarity mouse1_broad_group  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.296154           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.271510           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.296568           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.507136             T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.537653             T cell
#
#                                              search_method  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  similarity_abundance
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  similarity_abundance
#
#                                                     database_type  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
#
#                                                                   sketch_id  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA      alphabet-DNA__ksize-21__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  alphabet-dayhoff__ksize-51__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  alphabet-protein__ksize-30__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA      alphabet-DNA__ksize-21__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  alphabet-dayhoff__ksize-51__scaled-10
#
#                                      mol_or_alpha alphabet  ksize  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet      DNA     21
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet  dayhoff     51
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet  protein     30
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet      DNA     21
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet  dayhoff     51
#
#                                      sketch_style  sketch_value  ...  \
# query_cell_id                                                    ...
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10  ...
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10  ...
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10  ...
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10  ...
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10  ...
#
#                                      bat_channel bat_cell_ontology_class  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA         NaN                     NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA         NaN                     NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA         NaN                     NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA         NaN                     NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA         NaN                     NaN
#
#                                      bat_narrow_group bat_broad_group  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              NaN             NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              NaN             NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              NaN             NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              NaN             NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              NaN             NaN
#
#                                      bat_compartment_group human_channel  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                   NaN           NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                   NaN           NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                   NaN           NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                   NaN           NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                   NaN           NaN
#
#                                      human_cell_ontology_class  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                       NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                       NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                       NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                       NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                       NaN
#
#                                      human_narrow_group human_broad_group  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                NaN               NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                NaN               NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                NaN               NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                NaN               NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                NaN               NaN
#
#                                      human_compartment_group
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                     NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                     NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                     NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                     NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                     NaN
#
# [5 rows x 41 columns]

# %%
predicted_cells.species.value_counts()
# Out:
# human    424610
# bat      216998
# lemur    147236
# mouse     65940
# Name: species, dtype: int64

# %% [markdown]
# ### ignore mouse2mouse predictions on same query mouse as test mouse

# %%
self2self_rows = (
    predicted_cells.species == "mouse"
) & predicted_cells.index.str.startswith("MACA_18m_M_LUNG_52")
print(self2self_rows.sum())
# Out:
# 35160

# %%
predicted_cells = predicted_cells.loc[~self2self_rows]

# %% [markdown]
# ## Add predicted compartment

# %%
predicted_cells["predicted_compartment"] = predicted_cells["predicted_celltype"].map(
    broad_to_compartment
)
predicted_cells["groundtruth_compartment"] = predicted_cells["groundtruth_celltype"].map(
    broad_to_compartment
)

# %%
# predicted_cells.to_parq

# %% [markdown]
# ## Add `database_method` column for containment vs similarity

# %%
predicted_cells['database_method'] = predicted_cells.database_type.astype(str) + ': ' + predicted_cells.search_method.astype(str)

# %%
predicted_cells_min_5_percent = predicted_cells.query(
    'database_type == "min-5-percent-shared-kmers-remove-common-kmers" '
    'and search_method == "similarity_abundance"'
)
describe(predicted_cells_min_5_percent)
# Out:
# (84753, 43)
# --- First 5 entries ---
#                                       similarity mouse1_broad_group  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.086712             T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.119992             T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.114376             T cell
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT    0.181781             B cell
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT    0.170558             B cell
#
#                                              search_method  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  similarity_abundance
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  similarity_abundance
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  similarity_abundance
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT  similarity_abundance
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT  similarity_abundance
#
#                                                                        database_type  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-5-percent-shared-kmers-remove-common-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-5-percent-shared-kmers-remove-common-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-5-percent-shared-kmers-remove-common-kmers
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT  min-5-percent-shared-kmers-remove-common-kmers
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT  min-5-percent-shared-kmers-remove-common-kmers
#
#                                                                   sketch_id  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA      alphabet-DNA__ksize-21__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  alphabet-dayhoff__ksize-51__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  alphabet-protein__ksize-30__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT      alphabet-DNA__ksize-21__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT  alphabet-dayhoff__ksize-51__scaled-10
#
#                                      mol_or_alpha alphabet  ksize  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet      DNA     21
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet  dayhoff     51
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet  protein     30
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT     alphabet      DNA     21
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT     alphabet  dayhoff     51
#
#                                      sketch_style  sketch_value  ...  \
# query_cell_id                                                    ...
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10  ...
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10  ...
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10  ...
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT       scaled            10  ...
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT       scaled            10  ...
#
#                                      bat_narrow_group bat_broad_group  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              NaN             NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              NaN             NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              NaN             NaN
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT              NaN             NaN
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT              NaN             NaN
#
#                                      bat_compartment_group human_channel  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                   NaN           NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                   NaN           NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                   NaN           NaN
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT                   NaN           NaN
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT                   NaN           NaN
#
#                                      human_cell_ontology_class  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                       NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                       NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                       NaN
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT                       NaN
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT                       NaN
#
#                                      human_narrow_group human_broad_group  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                NaN               NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                NaN               NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                NaN               NaN
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT                NaN               NaN
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT                NaN               NaN
#
#                                      human_compartment_group  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                     NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                     NaN
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                     NaN
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT                     NaN
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT                     NaN
#
#                                      predicted_compartment  \
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              lymphoid
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              lymphoid
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              lymphoid
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT              lymphoid
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT              lymphoid
#
#                                      groundtruth_compartment
# query_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                lymphoid
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                lymphoid
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                lymphoid
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT                lymphoid
# MACA_18m_F_LUNG_51__AAACCTGGTGTGGTTT                lymphoid
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Write selected database type and search method to file

# %%
predicted_cells_min_5_percent.to_parquet(
    os.path.join(sig_outdir_base, "aggregated-predicted-cells.parquet")
)

# %%
1+1
# Out:
# 2

# %%
predicted_cells_min_5_percent.search_method.value_counts()
# Out:
# similarity_abundance    84753
# Name: search_method, dtype: int64
