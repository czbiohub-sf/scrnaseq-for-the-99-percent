# %%
import pandas as pd

import scanpy as sc
import sourmash

# %% [markdown]
# ### Clean batbam chanel metadata file to join onto adata

# %%
bam_channel_metadata = pd.read_csv('/home/olga/data_lg/data_sm_copy/batlas/Bat_Bams/metadata.csv')

# %%
# check column names have no spaces
bam_channel_metadata.columns.values
# Out:
# array(['Folder', 'Sex', 'Tissue', 'Animal ID'], dtype=object)

# %%
print(bam_channel_metadata.shape)
bam_channel_metadata.head()
# Out:
# (34, 4)
#      Folder Sex       Tissue  Animal ID
# 0   bat2-BL   M      bladder          2
# 1   bat2-BM   M  bone marrow          2
# 2   bat2-BR   M        brain          2
# 3  bat2-FTB   M    brown fat          2
# 4   bat2-KD   M       kidney          2

# %%
# add on missing metadata

from io import StringIO

s = """Folder,Animal ID,Tissue,Sex
bat2-FTW,2,white fat,M
bat2-CO,2,colon,M
bat3-FTB,3,brown fat,M
bat3-FTW,3,white fat,M
"""

df = pd.read_csv(StringIO(s))
# print(df.shape)
# df.head()

bam_channel_metadata_full = pd.concat([
    bam_channel_metadata, 
    df,
])

print(bam_channel_metadata_full.shape)
bam_channel_metadata_full.head()
# Out:
# (38, 4)
#      Folder Sex       Tissue  Animal ID
# 0   bat2-BL   M      bladder          2
# 1   bat2-BM   M  bone marrow          2
# 2   bat2-BR   M        brain          2
# 3  bat2-FTB   M    brown fat          2
# 4   bat2-KD   M       kidney          2

# %%
bat_metadata_index = bam_channel_metadata_full.set_index(["Animal ID", "Tissue", "Sex"])
bat_metadata_index.shape
bat_metadata_index.head()
# Out:
#                              Folder
# Animal ID Tissue      Sex
# 2         bladder     M     bat2-BL
#           bone marrow M     bat2-BM
#           brain       M     bat2-BR
#           brown fat   M    bat2-FTB
#           kidney      M     bat2-KD

# %% [markdown]
# ### Read in and clean adata

# %%
ls -lha /home/olga/data_lg/data_sm_copy/batlas/
# Out:
# total 22G
# drwxr-xr-x  4 olga czb  4.0K May 12 15:05 ./
# drwxrwxrwx 34 1004 root 8.0K May  5 08:36 ../
# drwxr-xr-x  2 olga czb  4.0K Oct 23  2020 .nextflow/
# -rw-r--r--  1 olga czb  1.1K Oct 23  2020 .nextflow.log
# drwxrwxrwx  2 olga czb  4.0K May 11 16:40 Bat_Bams/
# -rw-r--r--  1 olga czb  638M Sep 23  2020 baca-droplet-pre-processed.h5ad
# -rw-r--r--  1 olga czb  618M Sep 23  2020 baca-droplet-raw.h5ad
# -rw-r--r--  1 olga czb  6.5G May 12 15:06 bat_82k_cells.h5ad
# -rw-r--r--  1 olga czb   13M Sep 28  2020 bat_annotate.csv
# -rw-r--r--  1 olga czb  7.2G Sep 23  2020 bat_normalized_count.csv
# -rw-r--r--  1 olga czb  266M Oct 12  2020 bat_normalized_count.csv.tar.gz
# -rw-r--r--  1 olga czb  6.5G Sep 23  2020 bat_raw_counts.csv
# -rw-r--r--  1 olga czb  237M Oct 16  2020 bat_raw_counts.csv.tar.gz
# -rw-r--r--  1 olga czb     0 Jul  1  2020 rsync.log
# -rw-r--r--  1 olga czb   12M Sep 23  2020 scanpy-baca.ipynb
# -rw-r--r--  1 olga czb  1.5K Jul  1  2020 wang-lab-paths--paths-only.txt
# -rw-r--r--  1 olga czb  2.0K Jul  1  2020 wang-lab-paths--paths-only.txt~
# -rw-r--r--  1 olga czb  2.0K Jul  1  2020 wang-lab-paths.txt

# %%
ls -lha ~/data_lg/data_sm_copy/immune-evolution/data-objects/bat
# Out:
# total 8.3G
# drwxrwxr-x 2 phoenix czb 4.0K Feb  3 09:48 ./
# drwxrwxr-x 6 phoenix czb 4.0K Mar 31 09:03 ../
# -rw-r--r-- 1 olga    czb 6.5G Oct 16  2020 bat_82k_cells.h5ad
# -rw-r--r-- 1 olga    czb 692M Oct 16  2020 bat_82k_cells__lung_only.h5ad
# -rw-r--r-- 1 olga    czb 762K Feb  3 09:48 bat_lung__one2one_orthologs_var.csv
# -rw-r--r-- 1 phoenix czb 496M Oct  8  2020 bat_subset_w_shared_one2one_orthologs_human_lemur_mouse_bat.h5ad
# -rw-r--r-- 1 phoenix czb  48M Oct  8  2020 bat_subset_w_shared_one2one_orthologs_human_lemur_mouse_bat__lung_only.h5ad
# -rw-r--r-- 1 phoenix czb 623M Oct  8  2020 bat_with_cell_type_annotations.h5ad

# %%
# cp ~/data_lg/data_sm_copy/immune-evolution/data-objects/bat/bat_82k_cells.h5ad /home/olga/data_lg/data_sm_copy/batlas/

# %%
h5ad = '/home/olga/data_lg/data_sm_copy/batlas/bat_82k_cells.h5ad'
adata = sc.read(h5ad)
adata
# Out:
# AnnData object with n_obs × n_vars = 82924 × 20854
#     obs: 'animalID', 'batch', 'sex', 'tissue', 'method', 'n_genes', 'n_counts', 'louvain', 'clustertype', 'cluster', 'celltype', 'celltype_tiss', 'clustercellnumber', 'newcelltype', 'clustertonumber', 'tissue_lower', 'sex_abbrev', 'channel', 'cell_barcode', 'cell_id'

# %%
adata.obs.head()
# Out:
#                       animalID  batch   sex       tissue method  n_genes  \
# index
# AAACCTGAGAGGGCTT-1-0         3      0  male  Whole Blood    10x     2370
# AAACGGGAGACGCAAC-1-0         3      0  male  Whole Blood    10x     1196
# AAAGATGTCAGCTTAG-1-0         3      0  male  Whole Blood    10x     2647
# AAAGCAAAGCCCAACC-1-0         3      0  male  Whole Blood    10x      556
# AAAGCAATCAACACCA-1-0         3      0  male  Whole Blood    10x      661
#
#                       n_counts  louvain             clustertype  \
# index
# AAACCTGAGAGGGCTT-1-0    6673.0        0                  T cell
# AAACGGGAGACGCAAC-1-0    2132.0       12  Non-classical monocyte
# AAAGATGTCAGCTTAG-1-0    7631.0        8      Classical monocyte
# AAAGCAAAGCCCAACC-1-0    1048.0        5      Classical monocyte
# AAAGCAATCAACACCA-1-0    1256.0        0                  T cell
#
#                                                  cluster     celltype  \
# index
# AAACCTGAGAGGGCTT-1-0                  Whole Blood_T cell  Immune cell
# AAACGGGAGACGCAAC-1-0  Whole Blood_Non-classical monocyte  Immune cell
# AAAGATGTCAGCTTAG-1-0      Whole Blood_Classical monocyte  Immune cell
# AAAGCAAAGCCCAACC-1-0      Whole Blood_Classical monocyte  Immune cell
# AAAGCAATCAACACCA-1-0                  Whole Blood_T cell  Immune cell
#
#                                 celltype_tiss  clustercellnumber  \
# index
# AAACCTGAGAGGGCTT-1-0  Whole Blood_Immune cell                354
# AAACGGGAGACGCAAC-1-0  Whole Blood_Immune cell                488
# AAAGATGTCAGCTTAG-1-0  Whole Blood_Immune cell                229
# AAAGCAAAGCCCAACC-1-0  Whole Blood_Immune cell                229
# AAAGCAATCAACACCA-1-0  Whole Blood_Immune cell                354
#
#                             newcelltype  clustertonumber tissue_lower  \
# index
# AAACCTGAGAGGGCTT-1-0             T cell              181  whole blood
# AAACGGGAGACGCAAC-1-0  Other immune cell              180  whole blood
# AAAGATGTCAGCTTAG-1-0  Other immune cell              178  whole blood
# AAAGCAAAGCCCAACC-1-0  Other immune cell              178  whole blood
# AAAGCAATCAACACCA-1-0             T cell              181  whole blood
#
#                      sex_abbrev  channel      cell_barcode  \
# index
# AAACCTGAGAGGGCTT-1-0          M  bat3-WB  AAACCTGAGAGGGCTT
# AAACGGGAGACGCAAC-1-0          M  bat3-WB  AAACGGGAGACGCAAC
# AAAGATGTCAGCTTAG-1-0          M  bat3-WB  AAAGATGTCAGCTTAG
# AAAGCAAAGCCCAACC-1-0          M  bat3-WB  AAAGCAAAGCCCAACC
# AAAGCAATCAACACCA-1-0          M  bat3-WB  AAAGCAATCAACACCA
#
#                                         cell_id
# index
# AAACCTGAGAGGGCTT-1-0  bat3-WB__AAACCTGAGAGGGCTT
# AAACGGGAGACGCAAC-1-0  bat3-WB__AAACGGGAGACGCAAC
# AAAGATGTCAGCTTAG-1-0  bat3-WB__AAAGATGTCAGCTTAG
# AAAGCAAAGCCCAACC-1-0  bat3-WB__AAAGCAAAGCCCAACC
# AAAGCAATCAACACCA-1-0  bat3-WB__AAAGCAATCAACACCA

# %%
adata.var.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [GORAB, PRRX1, MROH9, FMO3, FMO2]

# %%
# "ADAR2" in adata.var.index
# Out:
# False

# %%
# clean up adata obs tissue names to match bam_channel_metadata
adata.obs["tissue_lower"] = adata.obs["tissue"].str.lower()
adata.obs["sex_abbrev"] = adata.obs["sex"].str[0].str.upper()
adata.obs["animalID"] = adata.obs["animalID"].astype(int)
adata.obs.head()
# Out:
#                       animalID  batch   sex       tissue method  n_genes  \
# index
# AAACCTGAGAGGGCTT-1-0         3      0  male  Whole Blood    10x     2370
# AAACGGGAGACGCAAC-1-0         3      0  male  Whole Blood    10x     1196
# AAAGATGTCAGCTTAG-1-0         3      0  male  Whole Blood    10x     2647
# AAAGCAAAGCCCAACC-1-0         3      0  male  Whole Blood    10x      556
# AAAGCAATCAACACCA-1-0         3      0  male  Whole Blood    10x      661
#
#                       n_counts  louvain             clustertype  \
# index
# AAACCTGAGAGGGCTT-1-0    6673.0        0                  T cell
# AAACGGGAGACGCAAC-1-0    2132.0       12  Non-classical monocyte
# AAAGATGTCAGCTTAG-1-0    7631.0        8      Classical monocyte
# AAAGCAAAGCCCAACC-1-0    1048.0        5      Classical monocyte
# AAAGCAATCAACACCA-1-0    1256.0        0                  T cell
#
#                                                  cluster     celltype  \
# index
# AAACCTGAGAGGGCTT-1-0                  Whole Blood_T cell  Immune cell
# AAACGGGAGACGCAAC-1-0  Whole Blood_Non-classical monocyte  Immune cell
# AAAGATGTCAGCTTAG-1-0      Whole Blood_Classical monocyte  Immune cell
# AAAGCAAAGCCCAACC-1-0      Whole Blood_Classical monocyte  Immune cell
# AAAGCAATCAACACCA-1-0                  Whole Blood_T cell  Immune cell
#
#                                 celltype_tiss  clustercellnumber  \
# index
# AAACCTGAGAGGGCTT-1-0  Whole Blood_Immune cell                354
# AAACGGGAGACGCAAC-1-0  Whole Blood_Immune cell                488
# AAAGATGTCAGCTTAG-1-0  Whole Blood_Immune cell                229
# AAAGCAAAGCCCAACC-1-0  Whole Blood_Immune cell                229
# AAAGCAATCAACACCA-1-0  Whole Blood_Immune cell                354
#
#                             newcelltype  clustertonumber tissue_lower  \
# index
# AAACCTGAGAGGGCTT-1-0             T cell              181  whole blood
# AAACGGGAGACGCAAC-1-0  Other immune cell              180  whole blood
# AAAGATGTCAGCTTAG-1-0  Other immune cell              178  whole blood
# AAAGCAAAGCCCAACC-1-0  Other immune cell              178  whole blood
# AAAGCAATCAACACCA-1-0             T cell              181  whole blood
#
#                      sex_abbrev  channel      cell_barcode  \
# index
# AAACCTGAGAGGGCTT-1-0          M  bat3-WB  AAACCTGAGAGGGCTT
# AAACGGGAGACGCAAC-1-0          M  bat3-WB  AAACGGGAGACGCAAC
# AAAGATGTCAGCTTAG-1-0          M  bat3-WB  AAAGATGTCAGCTTAG
# AAAGCAAAGCCCAACC-1-0          M  bat3-WB  AAAGCAAAGCCCAACC
# AAAGCAATCAACACCA-1-0          M  bat3-WB  AAAGCAATCAACACCA
#
#                                         cell_id
# index
# AAACCTGAGAGGGCTT-1-0  bat3-WB__AAACCTGAGAGGGCTT
# AAACGGGAGACGCAAC-1-0  bat3-WB__AAACGGGAGACGCAAC
# AAAGATGTCAGCTTAG-1-0  bat3-WB__AAAGATGTCAGCTTAG
# AAAGCAAAGCCCAACC-1-0  bat3-WB__AAAGCAAAGCCCAACC
# AAAGCAATCAACACCA-1-0  bat3-WB__AAAGCAATCAACACCA

# %%
adata_joined_bat_bam = adata.obs.join(
    bat_metadata_index, 
    on = ["animalID", "tissue_lower", "sex_abbrev"],
)

print(adata_joined_bat_bam.shape)
adata_joined_bat_bam.head()
# Out:
# (82924, 21)
#                       animalID  batch   sex       tissue method  n_genes  \
# index
# AAACCTGAGAGGGCTT-1-0         3      0  male  Whole Blood    10x     2370
# AAACGGGAGACGCAAC-1-0         3      0  male  Whole Blood    10x     1196
# AAAGATGTCAGCTTAG-1-0         3      0  male  Whole Blood    10x     2647
# AAAGCAAAGCCCAACC-1-0         3      0  male  Whole Blood    10x      556
# AAAGCAATCAACACCA-1-0         3      0  male  Whole Blood    10x      661
#
#                       n_counts  louvain             clustertype  \
# index
# AAACCTGAGAGGGCTT-1-0    6673.0        0                  T cell
# AAACGGGAGACGCAAC-1-0    2132.0       12  Non-classical monocyte
# AAAGATGTCAGCTTAG-1-0    7631.0        8      Classical monocyte
# AAAGCAAAGCCCAACC-1-0    1048.0        5      Classical monocyte
# AAAGCAATCAACACCA-1-0    1256.0        0                  T cell
#
#                                                  cluster  ...  \
# index                                                     ...
# AAACCTGAGAGGGCTT-1-0                  Whole Blood_T cell  ...
# AAACGGGAGACGCAAC-1-0  Whole Blood_Non-classical monocyte  ...
# AAAGATGTCAGCTTAG-1-0      Whole Blood_Classical monocyte  ...
# AAAGCAAAGCCCAACC-1-0      Whole Blood_Classical monocyte  ...
# AAAGCAATCAACACCA-1-0                  Whole Blood_T cell  ...
#
#                                 celltype_tiss clustercellnumber  \
# index
# AAACCTGAGAGGGCTT-1-0  Whole Blood_Immune cell               354
# AAACGGGAGACGCAAC-1-0  Whole Blood_Immune cell               488
# AAAGATGTCAGCTTAG-1-0  Whole Blood_Immune cell               229
# AAAGCAAAGCCCAACC-1-0  Whole Blood_Immune cell               229
# AAAGCAATCAACACCA-1-0  Whole Blood_Immune cell               354
#
#                             newcelltype clustertonumber  tissue_lower  \
# index
# AAACCTGAGAGGGCTT-1-0             T cell             181   whole blood
# AAACGGGAGACGCAAC-1-0  Other immune cell             180   whole blood
# AAAGATGTCAGCTTAG-1-0  Other immune cell             178   whole blood
# AAAGCAAAGCCCAACC-1-0  Other immune cell             178   whole blood
# AAAGCAATCAACACCA-1-0             T cell             181   whole blood
#
#                      sex_abbrev  channel      cell_barcode  \
# index
# AAACCTGAGAGGGCTT-1-0          M  bat3-WB  AAACCTGAGAGGGCTT
# AAACGGGAGACGCAAC-1-0          M  bat3-WB  AAACGGGAGACGCAAC
# AAAGATGTCAGCTTAG-1-0          M  bat3-WB  AAAGATGTCAGCTTAG
# AAAGCAAAGCCCAACC-1-0          M  bat3-WB  AAAGCAAAGCCCAACC
# AAAGCAATCAACACCA-1-0          M  bat3-WB  AAAGCAATCAACACCA
#
#                                         cell_id   Folder
# index
# AAACCTGAGAGGGCTT-1-0  bat3-WB__AAACCTGAGAGGGCTT  bat3-WB
# AAACGGGAGACGCAAC-1-0  bat3-WB__AAACGGGAGACGCAAC  bat3-WB
# AAAGATGTCAGCTTAG-1-0  bat3-WB__AAAGATGTCAGCTTAG  bat3-WB
# AAAGCAAAGCCCAACC-1-0  bat3-WB__AAAGCAAAGCCCAACC  bat3-WB
# AAAGCAATCAACACCA-1-0  bat3-WB__AAAGCAATCAACACCA  bat3-WB
#
# [5 rows x 21 columns]

# %%
# check where folders are null
null_columns = adata_joined_bat_bam[adata_joined_bat_bam.Folder.isnull()]
null_columns.groupby(by=["animalID", "tissue"], observed=True).size()
# Out:
# animalID  tissue
# 2         Brown Adipose Tissue    3134
# 3         Brown Adipose Tissue    5366
#           White Adipose Tissue    2127
# dtype: int64

# %% [markdown]
# ### make new adata columns

# %%
# make channel barcode ex: bat3-WB__AAAAAAAATTTTT in adata.obs
adata_joined_bat_bam["bam_channel_barcode"] = adata_joined_bat_bam.Folder + "__" + adata_joined_bat_bam.index
print(adata_joined_bat_bam.shape)
adata_joined_bat_bam.head()
# Out:
# (82924, 22)
#                       animalID  batch   sex       tissue method  n_genes  \
# index
# AAACCTGAGAGGGCTT-1-0         3      0  male  Whole Blood    10x     2370
# AAACGGGAGACGCAAC-1-0         3      0  male  Whole Blood    10x     1196
# AAAGATGTCAGCTTAG-1-0         3      0  male  Whole Blood    10x     2647
# AAAGCAAAGCCCAACC-1-0         3      0  male  Whole Blood    10x      556
# AAAGCAATCAACACCA-1-0         3      0  male  Whole Blood    10x      661
#
#                       n_counts  louvain             clustertype  \
# index
# AAACCTGAGAGGGCTT-1-0    6673.0        0                  T cell
# AAACGGGAGACGCAAC-1-0    2132.0       12  Non-classical monocyte
# AAAGATGTCAGCTTAG-1-0    7631.0        8      Classical monocyte
# AAAGCAAAGCCCAACC-1-0    1048.0        5      Classical monocyte
# AAAGCAATCAACACCA-1-0    1256.0        0                  T cell
#
#                                                  cluster  ...  \
# index                                                     ...
# AAACCTGAGAGGGCTT-1-0                  Whole Blood_T cell  ...
# AAACGGGAGACGCAAC-1-0  Whole Blood_Non-classical monocyte  ...
# AAAGATGTCAGCTTAG-1-0      Whole Blood_Classical monocyte  ...
# AAAGCAAAGCCCAACC-1-0      Whole Blood_Classical monocyte  ...
# AAAGCAATCAACACCA-1-0                  Whole Blood_T cell  ...
#
#                      clustercellnumber        newcelltype  clustertonumber  \
# index
# AAACCTGAGAGGGCTT-1-0               354             T cell              181
# AAACGGGAGACGCAAC-1-0               488  Other immune cell              180
# AAAGATGTCAGCTTAG-1-0               229  Other immune cell              178
# AAAGCAAAGCCCAACC-1-0               229  Other immune cell              178
# AAAGCAATCAACACCA-1-0               354             T cell              181
#
#                      tissue_lower  sex_abbrev  channel      cell_barcode  \
# index
# AAACCTGAGAGGGCTT-1-0  whole blood           M  bat3-WB  AAACCTGAGAGGGCTT
# AAACGGGAGACGCAAC-1-0  whole blood           M  bat3-WB  AAACGGGAGACGCAAC
# AAAGATGTCAGCTTAG-1-0  whole blood           M  bat3-WB  AAAGATGTCAGCTTAG
# AAAGCAAAGCCCAACC-1-0  whole blood           M  bat3-WB  AAAGCAAAGCCCAACC
# AAAGCAATCAACACCA-1-0  whole blood           M  bat3-WB  AAAGCAATCAACACCA
#
#                                         cell_id   Folder  \
# index
# AAACCTGAGAGGGCTT-1-0  bat3-WB__AAACCTGAGAGGGCTT  bat3-WB
# AAACGGGAGACGCAAC-1-0  bat3-WB__AAACGGGAGACGCAAC  bat3-WB
# AAAGATGTCAGCTTAG-1-0  bat3-WB__AAAGATGTCAGCTTAG  bat3-WB
# AAAGCAAAGCCCAACC-1-0  bat3-WB__AAAGCAAAGCCCAACC  bat3-WB
# AAAGCAATCAACACCA-1-0  bat3-WB__AAAGCAATCAACACCA  bat3-WB
#
#                                 bam_channel_barcode
# index
# AAACCTGAGAGGGCTT-1-0  bat3-WB__AAACCTGAGAGGGCTT-1-0
# AAACGGGAGACGCAAC-1-0  bat3-WB__AAACGGGAGACGCAAC-1-0
# AAAGATGTCAGCTTAG-1-0  bat3-WB__AAAGATGTCAGCTTAG-1-0
# AAAGCAAAGCCCAACC-1-0  bat3-WB__AAAGCAAAGCCCAACC-1-0
# AAAGCAATCAACACCA-1-0  bat3-WB__AAAGCAATCAACACCA-1-0
#
# [5 rows x 22 columns]

# %%
bat_annotate = pd.read_csv("/home/olga/data_lg/data_sm_copy/batlas/bat_annotate.csv", index_col=0)
print(bat_annotate.shape)
bat_annotate.head()
# Out:
# (82924, 15)
#                       animalID  batch   sex       tissue method  n_genes  \
# index
# AAACCTGAGAGGGCTT-1-0         3      0  male  Whole Blood    10x     2370
# AAACGGGAGACGCAAC-1-0         3      0  male  Whole Blood    10x     1196
# AAAGATGTCAGCTTAG-1-0         3      0  male  Whole Blood    10x     2647
# AAAGCAAAGCCCAACC-1-0         3      0  male  Whole Blood    10x      556
# AAAGCAATCAACACCA-1-0         3      0  male  Whole Blood    10x      661
#
#                       n_counts  louvain             clustertype  \
# index
# AAACCTGAGAGGGCTT-1-0    6673.0        0                  T cell
# AAACGGGAGACGCAAC-1-0    2132.0       12  Non-classical monocyte
# AAAGATGTCAGCTTAG-1-0    7631.0        8      Classical monocyte
# AAAGCAAAGCCCAACC-1-0    1048.0        5      Classical monocyte
# AAAGCAATCAACACCA-1-0    1256.0        0                  T cell
#
#                                                  cluster     celltype  \
# index
# AAACCTGAGAGGGCTT-1-0                  Whole Blood_T cell  Immune cell
# AAACGGGAGACGCAAC-1-0  Whole Blood_Non-classical monocyte  Immune cell
# AAAGATGTCAGCTTAG-1-0      Whole Blood_Classical monocyte  Immune cell
# AAAGCAAAGCCCAACC-1-0      Whole Blood_Classical monocyte  Immune cell
# AAAGCAATCAACACCA-1-0                  Whole Blood_T cell  Immune cell
#
#                                 celltype_tiss  clustercellnumber  \
# index
# AAACCTGAGAGGGCTT-1-0  Whole Blood_Immune cell                354
# AAACGGGAGACGCAAC-1-0  Whole Blood_Immune cell                488
# AAAGATGTCAGCTTAG-1-0  Whole Blood_Immune cell                229
# AAAGCAAAGCCCAACC-1-0  Whole Blood_Immune cell                229
# AAAGCAATCAACACCA-1-0  Whole Blood_Immune cell                354
#
#                             newcelltype  clustertonumber
# index
# AAACCTGAGAGGGCTT-1-0             T cell              181
# AAACGGGAGACGCAAC-1-0  Other immune cell              180
# AAAGATGTCAGCTTAG-1-0  Other immune cell              178
# AAAGCAAAGCCCAACC-1-0  Other immune cell              178
# AAAGCAATCAACACCA-1-0             T cell              181

# %%
adata_joined_bat_bam
# Out:
#                        animalID  batch   sex       tissue method  n_genes  \
# index
# AAACCTGAGAGGGCTT-1-0          3      0  male  Whole Blood    10x     2370
# AAACGGGAGACGCAAC-1-0          3      0  male  Whole Blood    10x     1196
# AAAGATGTCAGCTTAG-1-0          3      0  male  Whole Blood    10x     2647
# AAAGCAAAGCCCAACC-1-0          3      0  male  Whole Blood    10x      556
# AAAGCAATCAACACCA-1-0          3      0  male  Whole Blood    10x      661
# ...                         ...    ...   ...          ...    ...      ...
# TTTGCGCAGGAGTTTA-1-33         3     33  male       Testis    10x      929
# TTTGCGCTCCCAAGTA-1-33         3     33  male       Testis    10x     1387
# TTTGGTTGTTAAGATG-1-33         3     33  male       Testis    10x     1505
# TTTGTCAGTGCAGTAG-1-33         3     33  male       Testis    10x     2340
# TTTGTCATCAGTGTTG-1-33         3     33  male       Testis    10x     1061
#
#                        n_counts  louvain               clustertype  \
# index
# AAACCTGAGAGGGCTT-1-0     6673.0        0                    T cell
# AAACGGGAGACGCAAC-1-0     2132.0       12    Non-classical monocyte
# AAAGATGTCAGCTTAG-1-0     7631.0        8        Classical monocyte
# AAAGCAAAGCCCAACC-1-0     1048.0        5        Classical monocyte
# AAAGCAATCAACACCA-1-0     1256.0        0                    T cell
# ...                         ...      ...                       ...
# TTTGCGCAGGAGTTTA-1-33    1765.0       22             Myofibroblast
# TTTGCGCTCCCAAGTA-1-33    2459.0        3               Leydig cell
# TTTGGTTGTTAAGATG-1-33    2660.0        3               Leydig cell
# TTTGTCAGTGCAGTAG-1-33    6230.0        3               Leydig cell
# TTTGTCATCAGTGTTG-1-33    1676.0        3  Spermatogonial stem cell
#
#                                                   cluster  ...  \
# index                                                      ...
# AAACCTGAGAGGGCTT-1-0                   Whole Blood_T cell  ...
# AAACGGGAGACGCAAC-1-0   Whole Blood_Non-classical monocyte  ...
# AAAGATGTCAGCTTAG-1-0       Whole Blood_Classical monocyte  ...
# AAAGCAAAGCCCAACC-1-0       Whole Blood_Classical monocyte  ...
# AAAGCAATCAACACCA-1-0                   Whole Blood_T cell  ...
# ...                                                   ...  ...
# TTTGCGCAGGAGTTTA-1-33                Testis_Myofibroblast  ...
# TTTGCGCTCCCAAGTA-1-33                  Testis_Leydig cell  ...
# TTTGGTTGTTAAGATG-1-33                  Testis_Leydig cell  ...
# TTTGTCAGTGCAGTAG-1-33                  Testis_Leydig cell  ...
# TTTGTCATCAGTGTTG-1-33     Testis_Spermatogonial stem cell  ...
#
#                       clustercellnumber        newcelltype  clustertonumber  \
# index
# AAACCTGAGAGGGCTT-1-0                354             T cell              181
# AAACGGGAGACGCAAC-1-0                488  Other immune cell              180
# AAAGATGTCAGCTTAG-1-0                229  Other immune cell              178
# AAAGCAAAGCCCAACC-1-0                229  Other immune cell              178
# AAAGCAATCAACACCA-1-0                354             T cell              181
# ...                                 ...                ...              ...
# TTTGCGCAGGAGTTTA-1-33               176   Mesenchymal cell              133
# TTTGCGCTCCCAAGTA-1-33               748   Mesenchymal cell              131
# TTTGGTTGTTAAGATG-1-33               748   Mesenchymal cell              131
# TTTGTCAGTGCAGTAG-1-33               748   Mesenchymal cell              131
# TTTGTCATCAGTGTTG-1-33               132          Stem cell              136
#
#                       tissue_lower  sex_abbrev  channel      cell_barcode  \
# index
# AAACCTGAGAGGGCTT-1-0   whole blood           M  bat3-WB  AAACCTGAGAGGGCTT
# AAACGGGAGACGCAAC-1-0   whole blood           M  bat3-WB  AAACGGGAGACGCAAC
# AAAGATGTCAGCTTAG-1-0   whole blood           M  bat3-WB  AAAGATGTCAGCTTAG
# AAAGCAAAGCCCAACC-1-0   whole blood           M  bat3-WB  AAAGCAAAGCCCAACC
# AAAGCAATCAACACCA-1-0   whole blood           M  bat3-WB  AAAGCAATCAACACCA
# ...                            ...         ...      ...               ...
# TTTGCGCAGGAGTTTA-1-33       testis           M  bat3-TS  TTTGCGCAGGAGTTTA
# TTTGCGCTCCCAAGTA-1-33       testis           M  bat3-TS  TTTGCGCTCCCAAGTA
# TTTGGTTGTTAAGATG-1-33       testis           M  bat3-TS  TTTGGTTGTTAAGATG
# TTTGTCAGTGCAGTAG-1-33       testis           M  bat3-TS  TTTGTCAGTGCAGTAG
# TTTGTCATCAGTGTTG-1-33       testis           M  bat3-TS  TTTGTCATCAGTGTTG
#
#                                          cell_id   Folder  \
# index
# AAACCTGAGAGGGCTT-1-0   bat3-WB__AAACCTGAGAGGGCTT  bat3-WB
# AAACGGGAGACGCAAC-1-0   bat3-WB__AAACGGGAGACGCAAC  bat3-WB
# AAAGATGTCAGCTTAG-1-0   bat3-WB__AAAGATGTCAGCTTAG  bat3-WB
# AAAGCAAAGCCCAACC-1-0   bat3-WB__AAAGCAAAGCCCAACC  bat3-WB
# AAAGCAATCAACACCA-1-0   bat3-WB__AAAGCAATCAACACCA  bat3-WB
# ...                                          ...      ...
# TTTGCGCAGGAGTTTA-1-33  bat3-TS__TTTGCGCAGGAGTTTA  bat3-TS
# TTTGCGCTCCCAAGTA-1-33  bat3-TS__TTTGCGCTCCCAAGTA  bat3-TS
# TTTGGTTGTTAAGATG-1-33  bat3-TS__TTTGGTTGTTAAGATG  bat3-TS
# TTTGTCAGTGCAGTAG-1-33  bat3-TS__TTTGTCAGTGCAGTAG  bat3-TS
# TTTGTCATCAGTGTTG-1-33  bat3-TS__TTTGTCATCAGTGTTG  bat3-TS
#
#                                   bam_channel_barcode
# index
# AAACCTGAGAGGGCTT-1-0    bat3-WB__AAACCTGAGAGGGCTT-1-0
# AAACGGGAGACGCAAC-1-0    bat3-WB__AAACGGGAGACGCAAC-1-0
# AAAGATGTCAGCTTAG-1-0    bat3-WB__AAAGATGTCAGCTTAG-1-0
# AAAGCAAAGCCCAACC-1-0    bat3-WB__AAAGCAAAGCCCAACC-1-0
# AAAGCAATCAACACCA-1-0    bat3-WB__AAAGCAATCAACACCA-1-0
# ...                                               ...
# TTTGCGCAGGAGTTTA-1-33  bat3-TS__TTTGCGCAGGAGTTTA-1-33
# TTTGCGCTCCCAAGTA-1-33  bat3-TS__TTTGCGCTCCCAAGTA-1-33
# TTTGGTTGTTAAGATG-1-33  bat3-TS__TTTGGTTGTTAAGATG-1-33
# TTTGTCAGTGCAGTAG-1-33  bat3-TS__TTTGTCAGTGCAGTAG-1-33
# TTTGTCATCAGTGTTG-1-33  bat3-TS__TTTGTCATCAGTGTTG-1-33
#
# [82924 rows x 22 columns]

# %%
adata_joined_bat_bam.obs.join(
    bat_annotate,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-4788a2a74ac6> in <module>
#       1 adata_joined_bat_bam.join(
# ----> 2     bat_annotate,
#       3 )
#
# ~/miniconda3/envs/immune-evolution/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7868         """
#    7869         return self._join_compat(
# -> 7870             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7871         )
#    7872
#
# ~/miniconda3/envs/immune-evolution/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7891                 right_index=True,
#    7892                 suffixes=(lsuffix, rsuffix),
# -> 7893                 sort=sort,
#    7894             )
#    7895         else:
#
# ~/miniconda3/envs/immune-evolution/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~/miniconda3/envs/immune-evolution/lib/python3.7/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     669
#     670         llabels, rlabels = _items_overlap_with_suffix(
# --> 671             self.left._info_axis, self.right._info_axis, self.suffixes
#     672         )
#     673
#
# ~/miniconda3/envs/immune-evolution/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2089
#    2090     if not lsuffix and not rsuffix:
# -> 2091         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2092
#    2093     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['animalID', 'batch', 'sex', 'tissue', 'method', 'n_genes', 'n_counts',
#        'louvain', 'clustertype', 'cluster', 'celltype', 'celltype_tiss',
#        'clustercellnumber', 'newcelltype', 'clustertonumber'],
#       dtype='object')

# %%
adata_joined_bat_bam

# %%
# read in mouse human, lemur adata object and see what is similar between bat.obs.cluster_type and cell_ontology_class
adata_mhl = sc.read(
    "/home/olga/data_lg/data_sm_copy/tabula-microcebus/data-objects/cross-species/concatenated__human-lung--lemur-lung--mouse-lung__10x__one2one_orthologs__unified_compartments__bbknn.h5ad"
)
# Out:
# /home/phoenix/anaconda3/envs/scanpy_bat/lib/python3.7/site-packages/anndata/compat/__init__.py:161: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   FutureWarning,
# /home/phoenix/anaconda3/envs/scanpy_bat/lib/python3.7/site-packages/anndata/compat/__init__.py:161: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   FutureWarning,

# %%
print(adata_mhl)
# Out:
# AnnData object with n_obs × n_vars = 87909 × 13350
#     obs: 'age', 'cell_barcode', 'cell_ontology_class', 'cell_ontology_id', 'channel', 'free_annotation', 'individual', 'mouse.id', 'patient', 'possibly_contaminated_barcode', 'sample', 'sequencing_run', 'sex', 'species', 'species_batch', 'species_latin', 'tissue', 'narrow_group', 'broad_group', 'compartment_group', 'compartment_narrow', 'compartment_broad', 'compartment_broad_narrow', 'compartment_species', 'compartment_narrow_species', 'n_counts', 'log_counts', 'sqrt_counts', 'n_genes'
#     var: 'mouse_lemur__gene_name', 'mouse__gene_name', 'gene_ids-lemur', 'n_cells-mouse', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'age_colors', 'broad_group_colors', 'cell_ontology_class_colors', 'compartment_group_colors', 'individual_colors', 'narrow_group_colors', 'neighbors', 'pca', 'sex_colors', 'species_batch_colors', 'species_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
set(adata_mhl.obs.cell_ontology_class)
# Out:
# {'B cell',
#  'CD4-positive, alpha-beta T cell',
#  'CD8-positive, alpha-beta T cell',
#  'NK cell',
#  'T cell',
#  'adventitial cell',
#  'alveolar macrophage',
#  'bronchial smooth muscle cell',
#  'capillary endothelial cell',
#  'ciliated columnar cell of tracheobronchial tree',
#  'classical monocyte',
#  'conventional dendritic cell',
#  'endothelial cell of artery',
#  'endothelial cell of lymphatic vessel',
#  'fibroblast',
#  'fibroblast of lung',
#  'immature NK T cell',
#  'intermediate monocyte',
#  'lung ciliated cell',
#  'lung endothelial cell',
#  'lymphocyte',
#  'macrophage',
#  'mature NK T cell',
#  'monocyte',
#  'myeloid dendritic cell',
#  'myofibroblast cell',
#  'naive thymus-derived CD4-positive, alpha-beta T cell',
#  'naive thymus-derived CD8-positive, alpha-beta T cell',
#  'natural killer cell',
#  'non-classical monocyte',
#  'pericyte cell',
#  'plasma cell',
#  'plasmacytoid dendritic cell',
#  'pulmonary interstitial fibroblast',
#  'smooth muscle cell of the pulmonary artery',
#  'stromal cell',
#  'type II pneumocyte',
#  'vein endothelial cell'}
