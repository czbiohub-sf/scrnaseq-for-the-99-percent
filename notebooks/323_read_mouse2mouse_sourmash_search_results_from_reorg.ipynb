# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

import glob
import os
import re
import pandas as pd
pd.options.display.max_colwidth = 500
pd.options.display.max_columns = 50

import seaborn as sns
import sourmash
import scanpy as sc
from tqdm import tqdm
import kmermaid_utils
import sig_utils

from sourmash_search_utils import read_and_process_sourmash_search_results
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Constants (ksizes, scaled)

# %%
MOAR_KSIZES = list(range(21, 91, 3))

# %%
SCALED = 10

# %%
ls -lha
# Out:
# total 5.0K
# drwxr-xr-x 10 olga czb 4.0K Mar 27 13:48 ./
# drwxr-xr-x  4 olga czb 4.0K Feb 28 09:53 ../
# drwxr-xr-x 11 olga czb 4.0K Mar 27 13:38 0--train-mouse1/
# drwxr-xr-x  4 olga czb 4.0K Mar  5 14:16 1--test-mouse2/
# drwxr-xr-x  5 olga czb 4.0K Feb 28 16:48 2--search-results/
# drwxr-xr-x  5 olga czb 4.0K Mar 27 13:48 3-0--search-results--min-5-percent-shared-kmers/
# drwxr-xr-x  5 olga czb 4.0K Mar  5 14:16 3-0--search-results--remove_common/
# drwxr-xr-x  5 olga czb 4.0K Mar 27 13:48 3-1--search-results--min-10-percent-shared-kmers/
# drwxr-xr-x  5 olga czb 4.0K Mar  5 14:16 3-1--search-results--raw_merged/
# drwxr-xr-x  2 olga czb 4.0K Mar  5 14:48 4--aggregated-results/

# %%
mouse2mouse_dir = '/home/olga/data_sm/immune-evolution/kmer-signatures/0--mouse2mouse/1--mouse2mouse/'
# !ls -lha $mouse2mouse_dir
# Out:
# total 5.0K
# drwxr-xr-x 10 olga czb 4.0K Mar 27 13:48 .
# drwxr-xr-x  4 olga czb 4.0K Feb 28 09:53 ..
# drwxr-xr-x 11 olga czb 4.0K Mar 27 13:38 0--train-mouse1
# drwxr-xr-x  4 olga czb 4.0K Mar  5 14:16 1--test-mouse2
# drwxr-xr-x  5 olga czb 4.0K Feb 28 16:48 2--search-results
# drwxr-xr-x  5 olga czb 4.0K Mar 27 13:48 3-0--search-results--min-5-percent-shared-kmers
# drwxr-xr-x  5 olga czb 4.0K Mar  5 14:16 3-0--search-results--remove_common
# drwxr-xr-x  5 olga czb 4.0K Mar 27 13:48 3-1--search-results--min-10-percent-shared-kmers
# drwxr-xr-x  5 olga czb 4.0K Mar  5 14:16 3-1--search-results--raw_merged
# drwxr-xr-x  2 olga czb 4.0K Mar  5 14:48 4--aggregated-results

# %%
sig_outdir_base = "/home/olga/data_sm/immune-evolution/kmer-signatures"

mouse2mouse_dir = os.path.join(sig_outdir_base, "0--mouse2mouse", "1--mouse2mouse")


aggregated_results_dir = os.path.join(mouse2mouse_dir, "4--aggregated-results")
! mkdir -p $aggregated_results_dir

# %% [markdown]
# ## Def describe

# %%
def describe(df, random=False):
    print(df.shape)
    print("--- First 5 entries ---")
    display(df.head())
    if random:
        print('--- Random subset ---')
        display(df.sample(5))

# %% [markdown]
# ### Remove rogue TQDM instances

# %%
def remove_rogue_tqdm():
    import tqdm
    try:
        tqdm._instances.clear()
    except AttributeError:
        pass

# %% [markdown]
# ## Read one2one 5had

# %%
one2one = sc.read(
#     "/home/phoenix/data_sm/code/immune-evolution/h5ads/human-lemur-mouse-bat__lung_only_copy.h5ad"
    "/home/olga/data_sm/immune-evolution/h5ads/human-lemur-mouse-bat/human-lemur-mouse-bat__lung_only.h5ad"
)
one2one.obs = one2one.obs.reset_index().set_index('cell_id')
# one2one = one2one[one2one.obs.species_batch == 'mouse']

one2one.obs.head()
# Out:
#                                                   index  age  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  P2_1_AAACCTGAGAAACCAT-human-hlm  46y
# P2_1__AAATGCCAGATGAGAG  P2_1_AAATGCCAGATGAGAG-human-hlm  46y
# P2_1__AACACGTTCGATCCCT  P2_1_AACACGTTCGATCCCT-human-hlm  46y
# P2_1__AACACGTTCGCACTCT  P2_1_AACACGTTCGCACTCT-human-hlm  46y
# P2_1__AACCATGCAGCTCGCA  P2_1_AACCATGCAGCTCGCA-human-hlm  46y
#
#                             cell_barcode         cell_ontology_class  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  AAACCTGAGAAACCAT  capillary endothelial cell
# P2_1__AAATGCCAGATGAGAG  AAATGCCAGATGAGAG  capillary endothelial cell
# P2_1__AACACGTTCGATCCCT  AACACGTTCGATCCCT  capillary endothelial cell
# P2_1__AACACGTTCGCACTCT  AACACGTTCGCACTCT  capillary endothelial cell
# P2_1__AACCATGCAGCTCGCA  AACCATGCAGCTCGCA  capillary endothelial cell
#
#                        cell_ontology_id channel     free_annotation  \
# cell_id
# P2_1__AAACCTGAGAAACCAT              nan    P2_1  Capillary Aerocyte
# P2_1__AAATGCCAGATGAGAG              nan    P2_1  Capillary Aerocyte
# P2_1__AACACGTTCGATCCCT              nan    P2_1  Capillary Aerocyte
# P2_1__AACACGTTCGCACTCT              nan    P2_1  Capillary Aerocyte
# P2_1__AACCATGCAGCTCGCA              nan    P2_1  Capillary Aerocyte
#
#                        individual    sample                 sequencing_run  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
# P2_1__AAATGCCAGATGAGAG  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
# P2_1__AACACGTTCGATCCCT  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
# P2_1__AACACGTTCGCACTCT  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
# P2_1__AACCATGCAGCTCGCA  patient_2  distal 2  180607_A00111_0155_BHFCWYDMXX
#
#                          sex species species_batch species_latin tissue  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  male   Human         human  Homo sapiens   Lung
# P2_1__AAATGCCAGATGAGAG  male   Human         human  Homo sapiens   Lung
# P2_1__AACACGTTCGATCCCT  male   Human         human  Homo sapiens   Lung
# P2_1__AACACGTTCGCACTCT  male   Human         human  Homo sapiens   Lung
# P2_1__AACCATGCAGCTCGCA  male   Human         human  Homo sapiens   Lung
#
#                               narrow_group broad_group compartment_group  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  Capillary Aerocyte   Capillary       endothelial
# P2_1__AAATGCCAGATGAGAG  Capillary Aerocyte   Capillary       endothelial
# P2_1__AACACGTTCGATCCCT  Capillary Aerocyte   Capillary       endothelial
# P2_1__AACACGTTCGCACTCT  Capillary Aerocyte   Capillary       endothelial
# P2_1__AACCATGCAGCTCGCA  Capillary Aerocyte   Capillary       endothelial
#
#                                      compartment_narrow channel_cleaned  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  endothelial: Capillary Aerocyte            P2_1
# P2_1__AAATGCCAGATGAGAG  endothelial: Capillary Aerocyte            P2_1
# P2_1__AACACGTTCGATCCCT  endothelial: Capillary Aerocyte            P2_1
# P2_1__AACACGTTCGCACTCT  endothelial: Capillary Aerocyte            P2_1
# P2_1__AACCATGCAGCTCGCA  endothelial: Capillary Aerocyte            P2_1
#
#                         batch  n_genes  n_counts species_batch_v2  \
# cell_id
# P2_1__AAACCTGAGAAACCAT    NaN      NaN       NaN              hlm
# P2_1__AAATGCCAGATGAGAG    NaN      NaN       NaN              hlm
# P2_1__AACACGTTCGATCCCT    NaN      NaN       NaN              hlm
# P2_1__AACACGTTCGCACTCT    NaN      NaN       NaN              hlm
# P2_1__AACCATGCAGCTCGCA    NaN      NaN       NaN              hlm
#
#                              compartment_broad  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  endothelial: Capillary
# P2_1__AAATGCCAGATGAGAG  endothelial: Capillary
# P2_1__AACACGTTCGATCCCT  endothelial: Capillary
# P2_1__AACACGTTCGCACTCT  endothelial: Capillary
# P2_1__AACCATGCAGCTCGCA  endothelial: Capillary
#
#                                           compartment_broad_narrow  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  endothelial: Capillary: Capillary Aerocyte
# P2_1__AAATGCCAGATGAGAG  endothelial: Capillary: Capillary Aerocyte
# P2_1__AACACGTTCGATCCCT  endothelial: Capillary: Capillary Aerocyte
# P2_1__AACACGTTCGCACTCT  endothelial: Capillary: Capillary Aerocyte
# P2_1__AACCATGCAGCTCGCA  endothelial: Capillary: Capillary Aerocyte
#
#                        compartment_species  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  endothelial: human
# P2_1__AAATGCCAGATGAGAG  endothelial: human
# P2_1__AACACGTTCGATCCCT  endothelial: human
# P2_1__AACACGTTCGCACTCT  endothelial: human
# P2_1__AACCATGCAGCTCGCA  endothelial: human
#
#                                     compartment_narrow_species  \
# cell_id
# P2_1__AAACCTGAGAAACCAT  endothelial: Capillary Aerocyte: human
# P2_1__AAATGCCAGATGAGAG  endothelial: Capillary Aerocyte: human
# P2_1__AACACGTTCGATCCCT  endothelial: Capillary Aerocyte: human
# P2_1__AACACGTTCGCACTCT  endothelial: Capillary Aerocyte: human
# P2_1__AACCATGCAGCTCGCA  endothelial: Capillary Aerocyte: human
#
#                        common_individual_id
# cell_id
# P2_1__AAACCTGAGAAACCAT      human_patient_2
# P2_1__AAATGCCAGATGAGAG      human_patient_2
# P2_1__AACACGTTCGATCCCT      human_patient_2
# P2_1__AACACGTTCGCACTCT      human_patient_2
# P2_1__AACCATGCAGCTCGCA      human_patient_2

# %% [markdown]
# # Read and transform Sourmash search results

# %% [markdown]
# ## Functions / tools to add cell type ontologies

# %% [markdown]
# ### Column renamer

# %%
cols = ["cell_ontology_class", "narrow_group", "broad_group", "compartment_group"]

mouse1_renamer = {col: f"mouse1_{col}"  for col in cols}
mouse2_renamer = {col: f"mouse2_{col}" for col in cols}

# %%
def add_ontologies(search_results_df, adata, mouse_cell_id_col, renamer):

    search_results_with_ontologies = search_results_df.join(
        adata.obs[cols], 
        on=mouse_cell_id_col,
        how='inner'
    )
    # Remove null ksizes
#     search_results_with_ontologies = search_results_with_ontologies.loc[search_results_with_ontologies.ksize.notnull()]
    search_results_with_ontologies['ksize'] = search_results_with_ontologies['ksize'].astype(int)
    search_results_with_ontologies['sketch_value'] = search_results_with_ontologies['sketch_value'].astype(int)
    search_results_with_ontologies.rename(columns=renamer, inplace=True)
    search_results_with_ontologies.reset_index(inplace=True, drop=True)
#     search_results_with_ontologies.dropna(subset=renamer.values(), inplace=True)

#     print(search_results_with_ontologies.shape)
    return search_results_with_ontologies

# %% [markdown]
# ## Read output CSVs

# %%
celltype_cols = ["cell_ontology_class", "narrow_group", "broad_group", "compartment_group"]
matching_cols = [f'{x}_matches' for x in celltype_cols]
celltype_to_matching_cols = dict(zip(celltype_cols, matching_cols))

# %%
1+1
# Out:
# 2

# %%
dfs = []

globber = os.path.join(mouse2mouse_dir, '3-*', '*', '*.csv')

# Hardcoded magic number from the total number of lines in the file of all comands submitted to parallel
# (immune-evolution)
#  ✘  Tue 15 Dec - 18:55  ~/data_sm/immune-evolution/pipeline-results/mouse/kmermaid/lung--mouse--remove-ribo/sbt_indices_handmade_remove_ribosomal_all_cells_per_mouse 
#  olga@lrrr  wc -l  /home/olga/data_sm/immune-evolution/pipeline-results/mouse/kmermaid/lung--mouse--remove-ribo/search_mouse2mouse__remove_ribosomal_dissociation__all_cells__remove_common_hashes/sourmash_search_commands.txt
# 97416 /home/olga/data_sm/immune-evolution/pipeline-results/mouse/kmermaid/lung--mouse--remove-ribo/search_mouse2mouse__remove_ribosomal_dissociation__all_cells__remove_common_hashes/sourmash_search_commands.tx

# Manually obtained from the file sent to gnu parallel
total = sum(1 for _ in glob.iglob(globber))



def add_is_matching_col(
    df, 
    celltype_to_matching_cols=celltype_to_matching_cols, 
    mouse1_renamer=mouse1_renamer, 
    mouse2_renamer=mouse2_renamer
):
    ## Add matching col of whether the category matches
    for celltype_col, matching_col in celltype_to_matching_cols.items():
        mouse1_col = mouse1_renamer[celltype_col]
        mouse2_col = mouse2_renamer[celltype_col]
        df[matching_col] = df[mouse1_col] == df[mouse2_col]
    return df


for csv in tqdm(glob.iglob(globber), total=total):
#     df = read_and_process_sourmash_search_results(
#         csv,
#         adata=one2one,
#         column_renamer=mouse2_renamer,
#         query_species='mouse',
#         shared_celltypes=SHARED_CELLTYPES,
#     )

#     df["database_type"] = os.path.dirname(csv).split("/")[-2].split("--")[-1]

#     dfs.append(df)
    
    sketch_id = os.path.basename(os.path.dirname(csv))
    basename = os.path.basename(csv).split('.csv')[0]
    cell_id = basename.split('.')[0]


    df = pd.read_csv(csv)
    if 'containment' in csv:
        df["search_method"] = "containment"
    else:
        df["search_method"] = "similarity_abundance"
    df["database_type"] = os.path.dirname(csv).split("/")[-2].split("--")[-1] 
    
    df['sketch_id'] = sketch_id
    sig_info = df['sketch_id'].str.extractall(sig_utils.SKETCH_INFO_PATTERN)
    sig_info = sig_info.droplevel(-1)
    sig_info['ksize'] = sig_info['ksize'].astype(int)
    sig_info['sketch_value'] = sig_info['sketch_value'].astype(int)
    df['mouse2_cell_id'] = cell_id
    df_metadata = pd.concat([df, sig_info], axis=1)
    df_metadata = df_metadata.drop(['filename', 'md5'], axis=1)
    df_metadata = df_metadata.rename(columns={'name': 'mouse1_broad_group'})
#     df_metadata['mouse1_channel'] = df_metadata.mouse1_cell_id.str.split('__').str[0]
    df_metadata['mouse2_channel'] = df_metadata.mouse2_cell_id.str.split('__').str[0]
#     df_metadata['mouse1_eq_mouse2'] = df_metadata.mouse2_channel == df_metadata.mouse1_channel
    
    # Add cell_ontology_class, narrow_group, broad_group, compartment_group for each mouse
    df_metadata_mouse2_ontologies = add_ontologies(df_metadata, one2one, 'mouse2_cell_id', mouse2_renamer)
    
    # Add whether mouse1, mouse2 cell type match
    #     df_metadata_mouse2_ontologies = add_is_matching_col(df_metadata_mouse2_ontologies)
    
    dfs.append(df_metadata_mouse2_ontologies)
#     break
search_results = pd.concat(dfs, ignore_index=True)
print(search_results.shape)
search_results.head()
# Out:
# 100%|██████████| 65940/65940 [54:50<00:00, 20.04it/s]
# (656190, 16)
#    similarity mouse1_broad_group         search_method  database_type  \
# 0    0.002426           Monocyte  similarity_abundance  remove_common
# 1    0.002267             B cell  similarity_abundance  remove_common
# 2    0.001553          Capillary  similarity_abundance  remove_common
# 3    0.001389             T cell  similarity_abundance  remove_common
# 4    0.001267          Dendritic  similarity_abundance  remove_common
#
#                                sketch_id  \
# 0  alphabet-dayhoff__ksize-51__scaled-10
# 1  alphabet-dayhoff__ksize-51__scaled-10
# 2  alphabet-dayhoff__ksize-51__scaled-10
# 3  alphabet-dayhoff__ksize-51__scaled-10
# 4  alphabet-dayhoff__ksize-51__scaled-10
#
#                          mouse2_cell_id mol_or_alpha alphabet  ksize  \
# 0  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 1  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 2  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 3  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 4  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
#
#   sketch_style  sketch_value      mouse2_channel mouse2_cell_ontology_class  \
# 0       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 1       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 2       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 3       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 4       scaled            10  MACA_18m_F_LUNG_51                     B cell
#
#   mouse2_narrow_group mouse2_broad_group mouse2_compartment_group
# 0              B cell             B cell                 lymphoid
# 1              B cell             B cell                 lymphoid
# 2              B cell             B cell                 lymphoid
# 3              B cell             B cell                 lymphoid
# 4              B cell             B cell                 lymphoid

# %%
search_results['database_method'] = search_results.database_type.astype(str) + ': ' + search_results.search_method.astype(str)

# %%
search_results.database_method.value_counts()
# Out:
# min-10-percent-shared-kmers: containment                                 65940
# min-10-percent-shared-kmers: similarity_abundance                        65940
# min-10-percent-shared-kmers-remove-common-kmers: containment             65940
# min-5-percent-shared-kmers: containment                                  65940
# min-5-percent-shared-kmers: similarity_abundance                         65940
# min-10-percent-shared-kmers-remove-common-kmers: similarity_abundance    65940
# min-5-percent-shared-kmers-remove-common-kmers: containment              65940
# min-5-percent-shared-kmers-remove-common-kmers: similarity_abundance     65940
# raw_merged: similarity_abundance                                         64335
# remove_common: similarity_abundance                                      64335
# Name: database_method, dtype: int64

# %%
search_results
# Out:
#         similarity               mouse1_broad_group         search_method  \
# 0         0.002426                         Monocyte  similarity_abundance
# 1         0.002267                           B cell  similarity_abundance
# 2         0.001553                        Capillary  similarity_abundance
# 3         0.001389                           T cell  similarity_abundance
# 4         0.001267                        Dendritic  similarity_abundance
# ...            ...                              ...                   ...
# 656185    0.323133  Smooth Muscle and Myofibroblast  similarity_abundance
# 656186    0.254790                       Macrophage  similarity_abundance
# 656187    0.247480                        Capillary  similarity_abundance
# 656188    0.231250                       Fibroblast  similarity_abundance
# 656189    0.046490       Alveolar Epithelial Type 2  similarity_abundance
#
#                       database_type                              sketch_id  \
# 0                     remove_common  alphabet-dayhoff__ksize-51__scaled-10
# 1                     remove_common  alphabet-dayhoff__ksize-51__scaled-10
# 2                     remove_common  alphabet-dayhoff__ksize-51__scaled-10
# 3                     remove_common  alphabet-dayhoff__ksize-51__scaled-10
# 4                     remove_common  alphabet-dayhoff__ksize-51__scaled-10
# ...                             ...                                    ...
# 656185  min-10-percent-shared-kmers  alphabet-protein__ksize-30__scaled-10
# 656186  min-10-percent-shared-kmers  alphabet-protein__ksize-30__scaled-10
# 656187  min-10-percent-shared-kmers  alphabet-protein__ksize-30__scaled-10
# 656188  min-10-percent-shared-kmers  alphabet-protein__ksize-30__scaled-10
# 656189  min-10-percent-shared-kmers  alphabet-protein__ksize-30__scaled-10
#
#                               mouse2_cell_id mol_or_alpha alphabet  ksize  \
# 0       MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 1       MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 2       MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 3       MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 4       MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# ...                                      ...          ...      ...    ...
# 656185  MACA_18m_F_LUNG_51__GACGTTAGTCCTCTTG     alphabet  protein     30
# 656186  MACA_18m_F_LUNG_51__GACGTTAGTCCTCTTG     alphabet  protein     30
# 656187  MACA_18m_F_LUNG_51__GACGTTAGTCCTCTTG     alphabet  protein     30
# 656188  MACA_18m_F_LUNG_51__GACGTTAGTCCTCTTG     alphabet  protein     30
# 656189  MACA_18m_F_LUNG_51__GACGTTAGTCCTCTTG     alphabet  protein     30
#
#        sketch_style  sketch_value      mouse2_channel  \
# 0            scaled            10  MACA_18m_F_LUNG_51
# 1            scaled            10  MACA_18m_F_LUNG_51
# 2            scaled            10  MACA_18m_F_LUNG_51
# 3            scaled            10  MACA_18m_F_LUNG_51
# 4            scaled            10  MACA_18m_F_LUNG_51
# ...             ...           ...                 ...
# 656185       scaled            10  MACA_18m_F_LUNG_51
# 656186       scaled            10  MACA_18m_F_LUNG_51
# 656187       scaled            10  MACA_18m_F_LUNG_51
# 656188       scaled            10  MACA_18m_F_LUNG_51
# 656189       scaled            10  MACA_18m_F_LUNG_51
#
#        mouse2_cell_ontology_class    mouse2_narrow_group  \
# 0                          B cell                 B cell
# 1                          B cell                 B cell
# 2                          B cell                 B cell
# 3                          B cell                 B cell
# 4                          B cell                 B cell
# ...                           ...                    ...
# 656185           mature NK T cell  Natural Killer T cell
# 656186           mature NK T cell  Natural Killer T cell
# 656187           mature NK T cell  Natural Killer T cell
# 656188           mature NK T cell  Natural Killer T cell
# 656189           mature NK T cell  Natural Killer T cell
#
#            mouse2_broad_group mouse2_compartment_group  \
# 0                      B cell                 lymphoid
# 1                      B cell                 lymphoid
# 2                      B cell                 lymphoid
# 3                      B cell                 lymphoid
# 4                      B cell                 lymphoid
# ...                       ...                      ...
# 656185  Natural Killer T cell                 lymphoid
# 656186  Natural Killer T cell                 lymphoid
# 656187  Natural Killer T cell                 lymphoid
# 656188  Natural Killer T cell                 lymphoid
# 656189  Natural Killer T cell                 lymphoid
#
#                                           database_method
# 0                     remove_common: similarity_abundance
# 1                     remove_common: similarity_abundance
# 2                     remove_common: similarity_abundance
# 3                     remove_common: similarity_abundance
# 4                     remove_common: similarity_abundance
# ...                                                   ...
# 656185  min-10-percent-shared-kmers: similarity_abundance
# 656186  min-10-percent-shared-kmers: similarity_abundance
# 656187  min-10-percent-shared-kmers: similarity_abundance
# 656188  min-10-percent-shared-kmers: similarity_abundance
# 656189  min-10-percent-shared-kmers: similarity_abundance
#
# [656190 rows x 17 columns]

# %%
describe(search_results)
# Out:
# (656190, 17)
# --- First 5 entries ---
#    similarity mouse1_broad_group         search_method  database_type  \
# 0    0.002426           Monocyte  similarity_abundance  remove_common
# 1    0.002267             B cell  similarity_abundance  remove_common
# 2    0.001553          Capillary  similarity_abundance  remove_common
# 3    0.001389             T cell  similarity_abundance  remove_common
# 4    0.001267          Dendritic  similarity_abundance  remove_common
#
#                                sketch_id  \
# 0  alphabet-dayhoff__ksize-51__scaled-10
# 1  alphabet-dayhoff__ksize-51__scaled-10
# 2  alphabet-dayhoff__ksize-51__scaled-10
# 3  alphabet-dayhoff__ksize-51__scaled-10
# 4  alphabet-dayhoff__ksize-51__scaled-10
#
#                          mouse2_cell_id mol_or_alpha alphabet  ksize  \
# 0  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 1  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 2  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 3  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 4  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
#
#   sketch_style  sketch_value      mouse2_channel mouse2_cell_ontology_class  \
# 0       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 1       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 2       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 3       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 4       scaled            10  MACA_18m_F_LUNG_51                     B cell
#
#   mouse2_narrow_group mouse2_broad_group mouse2_compartment_group  \
# 0              B cell             B cell                 lymphoid
# 1              B cell             B cell                 lymphoid
# 2              B cell             B cell                 lymphoid
# 3              B cell             B cell                 lymphoid
# 4              B cell             B cell                 lymphoid
#
#                        database_method
# 0  remove_common: similarity_abundance
# 1  remove_common: similarity_abundance
# 2  remove_common: similarity_abundance
# 3  remove_common: similarity_abundance
# 4  remove_common: similarity_abundance

# %% [markdown]
# ### Make sure ksize 21, 24 in results

# %%
sorted(list(set(search_results.ksize)))
# Out:
# [21, 30, 51]

# %%
len(set(search_results.sketch_id))
# Out:
# 3

# %%
search_results.sketch_id.value_counts()
# Out:
# alphabet-DNA__ksize-21__scaled-10        219226
# alphabet-protein__ksize-30__scaled-10    218576
# alphabet-dayhoff__ksize-51__scaled-10    218388
# Name: sketch_id, dtype: int64

# %%
search_results.database_type.value_counts()
# Out:
# min-5-percent-shared-kmers-remove-common-kmers     131880
# min-10-percent-shared-kmers-remove-common-kmers    131880
# min-10-percent-shared-kmers                        131880
# min-5-percent-shared-kmers                         131880
# remove_common                                       64335
# raw_merged                                          64335
# Name: database_type, dtype: int64

# %%
set(search_results.alphabet)
# Out:
# {'DNA', 'dayhoff', 'protein'}

# %% [markdown]
# ## Add human readable column of cell type lookup

# %%
mouse2_channel__to__human_readable = {
    'MACA_18m_M_LUNG_52': 'self:self',
    'MACA_18m_M_LUNG_53': 'male:male',
    'MACA_18m_F_LUNG_51': 'male:female'
}


search_results['mouse2_human_readable'] = search_results.mouse2_channel.map(mouse2_channel__to__human_readable)
search_results['broad_group_matches'] = search_results['mouse1_broad_group'] == search_results['mouse2_broad_group']
describe(search_results)
# Out:
# (656190, 19)
# --- First 5 entries ---
#    similarity mouse1_broad_group         search_method  database_type  \
# 0    0.002426           Monocyte  similarity_abundance  remove_common
# 1    0.002267             B cell  similarity_abundance  remove_common
# 2    0.001553          Capillary  similarity_abundance  remove_common
# 3    0.001389             T cell  similarity_abundance  remove_common
# 4    0.001267          Dendritic  similarity_abundance  remove_common
#
#                                sketch_id  \
# 0  alphabet-dayhoff__ksize-51__scaled-10
# 1  alphabet-dayhoff__ksize-51__scaled-10
# 2  alphabet-dayhoff__ksize-51__scaled-10
# 3  alphabet-dayhoff__ksize-51__scaled-10
# 4  alphabet-dayhoff__ksize-51__scaled-10
#
#                          mouse2_cell_id mol_or_alpha alphabet  ksize  \
# 0  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 1  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 2  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 3  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 4  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
#
#   sketch_style  sketch_value      mouse2_channel mouse2_cell_ontology_class  \
# 0       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 1       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 2       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 3       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 4       scaled            10  MACA_18m_F_LUNG_51                     B cell
#
#   mouse2_narrow_group mouse2_broad_group mouse2_compartment_group  \
# 0              B cell             B cell                 lymphoid
# 1              B cell             B cell                 lymphoid
# 2              B cell             B cell                 lymphoid
# 3              B cell             B cell                 lymphoid
# 4              B cell             B cell                 lymphoid
#
#                        database_method mouse2_human_readable  \
# 0  remove_common: similarity_abundance           male:female
# 1  remove_common: similarity_abundance           male:female
# 2  remove_common: similarity_abundance           male:female
# 3  remove_common: similarity_abundance           male:female
# 4  remove_common: similarity_abundance           male:female
#
#    broad_group_matches
# 0                False
# 1                 True
# 2                False
# 3                False
# 4                False

# %% [markdown]
# ## Add some convenience columns for plotting

# %%
# %%time
broad_group_matches_str = {True: "same celltype", False: 'different celltype'}

search_results['broad_group_matches_string'] = search_results['broad_group_matches'].map(
    broad_group_matches_str
)
search_results['alpha_ksize'] = search_results.apply(
    lambda x: '{alphabet}, k:{ksize}'.format(**x), 
    axis=1
)
search_results['alpha_match'] = search_results.apply(
    lambda x: '{alphabet}, {broad_group_matches_string}'.format(**x), 
    axis=1
)

search_results['mouse2_match'] = search_results.apply(
    lambda x: '{mouse2_human_readable}, {broad_group_matches_string}'.format(**x), 
    axis=1
)
describe(search_results)
# Out:
# (656190, 23)
# --- First 5 entries ---
#    similarity mouse1_broad_group         search_method  database_type  \
# 0    0.002426           Monocyte  similarity_abundance  remove_common
# 1    0.002267             B cell  similarity_abundance  remove_common
# 2    0.001553          Capillary  similarity_abundance  remove_common
# 3    0.001389             T cell  similarity_abundance  remove_common
# 4    0.001267          Dendritic  similarity_abundance  remove_common
#
#                                sketch_id  \
# 0  alphabet-dayhoff__ksize-51__scaled-10
# 1  alphabet-dayhoff__ksize-51__scaled-10
# 2  alphabet-dayhoff__ksize-51__scaled-10
# 3  alphabet-dayhoff__ksize-51__scaled-10
# 4  alphabet-dayhoff__ksize-51__scaled-10
#
#                          mouse2_cell_id mol_or_alpha alphabet  ksize  \
# 0  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 1  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 2  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 3  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
# 4  MACA_18m_F_LUNG_51__TGCACCTAGGGTATCG     alphabet  dayhoff     51
#
#   sketch_style  sketch_value      mouse2_channel mouse2_cell_ontology_class  \
# 0       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 1       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 2       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 3       scaled            10  MACA_18m_F_LUNG_51                     B cell
# 4       scaled            10  MACA_18m_F_LUNG_51                     B cell
#
#   mouse2_narrow_group mouse2_broad_group mouse2_compartment_group  \
# 0              B cell             B cell                 lymphoid
# 1              B cell             B cell                 lymphoid
# 2              B cell             B cell                 lymphoid
# 3              B cell             B cell                 lymphoid
# 4              B cell             B cell                 lymphoid
#
#                        database_method mouse2_human_readable  \
# 0  remove_common: similarity_abundance           male:female
# 1  remove_common: similarity_abundance           male:female
# 2  remove_common: similarity_abundance           male:female
# 3  remove_common: similarity_abundance           male:female
# 4  remove_common: similarity_abundance           male:female
#
#    broad_group_matches broad_group_matches_string    alpha_ksize  \
# 0                False         different celltype  dayhoff, k:51
# 1                 True              same celltype  dayhoff, k:51
# 2                False         different celltype  dayhoff, k:51
# 3                False         different celltype  dayhoff, k:51
# 4                False         different celltype  dayhoff, k:51
#
#                    alpha_match                     mouse2_match
# 0  dayhoff, different celltype  male:female, different celltype
# 1       dayhoff, same celltype       male:female, same celltype
# 2  dayhoff, different celltype  male:female, different celltype
# 3  dayhoff, different celltype  male:female, different celltype
# 4  dayhoff, different celltype  male:female, different celltype
# CPU times: user 2min 48s, sys: 1.31 s, total: 2min 50s
# Wall time: 2min 50s

# %% [markdown]
# ## Constants (`classification_groupby`, `celltype_col`, `query_organism`, `scoring_groupby`)

# %%
classification_groupby = ["mouse2_cell_id", "database_type", "search_method", "alphabet", "ksize"]

celltype_col = "broad_group"
sbt_organism = "mouse1"
query_organism = "mouse2"

predicted_celltype_col = f"{sbt_organism}_{celltype_col}"
ground_truth_celltype_col = f"{query_organism}_{celltype_col}"

scoring_groupby = [
    "mouse2_human_readable",
    "database_type",
    "search_method",
    "alphabet",
    "ksize",
]

# %%
t_cell = 'MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA'
search_results.query('mouse2_cell_id == @t_cell').groupby(classification_groupby).apply(lambda x: x.nlargest(1, 'similarity'))
# Out:
#                                                                                                                                  similarity  \
# mouse2_cell_id                       database_type                                   search_method        alphabet ksize
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA min-10-percent-shared-kmers                     containment          DNA      21    159125    0.296154
#                                                                                                           dayhoff  51    137145    0.271510
#                                                                                                           protein  30    181105    0.296568
#                                                                                      similarity_abundance DNA      21    619100    0.507136
#                                                                                                           dayhoff  51    597120    0.537653
#                                                                                                           protein  30    641080    0.560248
#                                      min-10-percent-shared-kmers-remove-common-kmers containment          DNA      21    355340    0.182216
#                                                                                                           dayhoff  51    333360    0.165634
#                                                                                                           protein  30    377320    0.171718
#                                                                                      similarity_abundance DNA      21    487220    0.083241
#                                                                                                           dayhoff  51    465240    0.118770
#                                                                                                           protein  30    509200    0.112218
#                                      min-5-percent-shared-kmers                      containment          DNA      21    93185     0.395659
#                                                                                                           dayhoff  51    71205     0.367344
#                                                                                                           protein  30    115165    0.390205
#                                                                                      similarity_abundance DNA      21    421280    0.507801
#                                                                                                           dayhoff  51    399300    0.538735
#                                                                                                           protein  30    443260    0.561120
#                                      min-5-percent-shared-kmers-remove-common-kmers  containment          DNA      21    225065    0.237014
#                                                                                                           dayhoff  51    203085    0.216588
#                                                                                                           protein  30    247045    0.221297
#                                                                                      similarity_abundance DNA      21    553160    0.086712
#                                                                                                           dayhoff  51    531180    0.119992
#                                                                                                           protein  30    575140    0.114376
#                                      raw_merged                                      similarity_abundance DNA      21    290205    0.001851
#                                                                                                           dayhoff  51    268793    0.003108
#                                                                                                           protein  30    311781    0.002904
#                                      remove_common                                   similarity_abundance DNA      21    28050     0.001851
#                                                                                                           dayhoff  51    6638      0.003108
#                                                                                                           protein  30    49626     0.002904
#
#                                                                                                                                 mouse1_broad_group  \
# mouse2_cell_id                       database_type                                   search_method        alphabet ksize
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA min-10-percent-shared-kmers                     containment          DNA      21    159125           Monocyte
#                                                                                                           dayhoff  51    137145           Monocyte
#                                                                                                           protein  30    181105           Monocyte
#                                                                                      similarity_abundance DNA      21    619100             T cell
#                                                                                                           dayhoff  51    597120             T cell
#                                                                                                           protein  30    641080             T cell
#                                      min-10-percent-shared-kmers-remove-common-kmers containment          DNA      21    355340           Monocyte
#                                                                                                           dayhoff  51    333360           Monocyte
#                                                                                                           protein  30    377320           Monocyte
#                                                                                      similarity_abundance DNA      21    487220             T cell
#                                                                                                           dayhoff  51    465240             T cell
#                                                                                                           protein  30    509200             T cell
#                                      min-5-percent-shared-kmers                      containment          DNA      21    93185            Monocyte
#                                                                                                           dayhoff  51    71205            Monocyte
#                                                                                                           protein  30    115165           Monocyte
#                                                                                      similarity_abundance DNA      21    421280             T cell
#                                                                                                           dayhoff  51    399300             T cell
#                                                                                                           protein  30    443260             T cell
#                                      min-5-percent-shared-kmers-remove-common-kmers  containment          DNA      21    225065           Monocyte
#                                                                                                           dayhoff  51    203085           Monocyte
#                                                                                                           protein  30    247045           Monocyte
#                                                                                      similarity_abundance DNA      21    553160             T cell
#                                                                                                           dayhoff  51    531180             T cell
#                                                                                                           protein  30    575140             T cell
#                                      raw_merged                                      similarity_abundance DNA      21    290205             T cell
#                                                                                                           dayhoff  51    268793           Monocyte
#                                                                                                           protein  30    311781             T cell
#                                      remove_common                                   similarity_abundance DNA      21    28050              T cell
#                                                                                                           dayhoff  51    6638             Monocyte
#                                                                                                           protein  30    49626              T cell
#
#                                                                                                                                         search_method  \
# mouse2_cell_id                       database_type                                   search_method        alphabet ksize
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA min-10-percent-shared-kmers                     containment          DNA      21    159125           containment
#                                                                                                           dayhoff  51    137145           containment
#                                                                                                           protein  30    181105           containment
#                                                                                      similarity_abundance DNA      21    619100  similarity_abundance
#                                                                                                           dayhoff  51    597120  similarity_abundance
#                                                                                                           protein  30    641080  similarity_abundance
#                                      min-10-percent-shared-kmers-remove-common-kmers containment          DNA      21    355340           containment
#                                                                                                           dayhoff  51    333360           containment
#                                                                                                           protein  30    377320           containment
#                                                                                      similarity_abundance DNA      21    487220  similarity_abundance
#                                                                                                           dayhoff  51    465240  similarity_abundance
#                                                                                                           protein  30    509200  similarity_abundance
#                                      min-5-percent-shared-kmers                      containment          DNA      21    93185            containment
#                                                                                                           dayhoff  51    71205            containment
#                                                                                                           protein  30    115165           containment
#                                                                                      similarity_abundance DNA      21    421280  similarity_abundance
#                                                                                                           dayhoff  51    399300  similarity_abundance
#                                                                                                           protein  30    443260  similarity_abundance
#                                      min-5-percent-shared-kmers-remove-common-kmers  containment          DNA      21    225065           containment
#                                                                                                           dayhoff  51    203085           containment
#                                                                                                           protein  30    247045           containment
#                                                                                      similarity_abundance DNA      21    553160  similarity_abundance
#                                                                                                           dayhoff  51    531180  similarity_abundance
#                                                                                                           protein  30    575140  similarity_abundance
#                                      raw_merged                                      similarity_abundance DNA      21    290205  similarity_abundance
#                                                                                                           dayhoff  51    268793  similarity_abundance
#                                                                                                           protein  30    311781  similarity_abundance
#                                      remove_common                                   similarity_abundance DNA      21    28050   similarity_abundance
#                                                                                                           dayhoff  51    6638    similarity_abundance
#                                                                                                           protein  30    49626   similarity_abundance
#
#                                                                                                                                                                    database_type  \
# mouse2_cell_id                       database_type                                   search_method        alphabet ksize
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA min-10-percent-shared-kmers                     containment          DNA      21    159125                      min-10-percent-shared-kmers
#                                                                                                           dayhoff  51    137145                      min-10-percent-shared-kmers
#                                                                                                           protein  30    181105                      min-10-percent-shared-kmers
#                                                                                      similarity_abundance DNA      21    619100                      min-10-percent-shared-kmers
#                                                                                                           dayhoff  51    597120                      min-10-percent-shared-kmers
#                                                                                                           protein  30    641080                      min-10-percent-shared-kmers
#                                      min-10-percent-shared-kmers-remove-common-kmers containment          DNA      21    355340  min-10-percent-shared-kmers-remove-common-kmers
#                                                                                                           dayhoff  51    333360  min-10-percent-shared-kmers-remove-common-kmers
#                                                                                                           protein  30    377320  min-10-percent-shared-kmers-remove-common-kmers
#                                                                                      similarity_abundance DNA      21    487220  min-10-percent-shared-kmers-remove-common-kmers
#                                                                                                           dayhoff  51    465240  min-10-percent-shared-kmers-remove-common-kmers
#                                                                                                           protein  30    509200  min-10-percent-shared-kmers-remove-common-kmers
#                                      min-5-percent-shared-kmers                      containment          DNA      21    93185                        min-5-percent-shared-kmers
#                                                                                                           dayhoff  51    71205                        min-5-percent-shared-kmers
#                                                                                                           protein  30    115165                       min-5-percent-shared-kmers
#                                                                                      similarity_abundance DNA      21    421280                       min-5-percent-shared-kmers
#                                                                                                           dayhoff  51    399300                       min-5-percent-shared-kmers
#                                                                                                           protein  30    443260                       min-5-percent-shared-kmers
#                                      min-5-percent-shared-kmers-remove-common-kmers  containment          DNA      21    225065   min-5-percent-shared-kmers-remove-common-kmers
#                                                                                                           dayhoff  51    203085   min-5-percent-shared-kmers-remove-common-kmers
#                                                                                                           protein  30    247045   min-5-percent-shared-kmers-remove-common-kmers
#                                                                                      similarity_abundance DNA      21    553160   min-5-percent-shared-kmers-remove-common-kmers
#                                                                                                           dayhoff  51    531180   min-5-percent-shared-kmers-remove-common-kmers
#                                                                                                           protein  30    575140   min-5-percent-shared-kmers-remove-common-kmers
#                                      raw_merged                                      similarity_abundance DNA      21    290205                                       raw_merged
#                                                                                                           dayhoff  51    268793                                       raw_merged
#                                                                                                           protein  30    311781                                       raw_merged
#                                      remove_common                                   similarity_abundance DNA      21    28050                                     remove_common
#                                                                                                           dayhoff  51    6638                                      remove_common
#                                                                                                           protein  30    49626                                     remove_common
#
#                                                                                                                                                              sketch_id  \
# mouse2_cell_id                       database_type                                   search_method        alphabet ksize
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA min-10-percent-shared-kmers                     containment          DNA      21    159125      alphabet-DNA__ksize-21__scaled-10
#                                                                                                           dayhoff  51    137145  alphabet-dayhoff__ksize-51__scaled-10
#                                                                                                           protein  30    181105  alphabet-protein__ksize-30__scaled-10
#                                                                                      similarity_abundance DNA      21    619100      alphabet-DNA__ksize-21__scaled-10
#                                                                                                           dayhoff  51    597120  alphabet-dayhoff__ksize-51__scaled-10
#                                                                                                           protein  30    641080  alphabet-protein__ksize-30__scaled-10
#                                      min-10-percent-shared-kmers-remove-common-kmers containment          DNA      21    355340      alphabet-DNA__ksize-21__scaled-10
#                                                                                                           dayhoff  51    333360  alphabet-dayhoff__ksize-51__scaled-10
#                                                                                                           protein  30    377320  alphabet-protein__ksize-30__scaled-10
#                                                                                      similarity_abundance DNA      21    487220      alphabet-DNA__ksize-21__scaled-10
#                                                                                                           dayhoff  51    465240  alphabet-dayhoff__ksize-51__scaled-10
#                                                                                                           protein  30    509200  alphabet-protein__ksize-30__scaled-10
#                                      min-5-percent-shared-kmers                      containment          DNA      21    93185       alphabet-DNA__ksize-21__scaled-10
#                                                                                                           dayhoff  51    71205   alphabet-dayhoff__ksize-51__scaled-10
#                                                                                                           protein  30    115165  alphabet-protein__ksize-30__scaled-10
#                                                                                      similarity_abundance DNA      21    421280      alphabet-DNA__ksize-21__scaled-10
#                                                                                                           dayhoff  51    399300  alphabet-dayhoff__ksize-51__scaled-10
#                                                                                                           protein  30    443260  alphabet-protein__ksize-30__scaled-10
#                                      min-5-percent-shared-kmers-remove-common-kmers  containment          DNA      21    225065      alphabet-DNA__ksize-21__scaled-10
#                                                                                                           dayhoff  51    203085  alphabet-dayhoff__ksize-51__scaled-10
#                                                                                                           protein  30    247045  alphabet-protein__ksize-30__scaled-10
#                                                                                      similarity_abundance DNA      21    553160      alphabet-DNA__ksize-21__scaled-10
#                                                                                                           dayhoff  51    531180  alphabet-dayhoff__ksize-51__scaled-10
#                                                                                                           protein  30    575140  alphabet-protein__ksize-30__scaled-10
#                                      raw_merged                                      similarity_abundance DNA      21    290205      alphabet-DNA__ksize-21__scaled-10
#                                                                                                           dayhoff  51    268793  alphabet-dayhoff__ksize-51__scaled-10
#                                                                                                           protein  30    311781  alphabet-protein__ksize-30__scaled-10
#                                      remove_common                                   similarity_abundance DNA      21    28050       alphabet-DNA__ksize-21__scaled-10
#                                                                                                           dayhoff  51    6638    alphabet-dayhoff__ksize-51__scaled-10
#                                                                                                           protein  30    49626   alphabet-protein__ksize-30__scaled-10
#
#                                                                                                                                                        mouse2_cell_id  \
# mouse2_cell_id                       database_type                                   search_method        alphabet ksize
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA min-10-percent-shared-kmers                     containment          DNA      21    159125  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           dayhoff  51    137145  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           protein  30    181105  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                      similarity_abundance DNA      21    619100  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           dayhoff  51    597120  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           protein  30    641080  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                      min-10-percent-shared-kmers-remove-common-kmers containment          DNA      21    355340  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           dayhoff  51    333360  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           protein  30    377320  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                      similarity_abundance DNA      21    487220  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           dayhoff  51    465240  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           protein  30    509200  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                      min-5-percent-shared-kmers                      containment          DNA      21    93185   MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           dayhoff  51    71205   MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           protein  30    115165  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                      similarity_abundance DNA      21    421280  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           dayhoff  51    399300  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           protein  30    443260  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                      min-5-percent-shared-kmers-remove-common-kmers  containment          DNA      21    225065  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           dayhoff  51    203085  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           protein  30    247045  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                      similarity_abundance DNA      21    553160  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           dayhoff  51    531180  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           protein  30    575140  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                      raw_merged                                      similarity_abundance DNA      21    290205  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           dayhoff  51    268793  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           protein  30    311781  MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                      remove_common                                   similarity_abundance DNA      21    28050   MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           dayhoff  51    6638    MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#                                                                                                           protein  30    49626   MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA
#
#                                                                                                                                 mol_or_alpha  \
# mouse2_cell_id                       database_type                                   search_method        alphabet ksize
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA min-10-percent-shared-kmers                     containment          DNA      21    159125     alphabet
#                                                                                                           dayhoff  51    137145     alphabet
#                                                                                                           protein  30    181105     alphabet
#                                                                                      similarity_abundance DNA      21    619100     alphabet
#                                                                                                           dayhoff  51    597120     alphabet
#                                                                                                           protein  30    641080     alphabet
#                                      min-10-percent-shared-kmers-remove-common-kmers containment          DNA      21    355340     alphabet
#                                                                                                           dayhoff  51    333360     alphabet
#                                                                                                           protein  30    377320     alphabet
#                                                                                      similarity_abundance DNA      21    487220     alphabet
#                                                                                                           dayhoff  51    465240     alphabet
#                                                                                                           protein  30    509200     alphabet
#                                      min-5-percent-shared-kmers                      containment          DNA      21    93185      alphabet
#                                                                                                           dayhoff  51    71205      alphabet
#                                                                                                           protein  30    115165     alphabet
#                                                                                      similarity_abundance DNA      21    421280     alphabet
#                                                                                                           dayhoff  51    399300     alphabet
#                                                                                                           protein  30    443260     alphabet
#                                      min-5-percent-shared-kmers-remove-common-kmers  containment          DNA      21    225065     alphabet
#                                                                                                           dayhoff  51    203085     alphabet
#                                                                                                           protein  30    247045     alphabet
#                                                                                      similarity_abundance DNA      21    553160     alphabet
#                                                                                                           dayhoff  51    531180     alphabet
#                                                                                                           protein  30    575140     alphabet
#                                      raw_merged                                      similarity_abundance DNA      21    290205     alphabet
#                                                                                                           dayhoff  51    268793     alphabet
#                                                                                                           protein  30    311781     alphabet
#                                      remove_common                                   similarity_abundance DNA      21    28050      alphabet
#                                                                                                           dayhoff  51    6638       alphabet
#                                                                                                           protein  30    49626      alphabet
#
#                                                                                                                                 alphabet  \
# mouse2_cell_id                       database_type                                   search_method        alphabet ksize
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA min-10-percent-shared-kmers                     containment          DNA      21    159125      DNA
#                                                                                                           dayhoff  51    137145  dayhoff
#                                                                                                           protein  30    181105  protein
#                                                                                      similarity_abundance DNA      21    619100      DNA
#                                                                                                           dayhoff  51    597120  dayhoff
#                                                                                                           protein  30    641080  protein
#                                      min-10-percent-shared-kmers-remove-common-kmers containment          DNA      21    355340      DNA
#                                                                                                           dayhoff  51    333360  dayhoff
#                                                                                                           protein  30    377320  protein
#                                                                                      similarity_abundance DNA      21    487220      DNA
#                                                                                                           dayhoff  51    465240  dayhoff
#                                                                                                           protein  30    509200  protein
#                                      min-5-percent-shared-kmers                      containment          DNA      21    93185       DNA
#                                                                                                           dayhoff  51    71205   dayhoff
#                                                                                                           protein  30    115165  protein
#                                                                                      similarity_abundance DNA      21    421280      DNA
#                                                                                                           dayhoff  51    399300  dayhoff
#                                                                                                           protein  30    443260  protein
#                                      min-5-percent-shared-kmers-remove-common-kmers  containment          DNA      21    225065      DNA
#                                                                                                           dayhoff  51    203085  dayhoff
#                                                                                                           protein  30    247045  protein
#                                                                                      similarity_abundance DNA      21    553160      DNA
#                                                                                                           dayhoff  51    531180  dayhoff
#                                                                                                           protein  30    575140  protein
#                                      raw_merged                                      similarity_abundance DNA      21    290205      DNA
#                                                                                                           dayhoff  51    268793  dayhoff
#                                                                                                           protein  30    311781  protein
#                                      remove_common                                   similarity_abundance DNA      21    28050       DNA
#                                                                                                           dayhoff  51    6638    dayhoff
#                                                                                                           protein  30    49626   protein
#
#                                                                                                                                  ksize  \
# mouse2_cell_id                       database_type                                   search_method        alphabet ksize
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA min-10-percent-shared-kmers                     containment          DNA      21    159125     21
#                                                                                                           dayhoff  51    137145     51
#                                                                                                           protein  30    181105     30
#                                                                                      similarity_abundance DNA      21    619100     21
#                                                                                                           dayhoff  51    597120     51
#                                                                                                           protein  30    641080     30
#                                      min-10-percent-shared-kmers-remove-common-kmers containment          DNA      21    355340     21
#                                                                                                           dayhoff  51    333360     51
#                                                                                                           protein  30    377320     30
#                                                                                      similarity_abundance DNA      21    487220     21
#                                                                                                           dayhoff  51    465240     51
#                                                                                                           protein  30    509200     30
#                                      min-5-percent-shared-kmers                      containment          DNA      21    93185      21
#                                                                                                           dayhoff  51    71205      51
#                                                                                                           protein  30    115165     30
#                                                                                      similarity_abundance DNA      21    421280     21
#                                                                                                           dayhoff  51    399300     51
#                                                                                                           protein  30    443260     30
#                                      min-5-percent-shared-kmers-remove-common-kmers  containment          DNA      21    225065     21
#                                                                                                           dayhoff  51    203085     51
#                                                                                                           protein  30    247045     30
#                                                                                      similarity_abundance DNA      21    553160     21
#                                                                                                           dayhoff  51    531180     51
#                                                                                                           protein  30    575140     30
#                                      raw_merged                                      similarity_abundance DNA      21    290205     21
#                                                                                                           dayhoff  51    268793     51
#                                                                                                           protein  30    311781     30
#                                      remove_common                                   similarity_abundance DNA      21    28050      21
#                                                                                                           dayhoff  51    6638       51
#                                                                                                           protein  30    49626      30
#
#                                                                                                                                 sketch_style  \
# mouse2_cell_id                       database_type                                   search_method        alphabet ksize
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA min-10-percent-shared-kmers                     containment          DNA      21    159125       scaled
#                                                                                                           dayhoff  51    137145       scaled
#                                                                                                           protein  30    181105       scaled
#                                                                                      similarity_abundance DNA      21    619100       scaled
#                                                                                                           dayhoff  51    597120       scaled
#                                                                                                           protein  30    641080       scaled
#                                      min-10-percent-shared-kmers-remove-common-kmers containment          DNA      21    355340       scaled
#                                                                                                           dayhoff  51    333360       scaled
#                                                                                                           protein  30    377320       scaled
#                                                                                      similarity_abundance DNA      21    487220       scaled
#                                                                                                           dayhoff  51    465240       scaled
#                                                                                                           protein  30    509200       scaled
#                                      min-5-percent-shared-kmers                      containment          DNA      21    93185        scaled
#                                                                                                           dayhoff  51    71205        scaled
#                                                                                                           protein  30    115165       scaled
#                                                                                      similarity_abundance DNA      21    421280       scaled
#                                                                                                           dayhoff  51    399300       scaled
#                                                                                                           protein  30    443260       scaled
#                                      min-5-percent-shared-kmers-remove-common-kmers  containment          DNA      21    225065       scaled
#                                                                                                           dayhoff  51    203085       scaled
#                                                                                                           protein  30    247045       scaled
#                                                                                      similarity_abundance DNA      21    553160       scaled
#                                                                                                           dayhoff  51    531180       scaled
# ...
#                                      raw_merged                                      similarity_abundance DNA      21    290205           DNA, same celltype
#                                                                                                           dayhoff  51    268793  dayhoff, different celltype
#                                                                                                           protein  30    311781       protein, same celltype
#                                      remove_common                                   similarity_abundance DNA      21    28050            DNA, same celltype
#                                                                                                           dayhoff  51    6638    dayhoff, different celltype
#                                                                                                           protein  30    49626        protein, same celltype
#
#                                                                                                                                                     mouse2_match  \
# mouse2_cell_id                       database_type                                   search_method        alphabet ksize
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA min-10-percent-shared-kmers                     containment          DNA      21    159125  male:female, different celltype
#                                                                                                           dayhoff  51    137145  male:female, different celltype
#                                                                                                           protein  30    181105  male:female, different celltype
#                                                                                      similarity_abundance DNA      21    619100       male:female, same celltype
#                                                                                                           dayhoff  51    597120       male:female, same celltype
#                                                                                                           protein  30    641080       male:female, same celltype
#                                      min-10-percent-shared-kmers-remove-common-kmers containment          DNA      21    355340  male:female, different celltype
#                                                                                                           dayhoff  51    333360  male:female, different celltype
#                                                                                                           protein  30    377320  male:female, different celltype
#                                                                                      similarity_abundance DNA      21    487220       male:female, same celltype
#                                                                                                           dayhoff  51    465240       male:female, same celltype
#                                                                                                           protein  30    509200       male:female, same celltype
#                                      min-5-percent-shared-kmers                      containment          DNA      21    93185   male:female, different celltype
#                                                                                                           dayhoff  51    71205   male:female, different celltype
#                                                                                                           protein  30    115165  male:female, different celltype
#                                                                                      similarity_abundance DNA      21    421280       male:female, same celltype
#                                                                                                           dayhoff  51    399300       male:female, same celltype
#                                                                                                           protein  30    443260       male:female, same celltype
#                                      min-5-percent-shared-kmers-remove-common-kmers  containment          DNA      21    225065  male:female, different celltype
#                                                                                                           dayhoff  51    203085  male:female, different celltype
#                                                                                                           protein  30    247045  male:female, different celltype
#                                                                                      similarity_abundance DNA      21    553160       male:female, same celltype
#                                                                                                           dayhoff  51    531180       male:female, same celltype
#                                                                                                           protein  30    575140       male:female, same celltype
#                                      raw_merged                                      similarity_abundance DNA      21    290205       male:female, same celltype
#                                                                                                           dayhoff  51    268793  male:female, different celltype
#                                                                                                           protein  30    311781       male:female, same celltype
#                                      remove_common                                   similarity_abundance DNA      21    28050        male:female, same celltype
#                                                                                                           dayhoff  51    6638    male:female, different celltype
#                                                                                                           protein  30    49626        male:female, same celltype
#
#                                                                                                                                 groundtruth_celltype  \
# mouse2_cell_id                       database_type                                   search_method        alphabet ksize
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA min-10-percent-shared-kmers                     containment          DNA      21    159125               T cell
#                                                                                                           dayhoff  51    137145               T cell
#                                                                                                           protein  30    181105               T cell
#                                                                                      similarity_abundance DNA      21    619100               T cell
#                                                                                                           dayhoff  51    597120               T cell
#                                                                                                           protein  30    641080               T cell
#                                      min-10-percent-shared-kmers-remove-common-kmers containment          DNA      21    355340               T cell
#                                                                                                           dayhoff  51    333360               T cell
#                                                                                                           protein  30    377320               T cell
#                                                                                      similarity_abundance DNA      21    487220               T cell
#                                                                                                           dayhoff  51    465240               T cell
#                                                                                                           protein  30    509200               T cell
#                                      min-5-percent-shared-kmers                      containment          DNA      21    93185                T cell
#                                                                                                           dayhoff  51    71205                T cell
#                                                                                                           protein  30    115165               T cell
#                                                                                      similarity_abundance DNA      21    421280               T cell
#                                                                                                           dayhoff  51    399300               T cell
#                                                                                                           protein  30    443260               T cell
#                                      min-5-percent-shared-kmers-remove-common-kmers  containment          DNA      21    225065               T cell
#                                                                                                           dayhoff  51    203085               T cell
#                                                                                                           protein  30    247045               T cell
#                                                                                      similarity_abundance DNA      21    553160               T cell
#                                                                                                           dayhoff  51    531180               T cell
#                                                                                                           protein  30    575140               T cell
#                                      raw_merged                                      similarity_abundance DNA      21    290205               T cell
#                                                                                                           dayhoff  51    268793               T cell
#                                                                                                           protein  30    311781               T cell
#                                      remove_common                                   similarity_abundance DNA      21    28050                T cell
#                                                                                                           dayhoff  51    6638                 T cell
#                                                                                                           protein  30    49626                T cell
#
#                                                                                                                                 predicted_celltype
# mouse2_cell_id                       database_type                                   search_method        alphabet ksize
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA min-10-percent-shared-kmers                     containment          DNA      21    159125           Monocyte
#                                                                                                           dayhoff  51    137145           Monocyte
#                                                                                                           protein  30    181105           Monocyte
#                                                                                      similarity_abundance DNA      21    619100             T cell
#                                                                                                           dayhoff  51    597120             T cell
#                                                                                                           protein  30    641080             T cell
#                                      min-10-percent-shared-kmers-remove-common-kmers containment          DNA      21    355340           Monocyte
#                                                                                                           dayhoff  51    333360           Monocyte
#                                                                                                           protein  30    377320           Monocyte
#                                                                                      similarity_abundance DNA      21    487220             T cell
#                                                                                                           dayhoff  51    465240             T cell
#                                                                                                           protein  30    509200             T cell
#                                      min-5-percent-shared-kmers                      containment          DNA      21    93185            Monocyte
#                                                                                                           dayhoff  51    71205            Monocyte
#                                                                                                           protein  30    115165           Monocyte
#                                                                                      similarity_abundance DNA      21    421280             T cell
#                                                                                                           dayhoff  51    399300             T cell
#                                                                                                           protein  30    443260             T cell
#                                      min-5-percent-shared-kmers-remove-common-kmers  containment          DNA      21    225065           Monocyte
#                                                                                                           dayhoff  51    203085           Monocyte
#                                                                                                           protein  30    247045           Monocyte
#                                                                                      similarity_abundance DNA      21    553160             T cell
#                                                                                                           dayhoff  51    531180             T cell
#                                                                                                           protein  30    575140             T cell
#                                      raw_merged                                      similarity_abundance DNA      21    290205             T cell
#                                                                                                           dayhoff  51    268793           Monocyte
#                                                                                                           protein  30    311781             T cell
#                                      remove_common                                   similarity_abundance DNA      21    28050              T cell
#                                                                                                           dayhoff  51    6638             Monocyte
#                                                                                                           protein  30    49626              T cell

# %% [markdown]
# ## Add unifying column of predicted and ground truth celltypes

# %%
search_results['groundtruth_celltype'] = search_results[ground_truth_celltype_col]
search_results['predicted_celltype'] = search_results[predicted_celltype_col]

# %% [markdown]
# # write results to parquet file

# %%
# %%time

parquet_fn = "sourmash-search-results.parquet"
parquet = os.path.join(aggregated_results_dir, parquet_fn)
search_results.to_parquet(parquet)
# Out:
# CPU times: user 1.53 s, sys: 188 ms, total: 1.72 s
# Wall time: 1.72 s

# %% [markdown]
# # Predict cell type with top hit

# %% [markdown]
# ## Get top N

# %%
# %%time

predicted_cells_top_hit = search_results.groupby(
    classification_groupby, as_index=False, group_keys=False
).apply(lambda x: x.nlargest(1, 'similarity'))

predicted_cells_top_hit = predicted_cells_top_hit.set_index(f"{query_organism}_cell_id")

print(predicted_cells_top_hit.shape)
predicted_cells_top_hit.head()
# Out:
# (65940, 24)
# CPU times: user 5min 2s, sys: 5.64 s, total: 5min 8s
# Wall time: 5min 6s
#                                       similarity mouse1_broad_group  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.296154           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.271510           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.296568           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.507136             T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA    0.537653             T cell
#
#                                              search_method  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  similarity_abundance
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  similarity_abundance
#
#                                                     database_type  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers
#
#                                                                   sketch_id  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA      alphabet-DNA__ksize-21__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  alphabet-dayhoff__ksize-51__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  alphabet-protein__ksize-30__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA      alphabet-DNA__ksize-21__scaled-10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  alphabet-dayhoff__ksize-51__scaled-10
#
#                                      mol_or_alpha alphabet  ksize  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet      DNA     21
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet  dayhoff     51
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet  protein     30
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet      DNA     21
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA     alphabet  dayhoff     51
#
#                                      sketch_style  sketch_value  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       scaled            10
#
#                                           mouse2_channel  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  MACA_18m_F_LUNG_51
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  MACA_18m_F_LUNG_51
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  MACA_18m_F_LUNG_51
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  MACA_18m_F_LUNG_51
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  MACA_18m_F_LUNG_51
#
#                                            mouse2_cell_ontology_class  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  CD4-positive, alpha-beta T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  CD4-positive, alpha-beta T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  CD4-positive, alpha-beta T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  CD4-positive, alpha-beta T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  CD4-positive, alpha-beta T cell
#
#                                      mouse2_narrow_group mouse2_broad_group  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              CD4+ T             T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              CD4+ T             T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              CD4+ T             T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              CD4+ T             T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              CD4+ T             T cell
#
#                                      mouse2_compartment_group  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                 lymphoid
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                 lymphoid
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                 lymphoid
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                 lymphoid
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                 lymphoid
#
#                                                                         database_method  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           min-10-percent-shared-kmers: containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           min-10-percent-shared-kmers: containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           min-10-percent-shared-kmers: containment
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers: similarity_abundance
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  min-10-percent-shared-kmers: similarity_abundance
#
#                                      mouse2_human_readable  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           male:female
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           male:female
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           male:female
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           male:female
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           male:female
#
#                                       broad_group_matches  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                False
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                False
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                False
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                 True
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA                 True
#
#                                      broad_group_matches_string  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA         different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA         different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA         different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              same celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA              same celltype
#
#                                         alpha_ksize  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA      DNA, k:21
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  dayhoff, k:51
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  protein, k:30
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA      DNA, k:21
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  dayhoff, k:51
#
#                                                       alpha_match  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA      DNA, different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  dayhoff, different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  protein, different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA           DNA, same celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       dayhoff, same celltype
#
#                                                          mouse2_match  \
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  male:female, different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  male:female, different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA  male:female, different celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       male:female, same celltype
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA       male:female, same celltype
#
#                                      groundtruth_celltype predicted_celltype
# mouse2_cell_id
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA               T cell           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA               T cell           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA               T cell           Monocyte
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA               T cell             T cell
# MACA_18m_F_LUNG_51__AAACCTGCAGCCTATA               T cell             T cell

# %%
celpredicted_cells_top_hit.loc['']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-157-680dadd7cfe4> in <module>
# ----> 1 celpredicted_cells_top_hit.loc['']
#
# NameError: name 'celpredicted_cells_top_hit' is not defined

# %% [markdown]
# ### Write top N to file

# %%
# %%time

parquet_fn = "sourmash-search-results--top-hit.parquet"
parquet = os.path.join(aggregated_results_dir, parquet_fn)
predicted_cells_top_hit.to_parquet(parquet)

# %%
parquet

# %%
predicted_cells_top_hit.database_type.value_counts()
